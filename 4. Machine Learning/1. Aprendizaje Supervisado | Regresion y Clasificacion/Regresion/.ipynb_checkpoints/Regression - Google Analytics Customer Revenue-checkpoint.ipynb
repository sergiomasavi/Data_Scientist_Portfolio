# %% [markdown]
# <img src="Tarjeta.png">

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Import-Libraries" data-toc-modified-id="Import-Libraries-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Import Libraries</a></span></li><li><span><a href="#Import-Data" data-toc-modified-id="Import-Data-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Import Data</a></span></li><li><span><a href="#EDA" data-toc-modified-id="EDA-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>EDA</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Target-Analysis" data-toc-modified-id="Target-Analysis-3.0.1"><span class="toc-item-num">3.0.1&nbsp;&nbsp;</span>Target Analysis</a></span></li></ul></li><li><span><a href="#Device---Device-Browser" data-toc-modified-id="Device---Device-Browser-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Device - Device Browser</a></span></li><li><span><a href="#Sistema-Operativo" data-toc-modified-id="Sistema-Operativo-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Sistema Operativo</a></span></li><li><span><a href="#Device---Is-Mobile" data-toc-modified-id="Device---Is-Mobile-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Device - Is Mobile</a></span></li><li><span><a href="#Device---Category" data-toc-modified-id="Device---Category-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Device - Category</a></span></li><li><span><a href="#ChannelGrouping" data-toc-modified-id="ChannelGrouping-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>ChannelGrouping</a></span></li><li><span><a href="#Date" data-toc-modified-id="Date-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Date</a></span></li><li><span><a href="#Visit-Start-Time" data-toc-modified-id="Visit-Start-Time-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Visit Start Time</a></span></li><li><span><a href="#Visit-Number" data-toc-modified-id="Visit-Number-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>Visit Number</a></span></li><li><span><a href="#Hits" data-toc-modified-id="Hits-3.9"><span class="toc-item-num">3.9&nbsp;&nbsp;</span>Hits</a></span></li><li><span><a href="#PageViews" data-toc-modified-id="PageViews-3.10"><span class="toc-item-num">3.10&nbsp;&nbsp;</span>PageViews</a></span></li><li><span><a href="#GeoNetwork---Continent" data-toc-modified-id="GeoNetwork---Continent-3.11"><span class="toc-item-num">3.11&nbsp;&nbsp;</span>GeoNetwork - Continent</a></span></li><li><span><a href="#GeoNetwork---SubContinent" data-toc-modified-id="GeoNetwork---SubContinent-3.12"><span class="toc-item-num">3.12&nbsp;&nbsp;</span>GeoNetwork - SubContinent</a></span></li><li><span><a href="#GeoNetwork---Country" data-toc-modified-id="GeoNetwork---Country-3.13"><span class="toc-item-num">3.13&nbsp;&nbsp;</span>GeoNetwork - Country</a></span></li><li><span><a href="#geoNetwork---City" data-toc-modified-id="geoNetwork---City-3.14"><span class="toc-item-num">3.14&nbsp;&nbsp;</span>geoNetwork - City</a></span></li><li><span><a href="#GeoNetwork---Metro" data-toc-modified-id="GeoNetwork---Metro-3.15"><span class="toc-item-num">3.15&nbsp;&nbsp;</span>GeoNetwork - Metro</a></span></li><li><span><a href="#GeoNetwork---Network-Domain" data-toc-modified-id="GeoNetwork---Network-Domain-3.16"><span class="toc-item-num">3.16&nbsp;&nbsp;</span>GeoNetwork - Network Domain</a></span></li><li><span><a href="#GeoNetwork---Region" data-toc-modified-id="GeoNetwork---Region-3.17"><span class="toc-item-num">3.17&nbsp;&nbsp;</span>GeoNetwork - Region</a></span></li></ul></li><li><span><a href="#Final-DataFrame" data-toc-modified-id="Final-DataFrame-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Final DataFrame</a></span></li><li><span><a href="#Modelling" data-toc-modified-id="Modelling-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Modelling</a></span><ul class="toc-item"><li><span><a href="#Estrategia-de-validación" data-toc-modified-id="Estrategia-de-validación-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Estrategia de validación</a></span></li><li><span><a href="#Prueba-de-algoritmos" data-toc-modified-id="Prueba-de-algoritmos-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Prueba de algoritmos</a></span><ul class="toc-item"><li><span><a href="#Vamos-a-rebalancear-el-DF" data-toc-modified-id="Vamos-a-rebalancear-el-DF-5.2.1"><span class="toc-item-num">5.2.1&nbsp;&nbsp;</span>Vamos a rebalancear el DF</a></span></li><li><span><a href="#Cerramos-el-modelo-con-el-DF-de-validación" data-toc-modified-id="Cerramos-el-modelo-con-el-DF-de-validación-5.2.2"><span class="toc-item-num">5.2.2&nbsp;&nbsp;</span>Cerramos el modelo con el DF de validación</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Google Analytics Customer Revenue

# %% [markdown]
# ## Import Libraries

# %%
import sys
import os 

import numpy as np # Arrays
import pandas as pd # Series and Dataframes

import matplotlib.pyplot as plt 
import seaborn as sns # Advanced Plotting 


pd.options.display.max_rows = 100
plt.style.use('ggplot') # Beautify Plots

# %%
import random
import json 
from pandas.io.json import json_normalize
from scipy import stats
from datetime import datetime
from sklearn import model_selection
import xgboost as xgb
#import lightgbm as lgb

# %%
RANDOM_STATE = 42

# %% [markdown]
# ## Import Data

# %%
## Función de lectura 
columns = ['device', 'geoNetwork', 'totals'] # Columns with json format

p = 0.1 # Fraction of data to use

def json_read(df):
    data_frame = file_dir + df
    
    df = pd.read_csv(data_frame, 
                     converters={column: json.loads for column in columns}, 
                     dtype={'fullVisitorId': 'str'}, 
                     skiprows=lambda i: i>0 and random.random() > p)
    
    for column in columns: 
        column_as_df = json_normalize(df[column]) 
        column_as_df.columns = [f"{column}.{subcolumn}" for subcolumn in column_as_df.columns] 
        df = df.drop(column, axis=1).merge(column_as_df, right_index=True, left_index=True)
        
    print(f"Loaded {os.path.basename(data_frame)}. Shape: {df.shape}")
    return df

# %%
file_dir = ''
file_name = 'GACR_def.csv'

# %%
# %%time
df = json_read(file_name)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   from ipykernel import kernelapp as app
# Loaded GACR_def.csv. Shape: (40303, 42)
# CPU times: user 5.8 s, sys: 329 ms, total: 6.13 s
# Wall time: 6.19 s

# %% [markdown]
# ## EDA

# %%
df.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40303 entries, 0 to 40302
# Columns: 42 entries, Unnamed: 0 to totals.transactionRevenue
# dtypes: bool(1), int64(5), object(36)
# memory usage: 12.6+ MB

# %%
df.head().T
# Out:
#                                                                0  ...                               4
# Unnamed: 0                                                     6  ...                              63
# channelGrouping                                   Organic Search  ...                  Organic Search
# date                                                    20160902  ...                        20160902
# fullVisitorId                                1905672039242460897  ...             0854783508496317255
# sessionId                         1905672039242460897_1472817241  ...  0854783508496317255_1472823316
# socialEngagementType                        Not Socially Engaged  ...            Not Socially Engaged
# visitId                                               1472817241  ...                      1472823316
# visitNumber                                                    1  ...                               5
# visitStartTime                                        1472817241  ...                      1472823316
# device.browser                                            Chrome  ...                          Chrome
# device.browserVersion              not available in demo dataset  ...   not available in demo dataset
# device.browserSize                 not available in demo dataset  ...   not available in demo dataset
# device.operatingSystem                                   Windows  ...                         Android
# device.operatingSystemVersion      not available in demo dataset  ...   not available in demo dataset
# device.isMobile                                            False  ...                            True
# device.mobileDeviceBranding        not available in demo dataset  ...   not available in demo dataset
# device.mobileDeviceModel           not available in demo dataset  ...   not available in demo dataset
# device.mobileInputSelector         not available in demo dataset  ...   not available in demo dataset
# device.mobileDeviceInfo            not available in demo dataset  ...   not available in demo dataset
# device.mobileDeviceMarketingName   not available in demo dataset  ...   not available in demo dataset
# device.flashVersion                not available in demo dataset  ...   not available in demo dataset
# device.language                    not available in demo dataset  ...   not available in demo dataset
# device.screenColors                not available in demo dataset  ...   not available in demo dataset
# device.screenResolution            not available in demo dataset  ...   not available in demo dataset
# device.deviceCategory                                    desktop  ...                          tablet
# geoNetwork.continent                                        Asia  ...                          Europe
# geoNetwork.subContinent                            Southern Asia  ...                 Northern Europe
# geoNetwork.country                                      Pakistan  ...                  United Kingdom
# geoNetwork.region                  not available in demo dataset  ...   not available in demo dataset
# geoNetwork.metro                   not available in demo dataset  ...   not available in demo dataset
# geoNetwork.city                    not available in demo dataset  ...   not available in demo dataset
# geoNetwork.cityId                  not available in demo dataset  ...   not available in demo dataset
# geoNetwork.networkDomain                         unknown.unknown  ...               btcentralplus.com
# geoNetwork.latitude                not available in demo dataset  ...   not available in demo dataset
# geoNetwork.longitude               not available in demo dataset  ...   not available in demo dataset
# geoNetwork.networkLocation         not available in demo dataset  ...   not available in demo dataset
# totals.visits                                                  1  ...                               1
# totals.hits                                                    1  ...                               1
# totals.pageviews                                               1  ...                               1
# totals.bounces                                                 1  ...                               1
# totals.newVisits                                               1  ...                             NaN
# totals.transactionRevenue                                    NaN  ...                             NaN
#
# [42 rows x 5 columns]

# %%
df.set_index('sessionId', inplace=True)

# %%
df.head(2).T
# Out:
# sessionId                        1905672039242460897_1472817241 7356002680834488802_1472810526
# Unnamed: 0                                                    6                             46
# channelGrouping                                  Organic Search                 Organic Search
# date                                                   20160902                       20160902
# fullVisitorId                               1905672039242460897            7356002680834488802
# socialEngagementType                       Not Socially Engaged           Not Socially Engaged
# visitId                                              1472817241                     1472810526
# visitNumber                                                   1                              2
# visitStartTime                                       1472817241                     1472810526
# device.browser                                           Chrome                         Chrome
# device.browserVersion             not available in demo dataset  not available in demo dataset
# device.browserSize                not available in demo dataset  not available in demo dataset
# device.operatingSystem                                  Windows                        Android
# device.operatingSystemVersion     not available in demo dataset  not available in demo dataset
# device.isMobile                                           False                           True
# device.mobileDeviceBranding       not available in demo dataset  not available in demo dataset
# device.mobileDeviceModel          not available in demo dataset  not available in demo dataset
# device.mobileInputSelector        not available in demo dataset  not available in demo dataset
# device.mobileDeviceInfo           not available in demo dataset  not available in demo dataset
# device.mobileDeviceMarketingName  not available in demo dataset  not available in demo dataset
# device.flashVersion               not available in demo dataset  not available in demo dataset
# device.language                   not available in demo dataset  not available in demo dataset
# device.screenColors               not available in demo dataset  not available in demo dataset
# device.screenResolution           not available in demo dataset  not available in demo dataset
# device.deviceCategory                                   desktop                         mobile
# geoNetwork.continent                                       Asia                         Europe
# geoNetwork.subContinent                           Southern Asia                 Western Europe
# geoNetwork.country                                     Pakistan                         France
# geoNetwork.region                 not available in demo dataset                  Ile-de-France
# geoNetwork.metro                  not available in demo dataset                      (not set)
# geoNetwork.city                   not available in demo dataset                          Paris
# geoNetwork.cityId                 not available in demo dataset  not available in demo dataset
# geoNetwork.networkDomain                        unknown.unknown                unknown.unknown
# geoNetwork.latitude               not available in demo dataset  not available in demo dataset
# geoNetwork.longitude              not available in demo dataset  not available in demo dataset
# geoNetwork.networkLocation        not available in demo dataset  not available in demo dataset
# totals.visits                                                 1                              1
# totals.hits                                                   1                              1
# totals.pageviews                                              1                              1
# totals.bounces                                                1                              1
# totals.newVisits                                              1                            NaN
# totals.transactionRevenue                                   NaN                            NaN

# %%
### Borramos ids
df_ids = ['fullVisitorId', 'visitId']
df.drop(df_ids, axis=1, inplace=True)

# %%
df.describe(include=np.number).T
# Out:
#                   count          mean  ...           75%           max
# Unnamed: 0      40303.0  2.015121e+05  ...  3.016265e+05  4.021490e+05
# date            40303.0  2.016539e+07  ...  2.017041e+07  2.017080e+07
# visitNumber     40303.0  2.260427e+00  ...  1.000000e+00  3.890000e+02
# visitStartTime  40303.0  1.484332e+09  ...  1.491859e+09  1.501657e+09
#
# [4 rows x 8 columns]

# %%
df.describe(exclude=np.number).T
# Out:
#                                   count  ...   freq
# channelGrouping                   40303  ...  16657
# socialEngagementType              40303  ...  40303
# device.browser                    40303  ...  27484
# device.browserVersion             40303  ...  40303
# device.browserSize                40303  ...  40303
# device.operatingSystem            40303  ...  15622
# device.operatingSystemVersion     40303  ...  40303
# device.isMobile                   40303  ...  30046
# device.mobileDeviceBranding       40303  ...  40303
# device.mobileDeviceModel          40303  ...  40303
# device.mobileInputSelector        40303  ...  40303
# device.mobileDeviceInfo           40303  ...  40303
# device.mobileDeviceMarketingName  40303  ...  40303
# device.flashVersion               40303  ...  40303
# device.language                   40303  ...  40303
# device.screenColors               40303  ...  40303
# device.screenResolution           40303  ...  40303
# device.deviceCategory             40303  ...  30041
# geoNetwork.continent              40303  ...  19949
# geoNetwork.subContinent           40303  ...  17140
# geoNetwork.country                40303  ...  15995
# geoNetwork.region                 40303  ...  22236
# geoNetwork.metro                  40303  ...  22236
# geoNetwork.city                   40303  ...  22236
# geoNetwork.cityId                 40303  ...  40303
# geoNetwork.networkDomain          40303  ...  10637
# geoNetwork.latitude               40303  ...  40303
# geoNetwork.longitude              40303  ...  40303
# geoNetwork.networkLocation        40303  ...  40303
# totals.visits                     40303  ...  40303
# totals.hits                       40303  ...  19807
# totals.pageviews                  40298  ...  20072
# totals.bounces                    19986  ...  19986
# totals.newVisits                  31411  ...  31411
# totals.transactionRevenue           507  ...     12
#
# [35 rows x 4 columns]

# %%
# constant_columns = []
# for column in df.columns:
#        constant_columns.append(column)
#    if df[column].nunique() == 1:

# %%
# Eliminar variables sin varianza
constant_columns = [column for column in df.columns if df[column].nunique() == 1]

# %%
constant_columns
# Out:
# ['socialEngagementType',
#  'device.browserVersion',
#  'device.browserSize',
#  'device.operatingSystemVersion',
#  'device.mobileDeviceBranding',
#  'device.mobileDeviceModel',
#  'device.mobileInputSelector',
#  'device.mobileDeviceInfo',
#  'device.mobileDeviceMarketingName',
#  'device.flashVersion',
#  'device.language',
#  'device.screenColors',
#  'device.screenResolution',
#  'geoNetwork.cityId',
#  'geoNetwork.latitude',
#  'geoNetwork.longitude',
#  'geoNetwork.networkLocation',
#  'totals.visits',
#  'totals.bounces',
#  'totals.newVisits']

# %%
df.drop(constant_columns, axis=1, inplace=True)

# %%
df.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 40303 entries, 1905672039242460897_1472817241 to 8210274443353536201_1481499229
# Columns: 19 entries, Unnamed: 0 to totals.transactionRevenue
# dtypes: bool(1), int64(4), object(14)
# memory usage: 5.9+ MB

# %%
df.head(2).T
# Out:
# sessionId                 1905672039242460897_1472817241 7356002680834488802_1472810526
# Unnamed: 0                                             6                             46
# channelGrouping                           Organic Search                 Organic Search
# date                                            20160902                       20160902
# visitNumber                                            1                              2
# visitStartTime                                1472817241                     1472810526
# device.browser                                    Chrome                         Chrome
# device.operatingSystem                           Windows                        Android
# device.isMobile                                    False                           True
# device.deviceCategory                            desktop                         mobile
# geoNetwork.continent                                Asia                         Europe
# geoNetwork.subContinent                    Southern Asia                 Western Europe
# geoNetwork.country                              Pakistan                         France
# geoNetwork.region          not available in demo dataset                  Ile-de-France
# geoNetwork.metro           not available in demo dataset                      (not set)
# geoNetwork.city            not available in demo dataset                          Paris
# geoNetwork.networkDomain                 unknown.unknown                unknown.unknown
# totals.hits                                            1                              1
# totals.pageviews                                       1                              1
# totals.transactionRevenue                            NaN                            NaN

# %%
df_description = df.describe(include='all').T

# %%
df_description.to_excel('df_description.xlsx')

# %% [markdown]
# #### Target Analysis

# %%
TARGET = 'totals.transactionRevenue'

# %%
df[TARGET].describe()
# Out:
# count          507
# unique         373
# top       16990000
# freq            12
# Name: totals.transactionRevenue, dtype: object

# %%
df[TARGET].head()
# Out:
# sessionId
# 1905672039242460897_1472817241    NaN
# 7356002680834488802_1472810526    NaN
# 235246314908319034_1472833608     NaN
# 0808960480137718074_1472804813    NaN
# 0854783508496317255_1472823316    NaN
# Name: totals.transactionRevenue, dtype: object

# %%
df[df[TARGET].notnull()][TARGET].head(20)
# Out:
# sessionId
# 8516473451212465925_1472845932    339030000
# 1881458907401964229_1472849525    103240000
# 62722204677243801_1485456962       30390000
# 0463325773564352787_1485471506     44790000
# 3945894443419413506_1485470612     22970000
# 987390821892515431_1498241858      25000000
# 3508419666243874603_1498242081    300350000
# 5820498420449602355_1498260264     10990000
# 2840155464434051520_1486141246     28780000
# 3346100016851964940_1486148158     27110000
# 0375962687766031488_1470980004     23490000
# 2393197369360097718_1470941484     94490000
# 720843898955413491_1470931572      41450000
# 9494932638513134134_1470944101     30890000
# 1806006534240481243_1497406904     56980000
# 4296109044601139440_1497369312     55990000
# 850560433361022079_1497382779      15990000
# 0057826677844639343_1497366564     17590000
# 9884876722285756468_1497393700     21260000
# 4647847058075406841_1497386554     41180000
# Name: totals.transactionRevenue, dtype: object

# %%
df[TARGET] = df[TARGET].astype(float)

# %%
df[TARGET].describe()
# Out:
# count    5.070000e+02
# mean     1.377560e+08
# std      7.268713e+08
# min      9.000000e+04
# 25%      2.398000e+07
# 50%      4.892000e+07
# 75%      1.007750e+08
# max      1.602375e+10
# Name: totals.transactionRevenue, dtype: float64

# %%
df[TARGET].fillna(0.0, inplace=True)

# %%
df[TARGET].describe()
# Out:
# count    4.030300e+04
# mean     1.732930e+06
# std      8.288044e+07
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      1.602375e+10
# Name: totals.transactionRevenue, dtype: float64

# %%
df[TARGET] = df[TARGET] / 1000000

# %%
df[TARGET].describe()
# Out:
# count    40303.000000
# mean         1.732930
# std         82.880438
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max      16023.750000
# Name: totals.transactionRevenue, dtype: float64

# %%
df[df[TARGET]>0][TARGET].describe()
# Out:
# count      507.000000
# mean       137.755957
# std        726.871321
# min          0.090000
# 25%         23.980000
# 50%         48.920000
# 75%        100.775000
# max      16023.750000
# Name: totals.transactionRevenue, dtype: float64

# %%
df['visitWithTransaction'] = (df[TARGET] > 0).astype(int)

# %%
df.head().T
# Out:
# sessionId                 1905672039242460897_1472817241  ... 0854783508496317255_1472823316
# Unnamed: 0                                             6  ...                             63
# channelGrouping                           Organic Search  ...                 Organic Search
# date                                            20160902  ...                       20160902
# visitNumber                                            1  ...                              5
# visitStartTime                                1472817241  ...                     1472823316
# device.browser                                    Chrome  ...                         Chrome
# device.operatingSystem                           Windows  ...                        Android
# device.isMobile                                    False  ...                           True
# device.deviceCategory                            desktop  ...                         tablet
# geoNetwork.continent                                Asia  ...                         Europe
# geoNetwork.subContinent                    Southern Asia  ...                Northern Europe
# geoNetwork.country                              Pakistan  ...                 United Kingdom
# geoNetwork.region          not available in demo dataset  ...  not available in demo dataset
# geoNetwork.metro           not available in demo dataset  ...  not available in demo dataset
# geoNetwork.city            not available in demo dataset  ...  not available in demo dataset
# geoNetwork.networkDomain                 unknown.unknown  ...              btcentralplus.com
# totals.hits                                            1  ...                              1
# totals.pageviews                                       1  ...                              1
# totals.transactionRevenue                              0  ...                              0
# visitWithTransaction                                   0  ...                              0
#
# [20 rows x 5 columns]

# %%
df['visitWithTransaction'].sum()
# Out:
# 507

# %%
df['visitWithTransaction'].mean() * 100
# Out:
# 1.25797087065479

# %%
print('De las {} visitas, hay {} con compras, lo que significa que el {} por ciento de las visitas tienen compra'.format(
    df['visitWithTransaction'].count(),
    df['visitWithTransaction'].sum(),
    df['visitWithTransaction'].mean() * 100
))
# Out:
# De las 40303 visitas, hay 507 con compras, lo que significa que el 1.25797087065479 por ciento de las visitas tienen compra

# %%
# Distribución de la variable target al completo
plt.figure(figsize=(15, 5))
sns.distplot(
    df[TARGET]
)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Distribución de la variable target al completo
plt.figure(figsize=(15, 5))
sns.distplot(
    df[df['visitWithTransaction'] == 1][TARGET],
    fit = stats.norm
)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df['totals.transactionRevenue'].head()
# Out:
# sessionId
# 1905672039242460897_1472817241    0.0
# 7356002680834488802_1472810526    0.0
# 235246314908319034_1472833608     0.0
# 0808960480137718074_1472804813    0.0
# 0854783508496317255_1472823316    0.0
# Name: totals.transactionRevenue, dtype: float64

# %%
df['totals.transactionRevenueLN'] = df['totals.transactionRevenue'].apply(lambda x: np.log1p(x))

# %%
TARGET_LN = 'totals.transactionRevenueLN'

# %%
# Distribución de la variable target transformada al completo
plt.figure(figsize=(15, 5))
sns.distplot(
    df[df['visitWithTransaction'] == 1][TARGET_LN],
    fit = stats.norm
)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### Device - Device Browser

# %%
df['device.browser'].describe()
# Out:
# count      40303
# unique        25
# top       Chrome
# freq       27484
# Name: device.browser, dtype: object

# %%
top_browsers = df['device.browser'].value_counts().head(5)

# %%
top_browsers
# Out:
# Chrome               27484
# Safari                8516
# Firefox               1665
# Internet Explorer      843
# Edge                   442
# Name: device.browser, dtype: int64

# %%
top_browsers_list = top_browsers.index.to_list()

# %%
top_browsers_list
# Out:
# ['Chrome', 'Safari', 'Firefox', 'Internet Explorer', 'Edge']

# %%
top_browsers_list.append('Others')

# %%
top_browsers_list
# Out:
# ['Chrome', 'Safari', 'Firefox', 'Internet Explorer', 'Edge', 'Others']

# %%
df['device.browser'] = pd.Categorical(df['device.browser'], categories=top_browsers_list)

# %%
df['device.browser'].value_counts(dropna=False)
# Out:
# Chrome               27484
# Safari                8516
# Firefox               1665
# NaN                   1353
# Internet Explorer      843
# Edge                   442
# Others                   0
# Name: device.browser, dtype: int64

# %%
df['device.browser'].fillna('Others', inplace=True)

# %%
df['device.browser'].describe()
# Out:
# count      40303
# unique         6
# top       Chrome
# freq       27484
# Name: device.browser, dtype: object

# %%
df['device.browser'].value_counts(dropna=False)
# Out:
# Chrome               27484
# Safari                8516
# Firefox               1665
# Others                1353
# Internet Explorer      843
# Edge                   442
# Name: device.browser, dtype: int64

# %%
df['device.browser'].value_counts(normalize=True, dropna=False)
# Out:
# Chrome               0.681934
# Safari               0.211299
# Firefox              0.041312
# Others               0.033571
# Internet Explorer    0.020917
# Edge                 0.010967
# Name: device.browser, dtype: float64

# %%
df[df['visitWithTransaction'] == 1].pivot_table(index='device.browser', values=TARGET_LN, aggfunc=[len, np.mean])
# Out:
#                                           len                        mean
#                   totals.transactionRevenueLN totals.transactionRevenueLN
# device.browser
# Chrome                                  466.0                    4.037495
# Safari                                   25.0                    3.583459
# Firefox                                   9.0                    4.271998
# Internet Explorer                         6.0                    3.293580
# Edge                                      1.0                    4.303119

# %%
_results_df = df[df['visitWithTransaction'] == 1].pivot_table(index='device.browser', values=TARGET_LN, aggfunc=[len, np.mean])

# %%
_results_df.columns = ['transactions', 'mean_revenue_ln']

# %%
_results_df.head()
# Out:
#                    transactions  mean_revenue_ln
# device.browser
# Chrome                    466.0         4.037495
# Safari                     25.0         3.583459
# Firefox                     9.0         4.271998
# Internet Explorer           6.0         3.293580
# Edge                        1.0         4.303119

# %%
_results_df['n_rows'] = df['device.browser'].value_counts(dropna=False)

# %%
_results_df.head()
# Out:
#                    transactions  mean_revenue_ln  n_rows
# device.browser
# Chrome                    466.0         4.037495   27484
# Safari                     25.0         3.583459    8516
# Firefox                     9.0         4.271998    1665
# Internet Explorer           6.0         3.293580     843
# Edge                        1.0         4.303119     442

# %%
_results_df['pct_rows'] = df['device.browser'].value_counts(normalize=True, dropna=False)

# %%
_results_df.head()
# Out:
#                    transactions  mean_revenue_ln  n_rows  pct_rows
# device.browser
# Chrome                    466.0         4.037495   27484  0.681934
# Safari                     25.0         3.583459    8516  0.211299
# Firefox                     9.0         4.271998    1665  0.041312
# Internet Explorer           6.0         3.293580     843  0.020917
# Edge                        1.0         4.303119     442  0.010967

# %%
_results_df['pct_transactions'] = _results_df['transactions'] / _results_df['n_rows']

# %%
_results_df.head()
# Out:
#                    transactions  mean_revenue_ln  ...  pct_rows  pct_transactions
# device.browser                                    ...
# Chrome                    466.0         4.037495  ...  0.681934          0.016955
# Safari                     25.0         3.583459  ...  0.211299          0.002936
# Firefox                     9.0         4.271998  ...  0.041312          0.005405
# Internet Explorer           6.0         3.293580  ...  0.020917          0.007117
# Edge                        1.0         4.303119  ...  0.010967          0.002262
#
# [5 rows x 5 columns]

# %%
_results_df = _results_df[['n_rows', 'pct_rows', 'transactions', 'pct_transactions', 'mean_revenue_ln']]

# %%
_results_df
# Out:
#                    n_rows  pct_rows  ...  pct_transactions  mean_revenue_ln
# device.browser                       ...
# Chrome              27484  0.681934  ...          0.016955         4.037495
# Safari               8516  0.211299  ...          0.002936         3.583459
# Firefox              1665  0.041312  ...          0.005405         4.271998
# Internet Explorer     843  0.020917  ...          0.007117         3.293580
# Edge                  442  0.010967  ...          0.002262         4.303119
#
# [5 rows x 5 columns]

# %%
plt.figure(figsize=(15,5))
sns.countplot(
    df['device.browser']
)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(15,5))
sns.boxenplot(
    data = df[df['visitWithTransaction'] == 1], 
    x = 'device.browser',
    y = TARGET_LN
)

# %%
def plot_cat_values(dataframe, column, target_column):
    plt.figure(figsize=(15,8))
    #en una única grafica de 2x1 en el primer slot
    ax1 = plt.subplot(2,1,1)
    ## Graficamos el conteo de cada uno de los valores
    ax1 = sns.countplot(
        dataframe[column],
        order = list(dataframe[column].unique())
    )
    ax2 = plt.subplot(2,1,2) # share ax1 para que me pinte el axis en el mismo orden
    ## Graficamos la distribución del target sólo para aquellos casos con target > 0 (para que no se chafe el BP) 
    ax2 = sns.boxenplot(
        data = dataframe[dataframe[target_column] > 0], 
        x = column,
        y = target_column,
        order = list(dataframe[column].unique())
    )
    plt.show()

# %%
plot_cat_values(df, 'device.browser', TARGET_LN)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
def explore_cat_values(dataframe, column, target_column):
    _results_df = dataframe[dataframe[target_column] > 1].pivot_table(index=column, values=target_column, aggfunc=[len, np.mean])
    _results_df.columns = ['transactions', 'mean_revenue_ln']
    _results_df['n_rows'] = dataframe[column].value_counts(dropna=False)
    _results_df['pct_rows'] = dataframe[column].value_counts(normalize=True, dropna=False)
    _results_df['pct_transactions'] = _results_df['transactions'] / _results_df['n_rows']
    _results_df = _results_df[['n_rows', 'pct_rows', 'transactions', 'pct_transactions', 'mean_revenue_ln']]
    return _results_df

# %%
explore_cat_values(df, 'device.browser', TARGET_LN)
# Out:
#                    n_rows  pct_rows  ...  pct_transactions  mean_revenue_ln
# device.browser                       ...
# Chrome              27484  0.681934  ...          0.016919         4.045993
# Safari               8516  0.211299  ...          0.002936         3.583459
# Firefox              1665  0.041312  ...          0.005405         4.271998
# Internet Explorer     843  0.020917  ...          0.007117         3.293580
# Edge                  442  0.010967  ...          0.002262         4.303119
#
# [5 rows x 5 columns]

# %%
def setOthers(dataframe, column, num_values):
    top_categories = dataframe[column].value_counts().head(num_values)
    top_categories_list = top_categories.index.to_list()
    top_categories_list.append('Others')
    dataframe[column] = pd.Categorical(dataframe[column], categories=top_categories_list)
    return dataframe[column].fillna('Others')

# %% [markdown]
# ### Sistema Operativo

# %%
df['device.operatingSystem'].value_counts()
# Out:
# Windows          15622
# Macintosh        11725
# Android           5376
# iOS               4567
# Linux             1545
# Chrome OS         1183
# (not set)          208
# Windows Phone       50
# Samsung              8
# BlackBerry           7
# Nintendo Wii         4
# Firefox OS           4
# Xbox                 2
# Nintendo WiiU        1
# FreeBSD              1
# Name: device.operatingSystem, dtype: int64

# %%
df['device.operatingSystem'] = setOthers(df, 'device.operatingSystem', 6)

# %%
df['device.operatingSystem'].value_counts()
# Out:
# Windows      15622
# Macintosh    11725
# Android       5376
# iOS           4567
# Linux         1545
# Chrome OS     1183
# Others         285
# Name: device.operatingSystem, dtype: int64

# %%
plot_cat_values(df, 'device.operatingSystem', TARGET_LN)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
explore_cat_values(df, 'device.operatingSystem', TARGET_LN)
# Out:
#                         n_rows  pct_rows  ...  pct_transactions  mean_revenue_ln
# device.operatingSystem                    ...
# Windows                  15622  0.387614  ...          0.006337         4.007600
# Macintosh                11725  0.290921  ...          0.024051         4.087573
# Android                   5376  0.133390  ...          0.003534         3.385781
# iOS                       4567  0.113317  ...          0.003722         3.610976
# Linux                     1545  0.038335  ...          0.027184         3.761441
# Chrome OS                 1183  0.029353  ...          0.039730         4.262570
#
# [6 rows x 5 columns]

# %% [markdown]
# ### Device - Is Mobile

# %%
explore_cat_values(df, 'device.isMobile', TARGET_LN)
# Out:
#                  n_rows  pct_rows  ...  pct_transactions  mean_revenue_ln
# device.isMobile                    ...
# False             30046  0.745503  ...          0.015609         4.060495
# True              10257  0.254497  ...          0.003607         3.489558
#
# [2 rows x 5 columns]

# %% [markdown]
# Se observa que en Desktop se hace compra en un mayor porcentaje de ocasiones y el importe es más alto

# %%
df['device.isMobile'].dtype
# Out:
# dtype('bool')

# %%
df['device.isMobile'] = df['device.isMobile'].astype(int)

# %%
df['device.isMobile'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# ### Device - Category

# %%
explore_cat_values(df, 'device.deviceCategory', TARGET_LN)
# Out:
#                        n_rows  pct_rows  ...  pct_transactions  mean_revenue_ln
# device.deviceCategory                    ...
# desktop                 30041  0.745379  ...          0.015612         4.060495
# mobile                   8951  0.222093  ...          0.003352         3.350242
# tablet                   1311  0.032529  ...          0.005339         4.086627
#
# [3 rows x 5 columns]

# %%
pd.crosstab(df['device.isMobile'], df['device.deviceCategory'])
# Out:
# device.deviceCategory  desktop  mobile  tablet
# device.isMobile
# 0                        30039       7       0
# 1                            2    8944    1311

# %% [markdown]
# ### ChannelGrouping

# %%
explore_cat_values(df, 'channelGrouping', TARGET_LN)
# Out:
#                  n_rows  pct_rows  ...  pct_transactions  mean_revenue_ln
# channelGrouping                    ...
# Direct             6189  0.153562  ...          0.013411         4.299028
# Display             299  0.007419  ...          0.023411         3.674909
# Organic Search    16657  0.413294  ...          0.008765         3.847061
# Paid Search        1170  0.029030  ...          0.017094         3.798118
# Referral           4554  0.112994  ...          0.054238         4.060583
# Social            10757  0.266903  ...          0.000279         3.448280
#
# [6 rows x 5 columns]

# %%
plot_cat_values(df, 'channelGrouping', TARGET_LN)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### Date

# %%
df['date'].describe()
# Out:
# count    4.030300e+04
# mean     2.016539e+07
# std      4.678482e+03
# min      2.016080e+07
# 25%      2.016103e+07
# 50%      2.016121e+07
# 75%      2.017041e+07
# max      2.017080e+07
# Name: date, dtype: float64

# %%
df['date'].head()
# Out:
# sessionId
# 1905672039242460897_1472817241    20160902
# 7356002680834488802_1472810526    20160902
# 235246314908319034_1472833608     20160902
# 0808960480137718074_1472804813    20160902
# 0854783508496317255_1472823316    20160902
# Name: date, dtype: int64

# %%
df['date'] = pd.to_datetime(df['date'], format='%Y%m%d')

# %%
df['date'].head()
# Out:
# sessionId
# 1905672039242460897_1472817241   2016-09-02
# 7356002680834488802_1472810526   2016-09-02
# 235246314908319034_1472833608    2016-09-02
# 0808960480137718074_1472804813   2016-09-02
# 0854783508496317255_1472823316   2016-09-02
# Name: date, dtype: datetime64[ns]

# %%
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month
df['monthDay'] = df['date'].dt.day
df['weekDay'] = df['date'].dt.weekday
df['quarter'] = df['date'].dt.quarter
df['week'] = df['date'].dt.week
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.

# %%
df.head(5).T
# Out:
# sessionId                   1905672039242460897_1472817241  ... 0854783508496317255_1472823316
# Unnamed: 0                                               6  ...                             63
# channelGrouping                             Organic Search  ...                 Organic Search
# date                                   2016-09-02 00:00:00  ...            2016-09-02 00:00:00
# visitNumber                                              1  ...                              5
# visitStartTime                                  1472817241  ...                     1472823316
# device.browser                                      Chrome  ...                         Chrome
# device.operatingSystem                             Windows  ...                        Android
# device.isMobile                                          0  ...                              1
# device.deviceCategory                              desktop  ...                         tablet
# geoNetwork.continent                                  Asia  ...                         Europe
# geoNetwork.subContinent                      Southern Asia  ...                Northern Europe
# geoNetwork.country                                Pakistan  ...                 United Kingdom
# geoNetwork.region            not available in demo dataset  ...  not available in demo dataset
# geoNetwork.metro             not available in demo dataset  ...  not available in demo dataset
# geoNetwork.city              not available in demo dataset  ...  not available in demo dataset
# geoNetwork.networkDomain                   unknown.unknown  ...              btcentralplus.com
# totals.hits                                              1  ...                              1
# totals.pageviews                                         1  ...                              1
# totals.transactionRevenue                                0  ...                              0
# visitWithTransaction                                     0  ...                              0
# totals.transactionRevenueLN                              0  ...                              0
# year                                                  2016  ...                           2016
# month                                                    9  ...                              9
# monthDay                                                 2  ...                              2
# weekDay                                                  4  ...                              4
# quarter                                                  3  ...                              3
# week                                                    35  ...                             35
#
# [27 rows x 5 columns]

# %%
df.drop('date', axis=1, inplace=True)

# %% [markdown]
# ### Visit Start Time

# %%
df['visitStartTime'].describe()
# Out:
# count    4.030300e+04
# mean     1.484332e+09
# std      8.674532e+06
# min      1.470208e+09
# 25%      1.477886e+09
# 50%      1.481656e+09
# 75%      1.491859e+09
# max      1.501657e+09
# Name: visitStartTime, dtype: float64

# %%
df['visitStartTime'].head()
# Out:
# sessionId
# 1905672039242460897_1472817241    1472817241
# 7356002680834488802_1472810526    1472810526
# 235246314908319034_1472833608     1472833608
# 0808960480137718074_1472804813    1472804813
# 0854783508496317255_1472823316    1472823316
# Name: visitStartTime, dtype: int64

# %%
df['visitHour'] = df['visitStartTime'].apply(lambda x: datetime.fromtimestamp(x).hour)

# %%
df.head().T
# Out:
# sessionId                   1905672039242460897_1472817241  ... 0854783508496317255_1472823316
# Unnamed: 0                                               6  ...                             63
# channelGrouping                             Organic Search  ...                 Organic Search
# visitNumber                                              1  ...                              5
# visitStartTime                                  1472817241  ...                     1472823316
# device.browser                                      Chrome  ...                         Chrome
# device.operatingSystem                             Windows  ...                        Android
# device.isMobile                                          0  ...                              1
# device.deviceCategory                              desktop  ...                         tablet
# geoNetwork.continent                                  Asia  ...                         Europe
# geoNetwork.subContinent                      Southern Asia  ...                Northern Europe
# geoNetwork.country                                Pakistan  ...                 United Kingdom
# geoNetwork.region            not available in demo dataset  ...  not available in demo dataset
# geoNetwork.metro             not available in demo dataset  ...  not available in demo dataset
# geoNetwork.city              not available in demo dataset  ...  not available in demo dataset
# geoNetwork.networkDomain                   unknown.unknown  ...              btcentralplus.com
# totals.hits                                              1  ...                              1
# totals.pageviews                                         1  ...                              1
# totals.transactionRevenue                                0  ...                              0
# visitWithTransaction                                     0  ...                              0
# totals.transactionRevenueLN                              0  ...                              0
# year                                                  2016  ...                           2016
# month                                                    9  ...                              9
# monthDay                                                 2  ...                              2
# weekDay                                                  4  ...                              4
# quarter                                                  3  ...                              3
# week                                                    35  ...                             35
# visitHour                                               11  ...                             13
#
# [27 rows x 5 columns]

# %%
df.drop('visitStartTime', axis=1, inplace=True)

# %% [markdown]
# ### Visit Number

# %%
df['visitNumber'].head()
# Out:
# sessionId
# 1905672039242460897_1472817241    1
# 7356002680834488802_1472810526    2
# 235246314908319034_1472833608     1
# 0808960480137718074_1472804813    1
# 0854783508496317255_1472823316    5
# Name: visitNumber, dtype: int64

# %%
df['visitNumber'].describe()
# Out:
# count    40303.000000
# mean         2.260427
# std          9.089119
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max        389.000000
# Name: visitNumber, dtype: float64

# %%
plt.figure(figsize=(15,5))
sns.regplot(
    data=df[df['visitWithTransaction'] == 1],
    x='visitNumber',
    y=TARGET_LN
)

# %%
df[['visitNumber', TARGET_LN]].head()
# Out:
#                                 visitNumber  totals.transactionRevenueLN
# sessionId
# 1905672039242460897_1472817241            1                          0.0
# 7356002680834488802_1472810526            2                          0.0
# 235246314908319034_1472833608             1                          0.0
# 0808960480137718074_1472804813            1                          0.0
# 0854783508496317255_1472823316            5                          0.0

# %%
df[['visitNumber', TARGET_LN]].corr()
# Out:
#                              visitNumber  totals.transactionRevenueLN
# visitNumber                     1.000000                     0.016496
# totals.transactionRevenueLN     0.016496                     1.000000

# %%
df['visitNumberLN'] = df['visitNumber'].apply(lambda x: np.log1p(x))

# %%
plt.figure(figsize=(15,5))
sns.regplot(
    data=df[df['visitWithTransaction'] == 1],
    x='visitNumberLN',
    y=TARGET_LN
)

# %%
df[['visitNumberLN', TARGET_LN]].corr()
# Out:
#                              visitNumberLN  totals.transactionRevenueLN
# visitNumberLN                     1.000000                     0.078154
# totals.transactionRevenueLN       0.078154                     1.000000

# %% [markdown]
# ### Hits

# %%
df['totals.hits'].head(5)
# Out:
# sessionId
# 1905672039242460897_1472817241    1
# 7356002680834488802_1472810526    1
# 235246314908319034_1472833608     1
# 0808960480137718074_1472804813    1
# 0854783508496317255_1472823316    1
# Name: totals.hits, dtype: object

# %%
df['totals.hits'].describe()
# Out:
# count     40303
# unique      135
# top           1
# freq      19807
# Name: totals.hits, dtype: object

# %%
df['totals.hits'] = df['totals.hits'].astype(int)

# %%
df['totals.hits'].describe()
# Out:
# count    40303.000000
# mean         4.576384
# std          9.875289
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          4.000000
# max        500.000000
# Name: totals.hits, dtype: float64

# %%
plt.figure(figsize=(15,5))
sns.regplot(
    data=df[df['visitWithTransaction'] == 1],
    x='totals.hits',
    y=TARGET_LN
)

# %%
df['totals.hitsLN'] = df['totals.hits'].apply(lambda x: np.log1p(x))

# %%
plt.figure(figsize=(15,5))
sns.regplot(
    data=df[df['visitWithTransaction'] == 1],
    x='totals.hitsLN',
    y=TARGET_LN
)

# %%
df[['totals.hitsLN', TARGET_LN]].corr()
# Out:
#                              totals.hitsLN  totals.transactionRevenueLN
# totals.hitsLN                     1.000000                     0.302001
# totals.transactionRevenueLN       0.302001                     1.000000

# %%
df.pivot_table(index='totals.hits', values='visitWithTransaction', aggfunc=[len, np.sum, np.mean]).head(30)
# Out:
#                              len                  sum                 mean
#             visitWithTransaction visitWithTransaction visitWithTransaction
# totals.hits
# 1                          19807                    0             0.000000
# 2                           6466                    1             0.000155
# 3                           3141                    0             0.000000
# 4                           1953                    0             0.000000
# 5                           1312                    2             0.001524
# 6                            995                    1             0.001005
# 7                            878                    0             0.000000
# 8                            709                    1             0.001410
# 9                            498                    8             0.016064
# 10                           450                    4             0.008889
# 11                           384                    9             0.023438
# 12                           348                   13             0.037356
# 13                           305                   15             0.049180
# 14                           251                   19             0.075697
# 15                           233                    8             0.034335
# 16                           173                   16             0.092486
# 17                           205                   18             0.087805
# 18                           181                   25             0.138122
# 19                           160                   19             0.118750
# 20                           132                   21             0.159091
# 21                           123                   14             0.113821
# 22                           115                   13             0.113043
# 23                           111                    8             0.072072
# 24                           101                   19             0.188119
# 25                            89                    7             0.078652
# 26                            74                   12             0.162162
# 27                            76                    9             0.118421
# 28                            60                   11             0.183333
# 29                            65                    9             0.138462
# 30                            58                    8             0.137931

# %% [markdown]
# ### PageViews

# %%
df['totals.pageviews'].head(5)
# Out:
# sessionId
# 1905672039242460897_1472817241    1
# 7356002680834488802_1472810526    1
# 235246314908319034_1472833608     1
# 0808960480137718074_1472804813    1
# 0854783508496317255_1472823316    1
# Name: totals.pageviews, dtype: object

# %%
df['totals.pageviews'].fillna(0, inplace=True)

# %%
df['totals.pageviews'] = df['totals.pageviews'].astype(int)

# %%
df['totals.pageviews'].describe()
# Out:
# count    40303.000000
# mean         3.834305
# std          7.181895
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          4.000000
# max        343.000000
# Name: totals.pageviews, dtype: float64

# %%
plt.figure(figsize=(15,5))
sns.regplot(
    data=df[df['visitWithTransaction'] == 1],
    x='totals.pageviews',
    y=TARGET_LN
)

# %%
df['totals.pageviewsLN'] = df['totals.pageviews'].apply(lambda x: np.log1p(x))

# %%
plt.figure(figsize=(15,5))
sns.regplot(
    data=df[df['visitWithTransaction'] == 1],
    x='totals.pageviewsLN',
    y=TARGET_LN
)

# %% [markdown]
# Podemos analizar la correlación entre PV y Hits

# %%
df[['totals.pageviews', 'totals.hits']].corr()
# Out:
#                   totals.pageviews  totals.hits
# totals.pageviews          1.000000     0.984268
# totals.hits               0.984268     1.000000

# %% [markdown]
# ### GeoNetwork - Continent

# %%
explore_cat_values(df, 'geoNetwork.continent', TARGET_LN)
# Out:
#                       n_rows  pct_rows  ...  pct_transactions  mean_revenue_ln
# geoNetwork.continent                    ...
# Americas               19949  0.494976  ...          0.024663         4.007519
# Asia                   10337  0.256482  ...          0.000774         4.424132
# Europe                  8715  0.216237  ...          0.000459         3.511016
# Oceania                  625  0.015508  ...          0.003200         6.174678
#
# [4 rows x 5 columns]

# %%
plot_cat_values(df, 'geoNetwork.continent', TARGET_LN)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### GeoNetwork - SubContinent

# %%
explore_cat_values(df, 'geoNetwork.subContinent', TARGET_LN)
# Out:
#                          n_rows  pct_rows  ...  pct_transactions  mean_revenue_ln
# geoNetwork.subContinent                    ...
# Australasia                 618  0.015334  ...          0.003236         6.174678
# Caribbean                   106  0.002630  ...          0.018868         3.358903
# Central America             723  0.017939  ...          0.002766         4.119878
# Eastern Asia               1918  0.047590  ...          0.001564         3.206214
# Northern America          17140  0.425279  ...          0.028413         4.008840
# Northern Europe            2500  0.062030  ...          0.000800         3.134084
# South America              1980  0.049128  ...          0.000505         4.436752
# Southeast Asia             3995  0.099124  ...          0.000751         5.417070
# Southern Asia              2605  0.064635  ...          0.000384         4.744584
# Western Asia               1758  0.043620  ...          0.000569         4.778619
# Western Europe             2580  0.064015  ...          0.000775         3.887948
#
# [11 rows x 5 columns]

# %% [markdown]
# ### GeoNetwork - Country

# %%
results_by_country = explore_cat_values(df, 'geoNetwork.country', TARGET_LN)

# %%
results_by_country
# Out:
#                     n_rows  pct_rows  ...  pct_transactions  mean_revenue_ln
# geoNetwork.country                    ...
# Australia              523  0.012977  ...          0.003824         6.174678
# Canada                1143  0.028360  ...          0.004374         4.281905
# China                  149  0.003697  ...          0.006711         3.510351
# Germany                901  0.022356  ...          0.001110         3.216874
# India                 2255  0.055951  ...          0.000443         4.744584
# Indonesia              417  0.010347  ...          0.007194         5.417070
# Japan                  816  0.020247  ...          0.001225         3.218476
# Kuwait                  23  0.000571  ...          0.043478         4.778619
# Mexico                 624  0.015483  ...          0.003205         4.119878
# Puerto Rico             38  0.000943  ...          0.052632         3.358903
# South Korea            209  0.005186  ...          0.004785         2.889816
# Switzerland            165  0.004094  ...          0.006061         4.559022
# United Kingdom        1629  0.040419  ...          0.001228         3.134084
# United States        15995  0.396869  ...          0.030134         4.006007
# Venezuela               94  0.002332  ...          0.010638         4.436752
#
# [15 rows x 5 columns]

# %%
last_countries = results_by_country[results_by_country['n_rows'] > 500].sort_values(by='mean_revenue_ln').head().index.to_list()

# %%
last_countries
# Out:
# ['United Kingdom', 'Germany', 'Japan', 'United States', 'Mexico']

# %%
first_countries = results_by_country[results_by_country['n_rows'] > 500].sort_values(by='mean_revenue_ln').tail().index.to_list()

# %%
first_countries
# Out:
# ['United States', 'Mexico', 'Canada', 'India', 'Australia']

# %%
country_list = last_countries + first_countries

# %%
country_list
# Out:
# ['United Kingdom',
#  'Germany',
#  'Japan',
#  'United States',
#  'Mexico',
#  'United States',
#  'Mexico',
#  'Canada',
#  'India',
#  'Australia']

# %%
results_by_category = explore_cat_values(df, 'geoNetwork.country', TARGET_LN)
results_by_category
# Out:
#                     n_rows  pct_rows  ...  pct_transactions  mean_revenue_ln
# geoNetwork.country                    ...
# Australia              523  0.012977  ...          0.003824         6.174678
# Canada                1143  0.028360  ...          0.004374         4.281905
# China                  149  0.003697  ...          0.006711         3.510351
# Germany                901  0.022356  ...          0.001110         3.216874
# India                 2255  0.055951  ...          0.000443         4.744584
# Indonesia              417  0.010347  ...          0.007194         5.417070
# Japan                  816  0.020247  ...          0.001225         3.218476
# Kuwait                  23  0.000571  ...          0.043478         4.778619
# Mexico                 624  0.015483  ...          0.003205         4.119878
# Puerto Rico             38  0.000943  ...          0.052632         3.358903
# South Korea            209  0.005186  ...          0.004785         2.889816
# Switzerland            165  0.004094  ...          0.006061         4.559022
# United Kingdom        1629  0.040419  ...          0.001228         3.134084
# United States        15995  0.396869  ...          0.030134         4.006007
# Venezuela               94  0.002332  ...          0.010638         4.436752
#
# [15 rows x 5 columns]

# %%
last_categories = results_by_category[results_by_category['n_rows'] > 5].sort_values(by='mean_revenue_ln').head(500).index.to_list()
first_categories = results_by_category[results_by_category['n_rows'] > 5].sort_values(by='mean_revenue_ln').tail(500).index.to_list()
top_categories_list = first_categories + last_categories
top_categories_list.append('Others')
top_categories_list
# Out:
# ['South Korea',
#  'United Kingdom',
#  'Germany',
#  'Japan',
#  'Puerto Rico',
#  'China',
#  'United States',
#  'Mexico',
#  'Canada',
#  'Venezuela',
#  'Switzerland',
#  'India',
#  'Kuwait',
#  'Indonesia',
#  'Australia',
#  'South Korea',
#  'United Kingdom',
#  'Germany',
#  'Japan',
#  'Puerto Rico',
#  'China',
#  'United States',
#  'Mexico',
#  'Canada',
#  'Venezuela',
#  'Switzerland',
#  'India',
#  'Kuwait',
#  'Indonesia',
#  'Australia',
#  'Others']

# %%
def setOthersPataNegra(dataframe, column, target_column, num_rows_min, top_n):
    results_by_category = explore_cat_values(dataframe, column, target_column)
    last_categories = results_by_category[results_by_category['n_rows'] > num_rows_min].sort_values(by='mean_revenue_ln').head(top_n).index.to_list()
    first_categories = results_by_category[results_by_category['n_rows'] > num_rows_min].sort_values(by='mean_revenue_ln').tail(top_n).index.to_list()
    top_categories_list = first_categories + last_categories
    top_categories_list.append('Others')
    top_categories_list = list(set(top_categories_list))
    dataframe[column] = pd.Categorical(dataframe[column], categories=top_categories_list)
    return dataframe[column].fillna('Others')

# %%
df['geoNetwork.country'] = setOthersPataNegra(df, 'geoNetwork.country', TARGET_LN, 500, 5)

# %%
df['geoNetwork.country'].value_counts()
# Out:
# Others            16417
# United States     15995
# India              2255
# United Kingdom     1629
# Canada             1143
# Germany             901
# Japan               816
# Mexico              624
# Australia           523
# Name: geoNetwork.country, dtype: int64

# %% [markdown]
# ### geoNetwork - City

# %%
explore_cat_values(df, 'geoNetwork.city', TARGET_LN).sort_values(by='mean_revenue_ln')
# Out:
#                                n_rows  ...  mean_revenue_ln
# geoNetwork.city                        ...
# Pittsburgh                         41  ...         2.964242
# Columbus                           27  ...         3.044046
# Montreal                          119  ...         3.163004
# Fremont                            47  ...         3.201933
# Cupertino                          32  ...         3.257712
# San Diego                          68  ...         3.325275
# London                            565  ...         3.496204
# Kirkland                           71  ...         3.500474
# Kansas City                         5  ...         3.554776
# Houston                           113  ...         3.583241
# San Antonio                        24  ...         3.663049
# Sunnyvale                         634  ...         3.727085
# Dallas                             95  ...         3.813763
# Santa Clara                       152  ...         3.827002
# Omaha                               3  ...         3.840957
# Seattle                           225  ...         3.859094
# not available in demo dataset   22236  ...         3.860872
# Mountain View                    1841  ...         3.876942
# Austin                            166  ...         3.944594
# San Jose                          440  ...         4.054355
# Oakland                            18  ...         4.055777
# Ann Arbor                          84  ...         4.083531
# Cambridge                          68  ...         4.171361
# New York                         1177  ...         4.188483
# Chicago                           328  ...         4.214851
# Jersey City                        16  ...         4.268319
# Palo Alto                         157  ...         4.416493
# San Francisco                     924  ...         4.426542
# Los Angeles                       404  ...         4.504235
# Zurich                             38  ...         4.559022
# Atlanta                           108  ...         4.719956
# Washington                        113  ...         5.006312
# Salem                             108  ...         5.086979
# Toronto                           243  ...         5.445644
# Jakarta                           157  ...         5.608886
# (not set)                        1541  ...         5.638177
# Irvine                             40  ...         5.906914
# Sydney                            207  ...         6.012247
# Melbourne                         102  ...         6.337109
# Phoenix                            17  ...         6.884180
#
# [40 rows x 5 columns]

# %%
df['geoNetwork.city'] = setOthersPataNegra(df, 'geoNetwork.city', TARGET_LN, 100, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 40303 entries, 1905672039242460897_1472817241 to 8210274443353536201_1481499229
# Data columns (total 29 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   40303 non-null  int64
#  1   channelGrouping              40303 non-null  object
#  2   visitNumber                  40303 non-null  int64
#  3   device.browser               40303 non-null  category
#  4   device.operatingSystem       40303 non-null  category
#  5   device.isMobile              40303 non-null  int64
#  6   device.deviceCategory        40303 non-null  object
#  7   geoNetwork.continent         40303 non-null  object
#  8   geoNetwork.subContinent      40303 non-null  object
#  9   geoNetwork.country           40303 non-null  category
#  10  geoNetwork.region            40303 non-null  object
#  11  geoNetwork.metro             40303 non-null  object
#  12  geoNetwork.city              40303 non-null  category
#  13  geoNetwork.networkDomain     40303 non-null  object
#  14  totals.hits                  40303 non-null  int64
#  15  totals.pageviews             40303 non-null  int64
#  16  totals.transactionRevenue    40303 non-null  float64
#  17  visitWithTransaction         40303 non-null  int64
#  18  totals.transactionRevenueLN  40303 non-null  float64
#  19  year                         40303 non-null  int64
#  20  month                        40303 non-null  int64
#  21  monthDay                     40303 non-null  int64
#  22  weekDay                      40303 non-null  int64
#  23  quarter                      40303 non-null  int64
#  24  week                         40303 non-null  int64
#  25  visitHour                    40303 non-null  int64
#  26  visitNumberLN                40303 non-null  float64
#  27  totals.hitsLN                40303 non-null  float64
#  28  totals.pageviewsLN           40303 non-null  float64
# dtypes: category(4), float64(5), int64(13), object(7)
# memory usage: 9.4+ MB

# %% [markdown]
# ### GeoNetwork - Metro

# %%
df['geoNetwork.metro'].head(20)
# Out:
# sessionId
# 1905672039242460897_1472817241        not available in demo dataset
# 7356002680834488802_1472810526                            (not set)
# 235246314908319034_1472833608         not available in demo dataset
# 0808960480137718074_1472804813                            (not set)
# 0854783508496317255_1472823316        not available in demo dataset
# 3746051970600816343_1472843059    San Francisco-Oakland-San Jose CA
# 7995527208647516552_1472853844        not available in demo dataset
# 8722718821870548075_1472844617                            (not set)
# 3841593679668548974_1472836503                            (not set)
# 6933171547971573618_1472806913        not available in demo dataset
# 5343926651166197188_1472812632                            (not set)
# 0949718915643445721_1472831551                    Seattle-Tacoma WA
# 4686876203097568863_1472878975        not available in demo dataset
# 4353570557708747022_1472816331        not available in demo dataset
# 6811313210032101101_1472845508        not available in demo dataset
# 4792547228210569611_1472820383                            (not set)
# 1350700416054916432_1472879649        not available in demo dataset
# 3472600189179522575_1472832088    San Francisco-Oakland-San Jose CA
# 8940336827594180920_1472811766                            (not set)
# 1525494763197473450_1472862958        not available in demo dataset
# Name: geoNetwork.metro, dtype: object

# %%
df['geoNetwork.metro'].describe()
# Out:
# count                             40303
# unique                               68
# top       not available in demo dataset
# freq                              22236
# Name: geoNetwork.metro, dtype: object

# %%
explore_cat_values(df, 'geoNetwork.metro', TARGET_LN)
# Out:
#                                    n_rows  ...  mean_revenue_ln
# geoNetwork.metro                           ...
# (not set)                            9412  ...         5.041415
# Atlanta GA                            110  ...         4.719956
# Austin TX                             166  ...         3.944594
# Boston MA-Manchester NH               106  ...         4.171361
# Chicago IL                            335  ...         4.214851
# Columbus OH                            27  ...         3.044046
# Dallas-Ft. Worth TX                   100  ...         3.813763
# Detroit MI                             88  ...         4.083531
# Houston TX                            113  ...         3.583241
# Kansas City MO                          5  ...         3.554776
# London                                557  ...         3.496204
# Los Angeles CA                        448  ...         4.660088
# New York NY                          1199  ...         4.191856
# Omaha NE                                6  ...         3.840957
# Phoenix AZ                             18  ...         6.884180
# Pittsburgh PA                          41  ...         2.964242
# Roanoke-Lynchburg VA                  108  ...         5.086979
# San Antonio TX                         24  ...         3.663049
# San Diego CA                           70  ...         3.325275
# San Francisco-Oakland-San Jose CA    4386  ...         3.979109
# Seattle-Tacoma WA                     324  ...         3.811278
# Washington DC (Hagerstown MD)         149  ...         5.006312
# not available in demo dataset       22236  ...         3.860872
#
# [23 rows x 5 columns]

# %%
df.drop('geoNetwork.metro', axis=1, inplace=True)

# %% [markdown]
# ### GeoNetwork - Network Domain

# %%
df['geoNetwork.networkDomain'].head()
# Out:
# sessionId
# 1905672039242460897_1472817241      unknown.unknown
# 7356002680834488802_1472810526      unknown.unknown
# 235246314908319034_1472833608                 mm.pl
# 0808960480137718074_1472804813            (not set)
# 0854783508496317255_1472823316    btcentralplus.com
# Name: geoNetwork.networkDomain, dtype: object

# %%
df['geoNetwork.networkDomain'].describe()
# Out:
# count         40303
# unique         4221
# top       (not set)
# freq          10637
# Name: geoNetwork.networkDomain, dtype: object

# %%
df['geoNetwork.networkDomain'].value_counts().head(30)
# Out:
# (not set)                10637
# unknown.unknown           6630
# comcast.net               1212
# rr.com                     679
# ttnet.com.tr               631
# verizon.net                604
# comcastbusiness.net        419
# hinet.net                  332
# 3bb.co.th                  317
# prod-infinitum.com.mx      294
# totbb.net                  271
# virginm.net                271
# vnpt.vn                    264
# cox.net                    263
# btcentralplus.com          254
# att.net                    242
# google.com                 234
# sbcglobal.net              226
# asianet.co.th              223
# optonline.net              203
# rima-tde.net               195
# pldt.net                   179
# t-ipconnect.de             174
# virtua.com.br              166
# airtelbroadband.in         154
# amazonaws.com              153
# qwest.net                  140
# bell.ca                    139
# superonline.net            138
# telecomitalia.it           138
# Name: geoNetwork.networkDomain, dtype: int64

# %%
df['network_net'] = df['geoNetwork.networkDomain'].str.contains('.net', case=False).astype(int)

# %%
df['network_com'] = df['geoNetwork.networkDomain'].str.contains('.com', case=False).astype(int)

# %%
results_by_network = explore_cat_values(df, 'geoNetwork.networkDomain', TARGET_LN)

# %%
results_by_network[results_by_network['n_rows'] > 500]
# Out:
#                           n_rows  pct_rows  ...  pct_transactions  mean_revenue_ln
# geoNetwork.networkDomain                    ...
# (not set)                  10637  0.263926  ...          0.028203         4.021813
# comcast.net                 1212  0.030072  ...          0.035479         4.004821
# rr.com                       679  0.016847  ...          0.017673         3.718490
# unknown.unknown             6630  0.164504  ...          0.003469         3.911396
# verizon.net                  604  0.014986  ...          0.041391         4.324839
#
# [5 rows x 5 columns]

# %%
df['geoNetwork.networkDomain'] = setOthers(df, 'geoNetwork.networkDomain', 10)

# %% [markdown]
# ### GeoNetwork - Region

# %%
df['geoNetwork.region'].head(10)
# Out:
# sessionId
# 1905672039242460897_1472817241    not available in demo dataset
# 7356002680834488802_1472810526                    Ile-de-France
# 235246314908319034_1472833608     not available in demo dataset
# 0808960480137718074_1472804813                    North Holland
# 0854783508496317255_1472823316    not available in demo dataset
# 3746051970600816343_1472843059                       California
# 7995527208647516552_1472853844    not available in demo dataset
# 8722718821870548075_1472844617                        Karnataka
# 3841593679668548974_1472836503                        (not set)
# 6933171547971573618_1472806913    not available in demo dataset
# Name: geoNetwork.region, dtype: object

# %%
df['geoNetwork.region'].describe()
# Out:
# count                             40303
# unique                              276
# top       not available in demo dataset
# freq                              22236
# Name: geoNetwork.region, dtype: object

# %%
df.drop('geoNetwork.region', axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 40303 entries, 1905672039242460897_1472817241 to 8210274443353536201_1481499229
# Data columns (total 29 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   40303 non-null  int64
#  1   channelGrouping              40303 non-null  object
#  2   visitNumber                  40303 non-null  int64
#  3   device.browser               40303 non-null  category
#  4   device.operatingSystem       40303 non-null  category
#  5   device.isMobile              40303 non-null  int64
#  6   device.deviceCategory        40303 non-null  object
#  7   geoNetwork.continent         40303 non-null  object
#  8   geoNetwork.subContinent      40303 non-null  object
#  9   geoNetwork.country           40303 non-null  category
#  10  geoNetwork.city              40303 non-null  category
#  11  geoNetwork.networkDomain     40303 non-null  category
#  12  totals.hits                  40303 non-null  int64
#  13  totals.pageviews             40303 non-null  int64
#  14  totals.transactionRevenue    40303 non-null  float64
#  15  visitWithTransaction         40303 non-null  int64
#  16  totals.transactionRevenueLN  40303 non-null  float64
#  17  year                         40303 non-null  int64
#  18  month                        40303 non-null  int64
#  19  monthDay                     40303 non-null  int64
#  20  weekDay                      40303 non-null  int64
#  21  quarter                      40303 non-null  int64
#  22  week                         40303 non-null  int64
#  23  visitHour                    40303 non-null  int64
#  24  visitNumberLN                40303 non-null  float64
#  25  totals.hitsLN                40303 non-null  float64
#  26  totals.pageviewsLN           40303 non-null  float64
#  27  network_net                  40303 non-null  int64
#  28  network_com                  40303 non-null  int64
# dtypes: category(5), float64(5), int64(15), object(4)
# memory usage: 9.1+ MB

# %%
df.describe(include=np.number).T
# Out:
#                                count  ...            max
# Unnamed: 0                   40303.0  ...  402149.000000
# visitNumber                  40303.0  ...     389.000000
# device.isMobile              40303.0  ...       1.000000
# totals.hits                  40303.0  ...     500.000000
# totals.pageviews             40303.0  ...     343.000000
# totals.transactionRevenue    40303.0  ...   16023.750000
# visitWithTransaction         40303.0  ...       1.000000
# totals.transactionRevenueLN  40303.0  ...       9.681890
# year                         40303.0  ...    2017.000000
# month                        40303.0  ...      12.000000
# monthDay                     40303.0  ...      31.000000
# weekDay                      40303.0  ...       6.000000
# quarter                      40303.0  ...       4.000000
# week                         40303.0  ...      52.000000
# visitHour                    40303.0  ...      23.000000
# visitNumberLN                40303.0  ...       5.966147
# totals.hitsLN                40303.0  ...       6.216606
# totals.pageviewsLN           40303.0  ...       5.840642
# network_net                  40303.0  ...       1.000000
# network_com                  40303.0  ...       1.000000
#
# [20 rows x 8 columns]

# %%
df.describe(exclude=np.number).T
# Out:
#                           count unique                            top   freq
# channelGrouping           40303      8                 Organic Search  16657
# device.browser            40303      6                         Chrome  27484
# device.operatingSystem    40303      7                        Windows  15622
# device.deviceCategory     40303      3                        desktop  30041
# geoNetwork.continent      40303      6                       Americas  19949
# geoNetwork.subContinent   40303     22               Northern America  17140
# geoNetwork.country        40303      9                         Others  16417
# geoNetwork.city           40303     21  not available in demo dataset  22236
# geoNetwork.networkDomain  40303     11                         Others  18548

# %% [markdown]
# ## Final DataFrame

# %%
df.describe(include=np.number).T
# Out:
#                                count  ...            max
# Unnamed: 0                   40303.0  ...  402149.000000
# visitNumber                  40303.0  ...     389.000000
# device.isMobile              40303.0  ...       1.000000
# totals.hits                  40303.0  ...     500.000000
# totals.pageviews             40303.0  ...     343.000000
# totals.transactionRevenue    40303.0  ...   16023.750000
# visitWithTransaction         40303.0  ...       1.000000
# totals.transactionRevenueLN  40303.0  ...       9.681890
# year                         40303.0  ...    2017.000000
# month                        40303.0  ...      12.000000
# monthDay                     40303.0  ...      31.000000
# weekDay                      40303.0  ...       6.000000
# quarter                      40303.0  ...       4.000000
# week                         40303.0  ...      52.000000
# visitHour                    40303.0  ...      23.000000
# visitNumberLN                40303.0  ...       5.966147
# totals.hitsLN                40303.0  ...       6.216606
# totals.pageviewsLN           40303.0  ...       5.840642
# network_net                  40303.0  ...       1.000000
# network_com                  40303.0  ...       1.000000
#
# [20 rows x 8 columns]

# %%
df.describe(exclude=np.number).T
# Out:
#                           count unique                            top   freq
# channelGrouping           40303      8                 Organic Search  16657
# device.browser            40303      6                         Chrome  27484
# device.operatingSystem    40303      7                        Windows  15622
# device.deviceCategory     40303      3                        desktop  30041
# geoNetwork.continent      40303      6                       Americas  19949
# geoNetwork.subContinent   40303     22               Northern America  17140
# geoNetwork.country        40303      9                         Others  16417
# geoNetwork.city           40303     21  not available in demo dataset  22236
# geoNetwork.networkDomain  40303     11                         Others  18548

# %%
def generate_dummies(dataframe, column_name):
    _dummy_dataset = pd.get_dummies(dataframe[column_name], prefix=column_name)
    dataframe = pd.concat([dataframe, _dummy_dataset], axis=1)
    return dataframe.drop(column_name, axis=1)

# %%
for column in df.select_dtypes(exclude=np.number).columns:
    df = generate_dummies(df, column)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 40303 entries, 1905672039242460897_1472817241 to 8210274443353536201_1481499229
# Columns: 113 entries, Unnamed: 0 to geoNetwork.networkDomain_Others
# dtypes: float64(5), int64(15), uint8(93)
# memory usage: 11.3+ MB

# %%
df.describe(include=np.number).T.head(20)
# Out:
#                                count  ...            max
# Unnamed: 0                   40303.0  ...  402149.000000
# visitNumber                  40303.0  ...     389.000000
# device.isMobile              40303.0  ...       1.000000
# totals.hits                  40303.0  ...     500.000000
# totals.pageviews             40303.0  ...     343.000000
# totals.transactionRevenue    40303.0  ...   16023.750000
# visitWithTransaction         40303.0  ...       1.000000
# totals.transactionRevenueLN  40303.0  ...       9.681890
# year                         40303.0  ...    2017.000000
# month                        40303.0  ...      12.000000
# monthDay                     40303.0  ...      31.000000
# weekDay                      40303.0  ...       6.000000
# quarter                      40303.0  ...       4.000000
# week                         40303.0  ...      52.000000
# visitHour                    40303.0  ...      23.000000
# visitNumberLN                40303.0  ...       5.966147
# totals.hitsLN                40303.0  ...       6.216606
# totals.pageviewsLN           40303.0  ...       5.840642
# network_net                  40303.0  ...       1.000000
# network_com                  40303.0  ...       1.000000
#
# [20 rows x 8 columns]

# %% [markdown]
# ## Modelling

# %%
target_linked_features = ['totals.transactionRevenue', 'visitWithTransaction']

# %%
df.drop(target_linked_features, axis=1, inplace=True)

# %% [markdown]
# ### Estrategia de validación

# %%
df.pivot_table(index=['year', 'month'], values=TARGET_LN, aggfunc=len)
# Out:
#             totals.transactionRevenueLN
# year month
# 2016 8                           3497.0
#      9                           3196.0
#      10                          3426.0
#      11                          7438.0
#      12                          4049.0
# 2017 1                           2871.0
#      2                           1935.0
#      3                           2869.0
#      4                           2954.0
#      5                           2722.0
#      6                           3536.0
#      7                           1559.0
#      8                            251.0

# %%
df_val = df[df['year'] * 100 + df['month'] >= 201706]
df_dev = df[df['year'] * 100 + df['month'] < 201706]

# %%
df_val.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5346 entries, 5733439053584724644_1498261962 to 4879467450671130988_1497065381
# Columns: 111 entries, Unnamed: 0 to geoNetwork.networkDomain_Others
# dtypes: float64(4), int64(14), uint8(93)
# memory usage: 1.2+ MB

# %%
df_dev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 34957 entries, 1905672039242460897_1472817241 to 8210274443353536201_1481499229
# Columns: 111 entries, Unnamed: 0 to geoNetwork.networkDomain_Others
# dtypes: float64(4), int64(14), uint8(93)
# memory usage: 8.2+ MB

# %%
df_val_X = df_val.drop(TARGET_LN, axis=1)
df_val_y = df_val[[TARGET_LN]]
df_dev_X = df_dev.drop(TARGET_LN, axis=1)
df_dev_y = df_dev[[TARGET_LN]]

# %%
df_val_X.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5346 entries, 5733439053584724644_1498261962 to 4879467450671130988_1497065381
# Columns: 110 entries, Unnamed: 0 to geoNetwork.networkDomain_Others
# dtypes: float64(3), int64(14), uint8(93)
# memory usage: 1.2+ MB

# %%
df_val_y.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5346 entries, 5733439053584724644_1498261962 to 4879467450671130988_1497065381
# Columns: 1 entries, totals.transactionRevenueLN to totals.transactionRevenueLN
# dtypes: float64(1)
# memory usage: 83.5+ KB

# %%
df_dev_X.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 34957 entries, 1905672039242460897_1472817241 to 8210274443353536201_1481499229
# Columns: 110 entries, Unnamed: 0 to geoNetwork.networkDomain_Others
# dtypes: float64(3), int64(14), uint8(93)
# memory usage: 7.9+ MB

# %%
df_dev_y.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 34957 entries, 1905672039242460897_1472817241 to 8210274443353536201_1481499229
# Columns: 1 entries, totals.transactionRevenueLN to totals.transactionRevenueLN
# dtypes: float64(1)
# memory usage: 546.2+ KB

# %%
X_train, X_test, y_train, y_test = model_selection.train_test_split(
    df_dev_X,
    df_dev_y,
    random_state = RANDOM_STATE,
    test_size = 0.3
)

# %%
X_train.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24469 entries, 2443313901463831564_1476798209 to 8697271777283729320_1480366157
# Columns: 110 entries, Unnamed: 0 to geoNetwork.networkDomain_Others
# dtypes: float64(3), int64(14), uint8(93)
# memory usage: 5.5+ MB

# %%
X_test.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10488 entries, 5786187419312472058_1471852567 to 1750624053471305853_1486972636
# Columns: 110 entries, Unnamed: 0 to geoNetwork.networkDomain_Others
# dtypes: float64(3), int64(14), uint8(93)
# memory usage: 2.4+ MB

# %%
y_train.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24469 entries, 2443313901463831564_1476798209 to 8697271777283729320_1480366157
# Columns: 1 entries, totals.transactionRevenueLN to totals.transactionRevenueLN
# dtypes: float64(1)
# memory usage: 382.3+ KB

# %%
y_test.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10488 entries, 5786187419312472058_1471852567 to 1750624053471305853_1486972636
# Columns: 1 entries, totals.transactionRevenueLN to totals.transactionRevenueLN
# dtypes: float64(1)
# memory usage: 163.9+ KB

# %% [markdown]
# ### Prueba de algoritmos

# %%
first_model = xgb.XGBRegressor(random_state=42, n_estimators=100, max_depth=4)

# %%
# %%time
first_model.fit(X_train, y_train)
# Out:
# [17:20:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# CPU times: user 7.63 s, sys: 36.6 ms, total: 7.67 s
# Wall time: 7.7 s
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=4, min_child_weight=1, missing=None, n_estimators=100,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=42,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=1, verbosity=1)

# %%
test_predictions = pd.DataFrame(first_model.predict(X_test), columns=['Prediction'], index=X_test.index)

# %%
test_predictions.head(10)
# Out:
#                                 Prediction
# sessionId
# 5786187419312472058_1471852567   -0.000189
# 8719550687937429485_1479929068    0.002270
# 1402453490450638458_1486302295    0.000101
# 8526269319164584533_1474028328   -0.000311
# 8280799269632645400_1476786052    0.003316
# 411279272464577816_1477114422    -0.000189
# 3576405167767067016_1494880044   -0.000137
# 659528026112194760_1487252934    -0.001394
# 8094077602187363046_1487354612    0.012345
# 6351583460385700684_1488538442    0.000910

# %%
y_test.head(10)
# Out:
#                                 totals.transactionRevenueLN
# sessionId
# 5786187419312472058_1471852567                          0.0
# 8719550687937429485_1479929068                          0.0
# 1402453490450638458_1486302295                          0.0
# 8526269319164584533_1474028328                          0.0
# 8280799269632645400_1476786052                          0.0
# 411279272464577816_1477114422                           0.0
# 3576405167767067016_1494880044                          0.0
# 659528026112194760_1487252934                           0.0
# 8094077602187363046_1487354612                          0.0
# 6351583460385700684_1488538442                          0.0

# %%
results_df = y_test.join(test_predictions)

# %%
results_df.sort_values(by='totals.transactionRevenueLN', ascending=False).head(19)
# Out:
#                                 totals.transactionRevenueLN  Prediction
# sessionId
# 0951979273858392158_1481132948                     7.125967    1.845259
# 4984366501121503466_1481165808                     6.473042    1.517671
# 213465488216513322_1477497129                      6.160194    3.608261
# 0158994139683228392_1495127188                     6.123698    0.979872
# 2546464604912220860_1485014740                     6.035003    0.000355
# 6933441494397777284_1492932735                     6.012247    1.020928
# 7777403200539516342_1471096525                     5.991615   -0.134523
# 1246382538301098136_1492694315                     5.982802    2.433853
# 4959410280892365122_1495480596                     5.889044    1.676101
# 9941749289816017941_1473720926                     5.867289    1.390305
# 9341891163458549514_1496082862                     5.817438    3.701548
# 6232735730122462618_1471838262                     5.643077    1.270875
# 9377429831454005466_1473975319                     5.638355    0.416267
# 1759779356678951325_1481912077                     5.557986    2.172349
# 8156693537451506265_1484267392                     5.435685    1.712140
# 2402527199731150932_1494908899                     5.431711    0.801511
# 8733651591299904619_1480430000                     5.383761    1.768445
# 6176203092937961614_1490122722                     5.378745    1.214181
# 914489131587654698_1472735370                      5.350151    1.232101

# %%
results_df.columns = ['Target', 'Prediction']

# %%
results_df['error'] = results_df['Target'] - results_df['Prediction']

# %%
results_df.head()
# Out:
#                                 Target  Prediction     error
# sessionId
# 0001076216361964073_1487278251     0.0   -0.000828  0.000828
# 0001363886612345162_1470276486     0.0   -0.000189  0.000189
# 0005964519549395216_1482309072     0.0    0.000224 -0.000224
# 0007043624685291785_1471332508     0.0    0.000224 -0.000224
# 0007485573355537815_1476992170     0.0    0.000192 -0.000192

# %%
results_df['squared_error'] = results_df['error'] ** 2

# %%
results_df['rooted_squared_error'] = np.sqrt(results_df['squared_error'])

# %%
results_df.sort_values(by='Target', ascending=False).head()
# Out:
#                                   Target  ...  rooted_squared_error
# sessionId                                 ...
# 0951979273858392158_1481132948  7.125967  ...              5.280708
# 4984366501121503466_1481165808  6.473042  ...              4.955370
# 213465488216513322_1477497129   6.160194  ...              2.551933
# 0158994139683228392_1495127188  6.123698  ...              5.143826
# 2546464604912220860_1485014740  6.035003  ...              6.034648
#
# [5 rows x 5 columns]

# %%
mse = results_df['squared_error'].mean()
rmse = results_df['rooted_squared_error'].mean()

# %%
print('MSE: {} - RMSE: {}'.format(mse, rmse))
# Out:
# MSE: 0.156186304054147 - RMSE: 0.0738738253208286

# %%
plt.figure(figsize=(15,5))
sns.distplot(
    results_df['rooted_squared_error']
)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(15,5))
sns.distplot(
    results_df[results_df['Target'] > 0]['rooted_squared_error'],
    fit=stats.norm
)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(15,5))
sns.distplot(
    results_df[results_df['Target'] > 0]['Target'],
    fit=stats.norm
)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# #### Vamos a rebalancear el DF

# %%
df_dev_zero = df_dev[df_dev[TARGET_LN] == 0]

# %%
df_dev_nonzero = df_dev[df_dev[TARGET_LN] > 0]

# %%
df_dev_zero.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 34524 entries, 1905672039242460897_1472817241 to 8210274443353536201_1481499229
# Columns: 111 entries, Unnamed: 0 to geoNetwork.networkDomain_Others
# dtypes: float64(4), int64(14), uint8(93)
# memory usage: 8.1+ MB

# %%
df_dev_nonzero.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 433 entries, 8516473451212465925_1472845932 to 8084853554695349186_1481478267
# Columns: 111 entries, Unnamed: 0 to geoNetwork.networkDomain_Others
# dtypes: float64(4), int64(14), uint8(93)
# memory usage: 103.6+ KB

# %%
n_nonzeros = len(df_dev_nonzero) * 3

# %%
n_nonzeros
# Out:
# 1299

# %%
df_dev_zero_sample = df_dev_zero.sample(n = n_nonzeros, random_state = RANDOM_STATE)

# %%
df_dev_zero_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1299 entries, 3603387658834999067_1481231465 to 6441867687196488552_1486115318
# Columns: 111 entries, Unnamed: 0 to geoNetwork.networkDomain_Others
# dtypes: float64(4), int64(14), uint8(93)
# memory usage: 310.8+ KB

# %%
df_dev_sample = pd.concat([df_dev_nonzero, df_dev_zero_sample])

# %%
df_dev_sample.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1732 entries, 8516473451212465925_1472845932 to 6441867687196488552_1486115318
# Columns: 111 entries, Unnamed: 0 to geoNetwork.networkDomain_Others
# dtypes: float64(4), int64(14), uint8(93)
# memory usage: 414.4+ KB

# %%
df_dev_sample_X = df_dev_sample.drop(TARGET_LN, axis=1)
df_dev_sample_y = df_dev_sample[[TARGET_LN]]

# %%
X_train, X_test, y_train, y_test = model_selection.train_test_split(
    df_dev_sample_X,
    df_dev_sample_y,
    random_state = RANDOM_STATE,
    test_size = 0.3
)

# %%
X_train.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1212 entries, 8539076542702897067_1473178025 to 1506009839520505510_1482715988
# Columns: 110 entries, Unnamed: 0 to geoNetwork.networkDomain_Others
# dtypes: float64(3), int64(14), uint8(93)
# memory usage: 280.5+ KB

# %%
y_train.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1212 entries, 8539076542702897067_1473178025 to 1506009839520505510_1482715988
# Columns: 1 entries, totals.transactionRevenueLN to totals.transactionRevenueLN
# dtypes: float64(1)
# memory usage: 18.9+ KB

# %%
X_test.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 520 entries, 4876450605505555762_1473404818 to 084507021854516453_1474029358
# Columns: 110 entries, Unnamed: 0 to geoNetwork.networkDomain_Others
# dtypes: float64(3), int64(14), uint8(93)
# memory usage: 120.4+ KB

# %%
y_test.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 520 entries, 4876450605505555762_1473404818 to 084507021854516453_1474029358
# Columns: 1 entries, totals.transactionRevenueLN to totals.transactionRevenueLN
# dtypes: float64(1)
# memory usage: 8.1+ KB

# %%
resampled_model = xgb.XGBRegressor(max_depth=4, random_state=RANDOM_STATE, n_estimators=100)

# %%
# %%time
resampled_model.fit(X_train, y_train)
# Out:
# [17:20:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# CPU times: user 431 ms, sys: 2.64 ms, total: 434 ms
# Wall time: 438 ms
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=4, min_child_weight=1, missing=None, n_estimators=100,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=42,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=1, verbosity=1)

# %%
test_predictions = pd.DataFrame(resampled_model.predict(X_test), index=X_test.index, columns=['Prediction'])

# %%
results_df = y_test.join(test_predictions)

# %%
results_df.head()
# Out:
#                                 totals.transactionRevenueLN  Prediction
# sessionId
# 4876450605505555762_1473404818                          0.0    0.017916
# 9190322658426486581_1480149883                          0.0    0.030025
# 0403549692769406996_1491245131                          0.0    0.065839
# 2438715352645684298_1494883845                          0.0    0.109626
# 8313034021346257016_1473418958                          0.0    0.016644

# %%
results_df.columns = ['Target', 'Prediction']

# %%
results_df['error'] = results_df['Target'] - results_df['Prediction']
results_df['squared_error'] = results_df['error'] ** 2
results_df['rooted_squared_error'] = np.sqrt(results_df['squared_error'])
mse = results_df['squared_error'].mean()
rmse = results_df['rooted_squared_error'].mean()

# %%
print('MSE: {} - RMSE: {}'.format(mse, rmse))
# Out:
# MSE: 0.8845548639419535 - RMSE: 0.45775447897987737

# %%
plt.figure(figsize=(15,5))
sns.distplot(
    results_df[results_df['Target'] > 0]['rooted_squared_error'],
    fit=stats.norm
)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(15,5))
sns.distplot(
    results_df[results_df['Target'] > 0]['Target'],
    fit=stats.norm
)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
results_df.sort_values(by='Target', ascending=False).head(10)
# Out:
#                                   Target  ...  rooted_squared_error
# sessionId                                 ...
# 5632276788326171571_1474035643  9.681890  ...              4.847052
# 1012363918031449847_1486510446  7.000334  ...              3.179521
# 0389986037860676472_1490980280  6.530601  ...              2.248839
# 1774756696067199606_1483925055  6.327669  ...              2.500069
# 7066946419396410808_1480698423  6.276267  ...              2.751109
# 213465488216513322_1477497129   6.160194  ...              2.001256
# 4959410280892365122_1495480596  5.889044  ...              2.673632
# 9913613662127530897_1486003425  5.704615  ...              0.730751
# 370963443633670703_1470751368   5.642793  ...              2.813067
# 9377429831454005466_1473975319  5.638355  ...              2.057504
#
# [10 rows x 5 columns]

# %% [markdown]
# #### Cerramos el modelo con el DF de validación

# %%
val_predictions = pd.DataFrame(resampled_model.predict(df_val_X), index=df_val_X.index, columns=['Prediction'])

# %%
val_results_df = df_val_y.join(val_predictions)

# %%
val_results_df.head()
# Out:
#                                 totals.transactionRevenueLN  Prediction
# sessionId
# 5733439053584724644_1498261962                          0.0    0.008291
# 5377448900813053936_1498202273                          0.0   -0.011900
# 8465195671786100100_1498229838                          0.0    0.000613
# 3930265983822949492_1498233902                          0.0   -0.000826
# 8749592209550372979_1498229442                          0.0   -0.002821

# %%
val_results_df.columns = ['Target', 'Prediction']

# %%
val_results_df['error'] = val_results_df['Target'] - val_results_df['Prediction']
val_results_df['squared_error'] = val_results_df['error'] ** 2
val_results_df['rooted_squared_error'] = np.sqrt(val_results_df['squared_error'])
mse = val_results_df['squared_error'].mean()
rmse = val_results_df['rooted_squared_error'].mean()

# %%
print('MSE: {} - RMSE: {}'.format(mse, rmse))
# Out:
# MSE: 0.5827699364323793 - RMSE: 0.2568658132495576

# %%
plt.figure(figsize=(15,5))
sns.distplot(
    val_results_df[val_results_df['Target'] > 0]['rooted_squared_error'],
    fit=stats.norm
)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
