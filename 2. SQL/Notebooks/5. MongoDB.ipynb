# %% [markdown]
# <img src="Tarjeta.png">

# %% [markdown]
# # MongoDB
# Este notebook permite entender a nivel básico el funcionamiento de MongoDB y más concretamente, cómo se interacciona con esta base de datos a través de Python.
#
# Para poder hacer uso del mismo es necesario:
#
# 1. Tener instalado MongoDB (https://docs.mongodb.com/manual/installation/)
# 2. Tener activo el servicio de MongoDB

# %% [markdown]
# ## Módulos
# Para poder trabajar con MongoDB, más allá de haber instalado el motor de base de datos en local (localhost), es necesario cargar el módulo de Python que permite interactuar con él. Sería el equivalente de SQLAlchemy que habíamos utilizado en las sesiones de SQL para MySQL.

# %%
# Si no tenemos el módulo de pymongo, lo importamos primero
# !pip3 install pymongo
# Out:
# Requirement already satisfied: pymongo in /Users/nacho/opt/anaconda3/lib/python3.8/site-packages (3.11.3)

# %%
# Importamos las librerías
# Genéricas pandas
import pandas as pd

#Específica de MongoDB MongoClient de pymongo
from pymongo import MongoClient

# %% [markdown]
# ## Conexión con MongoDB
# Una vez tenemos importadas las librerías, podemos realizar la conexión a la base de datos. Para ello y, al igual que hicimos con MySQL, tenemos que crear una cadena de conexión. El formato es similiar, aunque en este caso algo más simple.
#
# - cadena_conexion "mongodb://localhost:27017"
# - y la conexión MongoClient(cadena_conexion)

# %%
# Creamos la cadena de conexión
sCadenaConexion = "mongodb://localhost:27017"
# Instanciamos la conexión
con = MongoClient(sCadenaConexion)

# %% [markdown]
# Una vez definida la conexión (no debería darnos error ya que aquí todavía no estamos conectando, simplemente inicializando), ya podemos empezar a "administrar" la base de datos de MongoDB.
#
# Para ello, primero debemos instanciar el objeto administrador (client.admin) y después ya podemos hacerle consultas, como por ejemplo, el estado del servicio client.admin.command("serverSatus") y mostrarlo por pantalla.
#
# >Nota: si los siguientes comandos tardan en ejecutar, significa que probablemente el servicio de MongoDB en localhost no está activo (net start mongodb). Si el servicio está en marcha, podremos ver el output del estado como un JSON.

# %%
# Asignamos la instancia del objeto administrador o funciones de administrador con.admin
client = con.admin
# Podemos consultar diferentes aspectos del servidor de base de datos, como por ejemplo su estado o configuración del servidor de MongoDB client.command("serverStatus").
status = client.command("serverStatus")
print(status)
# Out:
# cket 3) - 100-249ms': 0, 'file system read latency histogram (bucket 4) - 250-499ms': 0, 'file system read latency histogram (bucket 5) - 500-999ms': 0, 'file system read latency histogram (bucket 6) - 1000ms+': 0, 'file system write latency histogram (bucket 1) - 10-49ms': 8, 'file system write latency histogram (bucket 2) - 50-99ms': 2, 'file system write latency histogram (bucket 3) - 100-249ms': 0, 'file system write latency histogram (bucket 4) - 250-499ms': 0, 'file system write latency histogram (bucket 5) - 500-999ms': 0, 'file system write latency histogram (bucket 6) - 1000ms+': 0, 'operation read latency histogram (bucket 1) - 100-249us': 3, 'operation read latency histogram (bucket 2) - 250-499us': 2, 'operation read latency histogram (bucket 3) - 500-999us': 8, 'operation read latency histogram (bucket 4) - 1000-9999us': 2, 'operation read latency histogram (bucket 5) - 10000us+': 4, 'operation write latency histogram (bucket 1) - 100-249us': 4, 'operation write latency histogram (bucket 2) - 250-499us': 1, 'operation write latency histogram (bucket 3) - 500-999us': 0, 'operation write latency histogram (bucket 4) - 1000-9999us': 2, 'operation write latency histogram (bucket 5) - 10000us+': 0}, 'reconciliation': {'approximate byte size of timestamps in pages written': 0, 'approximate byte size of transaction IDs in pages written': 53928, 'fast-path pages deleted': 0, 'maximum seconds spent in a reconciliation call': 0, 'page reconciliation calls': 11364, 'page reconciliation calls for eviction': 2251, 'page reconciliation calls that resulted in values with prepared transaction metadata': 0, 'page reconciliation calls that resulted in values with timestamps': 0, 'page reconciliation calls that resulted in values with transaction ids': 2248, 'pages deleted': 6756, 'pages written including an aggregated newest start durable timestamp ': 0, 'pages written including an aggregated newest stop durable timestamp ': 0, 'pages written including an aggregated newest stop timestamp ': 0, 'pages written including an aggregated newest stop transaction ID': 0, 'pages written including an aggregated newest transaction ID ': 0, 'pages written including an aggregated oldest start timestamp ': 0, 'pages written including an aggregated prepare': 0, 'pages written including at least one prepare state': 0, 'pages written including at least one start durable timestamp': 0, 'pages written including at least one start timestamp': 0, 'pages written including at least one start transaction ID': 2248, 'pages written including at least one stop durable timestamp': 0, 'pages written including at least one stop timestamp': 0, 'pages written including at least one stop transaction ID': 0, 'records written including a prepare state': 0, 'records written including a start durable timestamp': 0, 'records written including a start timestamp': 0, 'records written including a start transaction ID': 6741, 'records written including a stop durable timestamp': 0, 'records written including a stop timestamp': 0, 'records written including a stop transaction ID': 0, 'split bytes currently awaiting free': 0, 'split objects currently awaiting free': 0}, 'session': {'open session count': 14, 'session query timestamp calls': 0, 'table alter failed calls': 0, 'table alter successful calls': 0, 'table alter unchanged and skipped': 0, 'table compact failed calls': 0, 'table compact successful calls': 0, 'table create failed calls': 0, 'table create successful calls': 1, 'table drop failed calls': 0, 'table drop successful calls': 0, 'table rename failed calls': 0, 'table rename successful calls': 0, 'table salvage failed calls': 0, 'table salvage successful calls': 0, 'table truncate failed calls': 0, 'table truncate successful calls': 0, 'table verify failed calls': 0, 'table verify successful calls': 0}, 'thread-state': {'active filesystem fsync calls': 0, 'active filesystem read calls': 0, 'active filesystem write calls': 0}, 'thread-yield': {'application thre ...

# %% [markdown]
# ## Listar bases de datos
# Si queremos ver qué bases de datos tenemos en nuestra instancia de MongoDB, tenemos que utilzar métodos propios de la librearía de pymongo. Es el equivalente a hacer un "SHOW DATABASES" en SQL, pero en vez de ejecutar una sentencia SQL, aquí lo que hacemos es una llamada al método "list_database_names" de la conexión de MongoClient.

# %%
# consultamos la lista de bases de datos
con.list_database_names()
# Out:
# ['NUCLIO', 'admin', 'config', 'local']

# %% [markdown]
# ## Creación de una base de datos
# Crear una base de datos con pymongo se hace a través de una única y sencilla instrucción:
#
# db = con.[nombre de la bbdd]
#
# >Nota: es importante indicar que la base de datos NO se crea, simplemente se instancia. Con pymongo, la base de datos no se creará hasta que no le insertemos como mínimo un documento.

# %%
# Creamos una nueva base de datos que se llame NUCLIO y la asignamos a una variable
db = con.nuclio2

# %%
con.list_database_names()
# Out:
# ['NUCLIO', 'admin', 'config', 'local']

# %% [markdown]
# ## Crear documentos
# Recordemos que un documento en MongoDB es el equivalente a una fila (registro) de una tabla en MySQL. Aquí empezamos a entender la flexibilidad de MongoDB vs los sistemas relacionales que hemos estado viendo, ya que vamos a crear registros (documentos) de diferentes estructuras en una misma tabla (colección).
#
# A modo de ejemplo, vamos a crear un documento equivalente a un restaurante, un país y una región, con la siguiente información:
#
# Restaurante:
#
# - nombre: KFC
# - barrio: Eixample
# - rating: 4
# - anio_inauguracion: 2019
#
# País:
#
# - nombre: España
# - poblacion: 47000000
#
# Región:
# - id: Europa
# - pais: España
#
#
# Los documentos siguen el formato JSON, un formato universal que permite compartir información entre sistemas de cualquier naturaleza. Los JSON son diccionarios de diccionarios, permitiendo incluir todo tipo de formatos, incluso listas.

# %%
restaurante = {
    "nombre": "KFC", 
    "barrio": "Eixample", 
    "rating": 4, 
    "anio_inauguracion": 2019, 
}

pais = {
   "nombre": "España", 
   "poblacion": 47000000,  
}

region = {
    "id": "Europa", 
    "pais": "España"
}

display(restaurante)
display(pais)
display(region)
# Out:
# {'nombre': 'KFC', 'barrio': 'Eixample', 'rating': 4, 'anio_inauguracion': 2019}
# {'nombre': 'España', 'poblacion': 47000000}
# {'id': 'Europa', 'pais': 'España'}

# %% [markdown]
# Para poder insertar los documentos, es necesario hacerlo en una colección. Al igual que antes, crear una colección es muy sencillo en MongoDB y únicamente requiere de una línea. En este caso, vamos a crear la colección a partir de la instancia de la base de datos, a la vez que insertamos, uno a uno, los documentos antes creados.
#
# Si no insertamos ningún documento, la colección queda como simple instancia, pero no se crea la colección en sí dentro de MongoDB. Tened en cuenta que estamos utilizando un módulo (pymongo) para poder interaccionar con MongoDB.
#
# db.[nombre_coleccion].insert_one(documento)

# %%
# insertamos el restaurante
db.coleccion_prueba.insert_one(restaurante)

# %%
# insertamos el país
db.coleccion_prueba.insert_one(pais)

# %%
# insertamos la región
db.coleccion_prueba.insert_one(region)

# %% [markdown]
# ## Vamos a buscar la información que hemos insertado
# Vamos a buscar dentro de la colección. Para ello, utilizamos el método "find", que es el equivalente al select. Por ahora, no vamos a pasar ningún tipo de filtro al find, con lo que debería retornarnos todos los documentos incluidos en dicha colección.
#
# >Nota: el resultado del método find, debemos convertirlo en una lista para poderlo visualizar y tratar. En sí, es un tipo Cursor, es decir, un punto que apunta a un elmento de memoria. Es por eso, que pare ver el contenido en sí, debemos transformarlo a lista.
#
# db.[nombre_coleccion].find()

# %%
# Hacemos una búsqueda sin filtros (list)
list(db.coleccion_prueba.find())
# Out:
# [{'_id': ObjectId('6075d05e341aba4b1605493d'),
#   'nombre': 'KFC',
#   'barrio': 'Eixample',
#   'rating': 4,
#   'anio_inauguracion': 2019},
#  {'_id': ObjectId('6075d0b0341aba4b1605493e'),
#   'nombre': 'España',
#   'poblacion': 47000000},
#  {'_id': ObjectId('6075d0bf341aba4b1605493f'),
#   'id': 'Europa',
#   'pais': 'España'}]

# %% [markdown]
# Si analizamos el resultado anterior, podemos ver:
#
# 1. Es una lista con un total de 3 elementos [1, 2, 3].
# 2. Cada elemento es un JSON, con la estructura que habíamos definido al realizar el insert.
# 3. Como no hemos definido ninguna clave en nuestros documentos, MongoDB ha creado una para cada uno de ellos (string).

# %% [markdown]
# ## Pongamos en práctica MongoDB a través de un dataset de reviews de restaurantes
# En vez de ir creando documentos de forma aleatoria, vamos a utilizar un dataset preexistente, concretamente el que tenemos en la carpeta ficheros_mongoDB/reviews.csv.
#
# Para ello, vamos a utilizar un dataframe de puente. Con el dataframe, vamos a importar la información del CSV y a partir de ahí vamos a generar los "JSON" de cada fila del Dataframe para que constituya un documento. El JSON, como habíamos dicho, es un equivalente de un diccionario. Del dataframe, pasaremos a diccionario y de ahí a MongoDB.
#
# - De CSV a dataframe
# - De dataframe a diccionario
# > https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.to_dict.html En la documentación podemos encontrar los formatos de generación de diccionarios a partir de un dataframe. Nosotros queremos que el dataframe se convierta en una lista de diccionarios (una lista de documentos), con lo que optaremos por el valor "records" para el parámetro "orient".
# - De diccionario a MongoDB

# %% [markdown]
# ### Importar e insertar

# %%
# Importamos el CSV y mostramos el dataframe dfRatings
dfRatings = pd.read_csv("ficheros_mongoDB/reviews.csv")
dfRatings
# Out:
#                           _id  anio_inauguracion            barrio  \
# 0    5e6587297a4b4ac008f89b79               2016            Gràcia
# 1    5e6587297a4b4ac008f89b7a               2007       Sant Andreu
# 2    5e6587297a4b4ac008f89b7b               2017            Gràcia
# 3    5e6587297a4b4ac008f89b7c               2016  Sants - Montjuïc
# 4    5e6587297a4b4ac008f89b7d               2007       Sant Andreu
# ..                        ...                ...               ...
# 395  5e6587297a4b4ac008f89d04               2020        Nou Barris
# 396  5e6587297a4b4ac008f89d05               2004        Sant Martí
# 397  5e6587297a4b4ac008f89d06               2008       Sant Andreu
# 398  5e6587297a4b4ac008f89d07               2002  Horta - Guinardó
# 399  5e6587297a4b4ac008f89d08               2001            Gràcia
#
#           nombre  rating
# 0            KFC       3
# 1      Pizza Hut       1
# 2     Papa Johns       5
# 3      Telepizza       5
# 4      Telepizza       1
# ..           ...     ...
# 395   Papa Johns       3
# 396  Burger King       5
# 397  Burger King       5
# 398    Pizza Hut       1
# 399    Pizza Hut       1
#
# [400 rows x 5 columns]

# %%
# Convertimos el dataframe en una lista de diccionarios y lo mostramos (lRestuarantes)
lRestaurantes = dfRatings.to_dict(orient="records")
display(lRestaurantes)
# Out:
# [{'_id': '5e6587297a4b4ac008f89b79',
#   'anio_inauguracion': 2016,
#   'barrio': 'Gràcia',
#   'nombre': 'KFC',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89b7a',
#   'anio_inauguracion': 2007,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Pizza Hut',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89b7b',
#   'anio_inauguracion': 2017,
#   'barrio': 'Gràcia',
#   'nombre': 'Papa Johns',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89b7c',
#   'anio_inauguracion': 2016,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'Telepizza',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89b7d',
#   'anio_inauguracion': 2007,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Telepizza',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89b7e',
#   'anio_inauguracion': 2015,
#   'barrio': 'Sant Martí',
#   'nombre': 'McDonalds',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89b7f',
#   'anio_inauguracion': 2000,
#   'barrio': 'Les Corts',
#   'nombre': 'Burger King',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89b80',
#   'anio_inauguracion': 2015,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'McDonalds',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89b81',
#   'anio_inauguracion': 2008,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'KFC',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89b82',
#   'anio_inauguracion': 2012,
#   'barrio': 'Les Corts',
#   'nombre': 'Telepizza',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89b83',
#   'anio_inauguracion': 2004,
#   'barrio': 'Nou Barris',
#   'nombre': 'Telepizza',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89b84',
#   'anio_inauguracion': 2007,
#   'barrio': 'Les Corts',
#   'nombre': 'Papa Johns',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89b85',
#   'anio_inauguracion': 2017,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'KFC',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89b86',
#   'anio_inauguracion': 2020,
#   'barrio': 'Nou Barris',
#   'nombre': 'KFC',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89b87',
#   'anio_inauguracion': 2012,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'Pizza Hut',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89b88',
#   'anio_inauguracion': 2017,
#   'barrio': 'Les Corts',
#   'nombre': 'KFC',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89b89',
#   'anio_inauguracion': 2016,
#   'barrio': 'Nou Barris',
#   'nombre': 'McDonalds',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89b8a',
#   'anio_inauguracion': 2005,
#   'barrio': 'Nou Barris',
#   'nombre': 'Papa Johns',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89b8b',
#   'anio_inauguracion': 2006,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'Telepizza',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89b8c',
#   'anio_inauguracion': 2001,
#   'barrio': 'Les Corts',
#   'nombre': 'Burger King',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89b8d',
#   'anio_inauguracion': 2011,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'Burger King',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89b8e',
#   'anio_inauguracion': 2020,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'McDonalds',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89b8f',
#   'anio_inauguracion': 2007,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Telepizza',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89b90',
#   'anio_inauguracion': 2017,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'KFC',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89b91',
#   'anio_inauguracion': 2018,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Pizza Hut',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89b92',
#   'anio_inauguracion': 2001,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'Papa Johns',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89b93',
#   'anio_inauguracion': 2008,
#   'barrio': 'Sant Martí',
#   'nombre': 'Telepizza',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89b94',
#   'anio_inauguracion': 2017,
#   'barrio': 'Nou Barris',
#   'nombre': 'Pizza Hut',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89b95',
#   'anio_inauguracion': 2017,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'McDonalds',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89b96',
#   'anio_inauguracion': 2017,
#   'barrio': 'Gràcia',
#   'nombre': 'Telepizza',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89b97',
#   'anio_inauguracion': 2009,
#   'barrio': 'Eixample',
#   'nombre': 'Pizza Hut',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89b98',
#   'anio_inauguracion': 2002,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'Burger King',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89b99',
#   'anio_inauguracion': 2005,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'Pizza Hut',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89b9a',
#   'anio_inauguracion': 2005,
#   'barrio': 'Sant Andreu',
#   'nombre': 'McDonalds',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89b9b',
#   'anio_inauguracion': 2009,
#   'barrio': 'Sant Martí',
#   'nombre': 'Pizza Hut',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89b9c',
#   'anio_inauguracion': 2013,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'Papa Johns',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89b9d',
#   'anio_inauguracion': 2008,
#   'barrio': 'Les Corts',
#   'nombre': 'Burger King',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89b9e',
#   'anio_inauguracion': 2015,
#   'barrio': 'Nou Barris',
#   'nombre': 'McDonalds',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89b9f',
#   'anio_inauguracion': 2002,
#   'barrio': 'Sant Andreu',
#   'nombre': 'KFC',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89ba0',
#   'anio_inauguracion': 2013,
#   'barrio': 'Sant Martí',
#   'nombre': 'Pizza Hut',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89ba1',
#   'anio_inauguracion': 2020,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Burger King',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89ba2',
#   'anio_inauguracion': 2004,
#   'barrio': 'Les Corts',
#   'nombre': 'McDonalds',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89ba3',
#   'anio_inauguracion': 2005,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'KFC',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89ba4',
#   'anio_inauguracion': 2003,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'Pizza Hut',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89ba5',
#   'anio_inauguracion': 2016,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'Papa Johns',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89ba6',
#   'anio_inauguracion': 2013,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Telepizza',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89ba7',
#   'anio_inauguracion': 2003,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'Papa Johns',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89ba8',
#   'anio_inauguracion': 2008,
#   'barrio': 'Eixample',
#   'nombre': 'Papa Johns',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89ba9',
#   'anio_inauguracion': 2017,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'Telepizza',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89baa',
#   'anio_inauguracion': 2009,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Pizza Hut',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89bab',
#   'anio_inauguracion': 2014,
#   'barrio': 'Nou Barris',
#   'nombre': 'Pizza Hut',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89bac',
#   'anio_inauguracion': 2017,
#   'barrio': 'Gràcia',
#   'nombre': 'Burger King',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89bad',
#   'anio_inauguracion': 2001,
#   'barrio': 'Nou Barris',
#   'nombre': 'Pizza Hut',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89bae',
#   'anio_inauguracion': 2013,
#   'barrio': 'Les Corts',
#   'nombre': 'Papa Johns',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89baf',
#   'anio_inauguracion': 2010,
#   'barrio': 'Nou Barris',
#   'nombre': 'KFC',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89bb0',
#   'anio_inauguracion': 2005,
#   'barrio': 'Les Corts',
#   'nombre': 'McDonalds',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89bb1',
#   'anio_inauguracion': 2010,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Pizza Hut',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89bb2',
#   'anio_inauguracion': 2018,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'McDonalds',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89bb3',
#   'anio_inauguracion': 2011,
#   'barrio': 'Les Corts',
#   'nombre': 'McDonalds',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89bb4',
#   'anio_inauguracion': 2010,
#   'barrio': 'Les Corts',
#   'nombre': 'Papa Johns',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89bb5',
#   'anio_inauguracion': 2017,
#   'barrio': 'Sant Martí',
#   'nombre': 'Pizza Hut',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89bb6',
#   'anio_inauguracion': 2013,
#   'barrio': 'Gràcia',
#   'nombre': 'Papa Johns',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89bb7',
#   'anio_inauguracion': 2013,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'Pizza Hut',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89bb8',
#   'anio_inauguracion': 2002,
#   'barrio': 'Les Corts',
#   'nombre': 'McDonalds',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89bb9',
#   'anio_inauguracion': 2011,
#   'barrio': 'Gràcia',
#   'nombre': 'KFC',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89bba',
#   'anio_inauguracion': 2006,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'Burger King',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89bbb',
#   'anio_inauguracion': 2018,
#   'barrio': 'Eixample',
#   'nombre': 'Telepizza',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89bbc',
#   'anio_inauguracion': 2001,
#   'barrio': 'Gràcia',
#   'nombre': 'McDonalds',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89bbd',
#   'anio_inauguracion': 2005,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'Papa Johns',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89bbe',
#   'anio_inauguracion': 2001,
#   'barrio': 'Sant Martí',
#   'nombre': 'Burger King',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89bbf',
#   'anio_inauguracion': 2012,
#   'barrio': 'Sant Martí',
#   'nombre': 'KFC',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89bc0',
#   'anio_inauguracion': 2008,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'KFC',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89bc1',
#   'anio_inauguracion': 2010,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'Burger King',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89bc2',
#   'anio_inauguracion': 2012,
#   'barrio': 'Les Corts',
#   'nombre': 'Pizza Hut',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89bc3',
#   'anio_inauguracion': 2002,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'Papa Johns',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89bc4',
#   'anio_inauguracion': 2000,
#   'barrio': 'Nou Barris',
#   'nombre': 'Burger King',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89bc5',
#   'anio_inauguracion': 2000,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'Burger King',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89bc6',
#   'anio_inauguracion': 2017,
#   'barrio': 'Nou Barris',
#   'nombre': 'Burger King',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89bc7',
#   'anio_inauguracion': 2015,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'McDonalds',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89bc8',
#   'anio_inauguracion': 2016,
#   'barrio': 'Sant Andreu',
#   'nombre': 'McDonalds',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89bc9',
#   'anio_inauguracion': 2004,
#   'barrio': 'Nou Barris',
#   'nombre': 'McDonalds',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89bca',
#   'anio_inauguracion': 2003,
#   'barrio': 'Nou Barris',
#   'nombre': 'Pizza Hut',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89bcb',
#   'anio_inauguracion': 2003,
#   'barrio': 'Sant Martí',
#   'nombre': 'Papa Johns',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89bcc',
#   'anio_inauguracion': 2015,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'Burger King',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89bcd',
#   'anio_inauguracion': 2003,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Pizza Hut',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89bce',
#   'anio_inauguracion': 2017,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'Papa Johns',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89bcf',
#   'anio_inauguracion': 2007,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'Telepizza',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89bd0',
#   'anio_inauguracion': 2014,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'Pizza Hut',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89bd1',
#   'anio_inauguracion': 2014,
#   'barrio': 'Les Corts',
#   'nombre': 'Burger King',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89bd2',
#   'anio_inauguracion': 2020,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'KFC',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89bd3',
#   'anio_inauguracion': 2016,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Papa Johns',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89bd4',
#   'anio_inauguracion': 2016,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'Burger King',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89bd5',
#   'anio_inauguracion': 2001,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'Papa Johns',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89bd6',
#   'anio_inauguracion': 2018,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'Telepizza',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89bd7',
#   'anio_inauguracion': 2013,
#   'barrio': 'Les Corts',
#   'nombre': 'KFC',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89bd8',
#   'anio_inauguracion': 2019,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'Pizza Hut',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89bd9',
#   'anio_inauguracion': 2015,
#   'barrio': 'Eixample',
#   'nombre': 'Burger King',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89bda',
#   'anio_inauguracion': 2000,
#   'barrio': 'Sant Andreu',
#   'nombre': 'KFC',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89bdb',
#   'anio_inauguracion': 2002,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'Pizza Hut',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89bdc',
#   'anio_inauguracion': 2000,
#   'barrio': 'Sant Andreu',
#   'nombre': 'KFC',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89bdd',
#   'anio_inauguracion': 2019,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Telepizza',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89bde',
#   'anio_inauguracion': 2000,
#   'barrio': 'Nou Barris',
#   'nombre': 'Telepizza',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89bdf',
#   'anio_inauguracion': 2020,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'KFC',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89be0',
#   'anio_inauguracion': 2013,
#   'barrio': 'Les Corts',
#   'nombre': 'Telepizza',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89be1',
#   'anio_inauguracion': 2011,
#   'barrio': 'Gràcia',
#   'nombre': 'Telepizza',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89be2',
#   'anio_inauguracion': 2006,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'Pizza Hut',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89be3',
#   'anio_inauguracion': 2002,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'KFC',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89be4',
#   'anio_inauguracion': 2018,
#   'barrio': 'Nou Barris',
#   'nombre': 'Pizza Hut',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89be5',
#   'anio_inauguracion': 2002,
#   'barrio': 'Sant Martí',
#   'nombre': 'Telepizza',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89be6',
#   'anio_inauguracion': 2009,
#   'barrio': 'Nou Barris',
#   'nombre': 'McDonalds',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89be7',
#   'anio_inauguracion': 2017,
#   'barrio': 'Sant Martí',
#   'nombre': 'Burger King',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89be8',
#   'anio_inauguracion': 2008,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'Papa Johns',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89be9',
#   'anio_inauguracion': 2005,
#   'barrio': 'Nou Barris',
#   'nombre': 'McDonalds',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89bea',
#   'anio_inauguracion': 2013,
#   'barrio': 'Eixample',
#   'nombre': 'Pizza Hut',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89beb',
#   'anio_inauguracion': 2008,
#   'barrio': 'Nou Barris',
#   'nombre': 'Papa Johns',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89bec',
#   'anio_inauguracion': 2018,
#   'barrio': 'Gràcia',
#   'nombre': 'Pizza Hut',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89bed',
#   'anio_inauguracion': 2011,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'McDonalds',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89bee',
#   'anio_inauguracion': 2005,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'McDonalds',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89bef',
#   'anio_inauguracion': 2018,
#   'barrio': 'Gràcia',
#   'nombre': 'Pizza Hut',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89bf0',
#   'anio_inauguracion': 2004,
#   'barrio': 'Les Corts',
#   'nombre': 'Telepizza',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89bf1',
#   'anio_inauguracion': 2015,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'McDonalds',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89bf2',
#   'anio_inauguracion': 2018,
#   'barrio': 'Sant Andreu',
#   'nombre': 'KFC',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89bf3',
#   'anio_inauguracion': 2004,
#   'barrio': 'Nou Barris',
#   'nombre': 'Papa Johns',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89bf4',
#   'anio_inauguracion': 2014,
#   'barrio': 'Les Corts',
#   'nombre': 'McDonalds',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89bf5',
#   'anio_inauguracion': 2015,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'McDonalds',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89bf6',
#   'anio_inauguracion': 2020,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'Telepizza',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89bf7',
#   'anio_inauguracion': 2005,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Telepizza',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89bf8',
#   'anio_inauguracion': 2014,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'Papa Johns',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89bf9',
#   'anio_inauguracion': 2010,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'Telepizza',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89bfa',
#   'anio_inauguracion': 2010,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'Burger King',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89bfb',
#   'anio_inauguracion': 2011,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'KFC',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89bfc',
#   'anio_inauguracion': 2000,
#   'barrio': 'Nou Barris',
#   'nombre': 'McDonalds',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89bfd',
#   'anio_inauguracion': 2004,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'Telepizza',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89bfe',
#   'anio_inauguracion': 2013,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'Papa Johns',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89bff',
#   'anio_inauguracion': 2000,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'Burger King',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c00',
#   'anio_inauguracion': 2020,
#   'barrio': 'Sant Martí',
#   'nombre': 'KFC',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89c01',
#   'anio_inauguracion': 2002,
#   'barrio': 'Gràcia',
#   'nombre': 'KFC',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89c02',
#   'anio_inauguracion': 2004,
#   'barrio': 'Sant Andreu',
#   'nombre': 'KFC',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89c03',
#   'anio_inauguracion': 2010,
#   'barrio': 'Les Corts',
#   'nombre': 'Papa Johns',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89c04',
#   'anio_inauguracion': 2013,
#   'barrio': 'Les Corts',
#   'nombre': 'KFC',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89c05',
#   'anio_inauguracion': 2006,
#   'barrio': 'Sant Martí',
#   'nombre': 'Papa Johns',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89c06',
#   'anio_inauguracion': 2016,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'Burger King',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89c07',
#   'anio_inauguracion': 2005,
#   'barrio': 'Sant Martí',
#   'nombre': 'Papa Johns',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89c08',
#   'anio_inauguracion': 2001,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'Burger King',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89c09',
#   'anio_inauguracion': 2020,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'Burger King',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89c0a',
#   'anio_inauguracion': 2020,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'McDonalds',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89c0b',
#   'anio_inauguracion': 2013,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'Telepizza',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89c0c',
#   'anio_inauguracion': 2000,
#   'barrio': 'Eixample',
#   'nombre': 'KFC',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89c0d',
#   'anio_inauguracion': 2013,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'Burger King',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89c0e',
#   'anio_inauguracion': 2009,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'Burger King',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89c0f',
#   'anio_inauguracion': 2002,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'KFC',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c10',
#   'anio_inauguracion': 2006,
#   'barrio': 'Sant Martí',
#   'nombre': 'Telepizza',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c11',
#   'anio_inauguracion': 2011,
#   'barrio': 'Nou Barris',
#   'nombre': 'McDonalds',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89c12',
#   'anio_inauguracion': 2008,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'Telepizza',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89c13',
#   'anio_inauguracion': 2018,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'Burger King',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89c14',
#   'anio_inauguracion': 2007,
#   'barrio': 'Sant Martí',
#   'nombre': 'Telepizza',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89c15',
#   'anio_inauguracion': 2020,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Burger King',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89c16',
#   'anio_inauguracion': 2008,
#   'barrio': 'Sant Martí',
#   'nombre': 'Telepizza',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c17',
#   'anio_inauguracion': 2010,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'Pizza Hut',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89c18',
#   'anio_inauguracion': 2019,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'Burger King',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89c19',
#   'anio_inauguracion': 2020,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'Telepizza',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89c1a',
#   'anio_inauguracion': 2018,
#   'barrio': 'Sant Andreu',
#   'nombre': 'McDonalds',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89c1b',
#   'anio_inauguracion': 2009,
#   'barrio': 'Eixample',
#   'nombre': 'McDonalds',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89c1c',
#   'anio_inauguracion': 2014,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Papa Johns',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89c1d',
#   'anio_inauguracion': 2017,
#   'barrio': 'Les Corts',
#   'nombre': 'McDonalds',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89c1e',
#   'anio_inauguracion': 2007,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'Papa Johns',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89c1f',
#   'anio_inauguracion': 2000,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'Pizza Hut',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c20',
#   'anio_inauguracion': 2016,
#   'barrio': 'Les Corts',
#   'nombre': 'KFC',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89c21',
#   'anio_inauguracion': 2015,
#   'barrio': 'Les Corts',
#   'nombre': 'McDonalds',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c22',
#   'anio_inauguracion': 2009,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'KFC',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89c23',
#   'anio_inauguracion': 2008,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'Burger King',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c24',
#   'anio_inauguracion': 2019,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'Telepizza',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89c25',
#   'anio_inauguracion': 2019,
#   'barrio': 'Gràcia',
#   'nombre': 'Burger King',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89c26',
#   'anio_inauguracion': 2000,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'Telepizza',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89c27',
#   'anio_inauguracion': 2017,
#   'barrio': 'Nou Barris',
#   'nombre': 'Papa Johns',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89c28',
#   'anio_inauguracion': 2005,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'McDonalds',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89c29',
#   'anio_inauguracion': 2010,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'Burger King',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89c2a',
#   'anio_inauguracion': 2011,
#   'barrio': 'Eixample',
#   'nombre': 'Papa Johns',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89c2b',
#   'anio_inauguracion': 2018,
#   'barrio': 'Sant Martí',
#   'nombre': 'Pizza Hut',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89c2c',
#   'anio_inauguracion': 2002,
#   'barrio': 'Nou Barris',
#   'nombre': 'Burger King',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89c2d',
#   'anio_inauguracion': 2016,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'Telepizza',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89c2e',
#   'anio_inauguracion': 2012,
#   'barrio': 'Sant Martí',
#   'nombre': 'Telepizza',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89c2f',
#   'anio_inauguracion': 2010,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Pizza Hut',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89c30',
#   'anio_inauguracion': 2017,
#   'barrio': 'Les Corts',
#   'nombre': 'Papa Johns',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89c31',
#   'anio_inauguracion': 2004,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'Pizza Hut',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89c32',
#   'anio_inauguracion': 2015,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'Papa Johns',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89c33',
#   'anio_inauguracion': 2020,
#   'barrio': 'Les Corts',
#   'nombre': 'Telepizza',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89c34',
#   'anio_inauguracion': 2009,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'McDonalds',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89c35',
#   'anio_inauguracion': 2009,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'KFC',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89c36',
#   'anio_inauguracion': 2003,
#   'barrio': 'Sant Martí',
#   'nombre': 'KFC',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89c37',
#   'anio_inauguracion': 2019,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Papa Johns',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89c38',
#   'anio_inauguracion': 2004,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Burger King',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89c39',
#   'anio_inauguracion': 2020,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'Papa Johns',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89c3a',
#   'anio_inauguracion': 2003,
#   'barrio': 'Sant Martí',
#   'nombre': 'McDonalds',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c3b',
#   'anio_inauguracion': 2002,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Pizza Hut',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c3c',
#   'anio_inauguracion': 2014,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'Telepizza',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89c3d',
#   'anio_inauguracion': 2012,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Burger King',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89c3e',
#   'anio_inauguracion': 2001,
#   'barrio': 'Eixample',
#   'nombre': 'Papa Johns',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89c3f',
#   'anio_inauguracion': 2010,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'Pizza Hut',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c40',
#   'anio_inauguracion': 2020,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'Pizza Hut',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89c41',
#   'anio_inauguracion': 2020,
#   'barrio': 'Gràcia',
#   'nombre': 'McDonalds',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c42',
#   'anio_inauguracion': 2011,
#   'barrio': 'Sant Martí',
#   'nombre': 'Pizza Hut',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89c43',
#   'anio_inauguracion': 2004,
#   'barrio': 'Eixample',
#   'nombre': 'Pizza Hut',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c44',
#   'anio_inauguracion': 2003,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'McDonalds',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89c45',
#   'anio_inauguracion': 2014,
#   'barrio': 'Nou Barris',
#   'nombre': 'KFC',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89c46',
#   'anio_inauguracion': 2016,
#   'barrio': 'Sant Martí',
#   'nombre': 'Telepizza',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89c47',
#   'anio_inauguracion': 2009,
#   'barrio': 'Gràcia',
#   'nombre': 'KFC',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c48',
#   'anio_inauguracion': 2017,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'Telepizza',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89c49',
#   'anio_inauguracion': 2005,
#   'barrio': 'Eixample',
#   'nombre': 'McDonalds',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89c4a',
#   'anio_inauguracion': 2012,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'Pizza Hut',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c4b',
#   'anio_inauguracion': 2012,
#   'barrio': 'Sant Andreu',
#   'nombre': 'KFC',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89c4c',
#   'anio_inauguracion': 2002,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'McDonalds',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89c4d',
#   'anio_inauguracion': 2016,
#   'barrio': 'Nou Barris',
#   'nombre': 'Pizza Hut',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89c4e',
#   'anio_inauguracion': 2003,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'McDonalds',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89c4f',
#   'anio_inauguracion': 2011,
#   'barrio': 'Nou Barris',
#   'nombre': 'Telepizza',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89c50',
#   'anio_inauguracion': 2018,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'Papa Johns',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c51',
#   'anio_inauguracion': 2015,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'Telepizza',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89c52',
#   'anio_inauguracion': 2018,
#   'barrio': 'Les Corts',
#   'nombre': 'Burger King',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c53',
#   'anio_inauguracion': 2010,
#   'barrio': 'Eixample',
#   'nombre': 'Telepizza',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89c54',
#   'anio_inauguracion': 2015,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'McDonalds',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c55',
#   'anio_inauguracion': 2012,
#   'barrio': 'Les Corts',
#   'nombre': 'Pizza Hut',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c56',
#   'anio_inauguracion': 2018,
#   'barrio': 'Sant Martí',
#   'nombre': 'Burger King',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c57',
#   'anio_inauguracion': 2016,
#   'barrio': 'Eixample',
#   'nombre': 'Pizza Hut',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89c58',
#   'anio_inauguracion': 2005,
#   'barrio': 'Eixample',
#   'nombre': 'McDonalds',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c59',
#   'anio_inauguracion': 2011,
#   'barrio': 'Nou Barris',
#   'nombre': 'McDonalds',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89c5a',
#   'anio_inauguracion': 2000,
#   'barrio': 'Sant Martí',
#   'nombre': 'KFC',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89c5b',
#   'anio_inauguracion': 2005,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'KFC',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89c5c',
#   'anio_inauguracion': 2005,
#   'barrio': 'Sant Martí',
#   'nombre': 'Pizza Hut',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c5d',
#   'anio_inauguracion': 2006,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'Pizza Hut',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89c5e',
#   'anio_inauguracion': 2003,
#   'barrio': 'Sant Martí',
#   'nombre': 'Telepizza',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89c5f',
#   'anio_inauguracion': 2018,
#   'barrio': 'Eixample',
#   'nombre': 'Burger King',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89c60',
#   'anio_inauguracion': 2005,
#   'barrio': 'Eixample',
#   'nombre': 'Telepizza',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89c61',
#   'anio_inauguracion': 2020,
#   'barrio': 'Gràcia',
#   'nombre': 'Papa Johns',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89c62',
#   'anio_inauguracion': 2017,
#   'barrio': 'Nou Barris',
#   'nombre': 'Papa Johns',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89c63',
#   'anio_inauguracion': 2009,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'McDonalds',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89c64',
#   'anio_inauguracion': 2016,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'Pizza Hut',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89c65',
#   'anio_inauguracion': 2008,
#   'barrio': 'Les Corts',
#   'nombre': 'Pizza Hut',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89c66',
#   'anio_inauguracion': 2004,
#   'barrio': 'Nou Barris',
#   'nombre': 'McDonalds',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89c67',
#   'anio_inauguracion': 2001,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'Telepizza',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89c68',
#   'anio_inauguracion': 2013,
#   'barrio': 'Sant Andreu',
#   'nombre': 'McDonalds',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c69',
#   'anio_inauguracion': 2020,
#   'barrio': 'Sant Martí',
#   'nombre': 'KFC',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89c6a',
#   'anio_inauguracion': 2004,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Burger King',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89c6b',
#   'anio_inauguracion': 2007,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'McDonalds',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89c6c',
#   'anio_inauguracion': 2012,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'Papa Johns',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89c6d',
#   'anio_inauguracion': 2001,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'KFC',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89c6e',
#   'anio_inauguracion': 2015,
#   'barrio': 'Les Corts',
#   'nombre': 'McDonalds',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89c6f',
#   'anio_inauguracion': 2015,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'KFC',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89c70',
#   'anio_inauguracion': 2015,
#   'barrio': 'Sant Martí',
#   'nombre': 'Pizza Hut',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89c71',
#   'anio_inauguracion': 2008,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'Papa Johns',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89c72',
#   'anio_inauguracion': 2003,
#   'barrio': 'Nou Barris',
#   'nombre': 'Pizza Hut',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89c73',
#   'anio_inauguracion': 2010,
#   'barrio': 'Les Corts',
#   'nombre': 'Papa Johns',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89c74',
#   'anio_inauguracion': 2017,
#   'barrio': 'Eixample',
#   'nombre': 'Telepizza',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89c75',
#   'anio_inauguracion': 2000,
#   'barrio': 'Sant Andreu',
#   'nombre': 'KFC',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89c76',
#   'anio_inauguracion': 2003,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Papa Johns',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89c77',
#   'anio_inauguracion': 2008,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'KFC',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89c78',
#   'anio_inauguracion': 2009,
#   'barrio': 'Nou Barris',
#   'nombre': 'McDonalds',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c79',
#   'anio_inauguracion': 2010,
#   'barrio': 'Eixample',
#   'nombre': 'McDonalds',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89c7a',
#   'anio_inauguracion': 2006,
#   'barrio': 'Gràcia',
#   'nombre': 'Pizza Hut',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c7b',
#   'anio_inauguracion': 2020,
#   'barrio': 'Eixample',
#   'nombre': 'McDonalds',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89c7c',
#   'anio_inauguracion': 2010,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'KFC',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89c7d',
#   'anio_inauguracion': 2019,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'Burger King',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89c7e',
#   'anio_inauguracion': 2007,
#   'barrio': 'Eixample',
#   'nombre': 'Papa Johns',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89c7f',
#   'anio_inauguracion': 2009,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Burger King',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c80',
#   'anio_inauguracion': 2012,
#   'barrio': 'Eixample',
#   'nombre': 'Papa Johns',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89c81',
#   'anio_inauguracion': 2013,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'Pizza Hut',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89c82',
#   'anio_inauguracion': 2015,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'McDonalds',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c83',
#   'anio_inauguracion': 2011,
#   'barrio': 'Eixample',
#   'nombre': 'KFC',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89c84',
#   'anio_inauguracion': 2003,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Burger King',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89c85',
#   'anio_inauguracion': 2013,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'Pizza Hut',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89c86',
#   'anio_inauguracion': 2008,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'Telepizza',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89c87',
#   'anio_inauguracion': 2005,
#   'barrio': 'Eixample',
#   'nombre': 'KFC',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89c88',
#   'anio_inauguracion': 2015,
#   'barrio': 'Les Corts',
#   'nombre': 'Telepizza',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89c89',
#   'anio_inauguracion': 2020,
#   'barrio': 'Gràcia',
#   'nombre': 'KFC',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89c8a',
#   'anio_inauguracion': 2017,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'Pizza Hut',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89c8b',
#   'anio_inauguracion': 2004,
#   'barrio': 'Gràcia',
#   'nombre': 'McDonalds',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89c8c',
#   'anio_inauguracion': 2000,
#   'barrio': 'Sant Martí',
#   'nombre': 'Papa Johns',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89c8d',
#   'anio_inauguracion': 2006,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'Telepizza',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89c8e',
#   'anio_inauguracion': 2013,
#   'barrio': 'Sant Martí',
#   'nombre': 'Pizza Hut',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c8f',
#   'anio_inauguracion': 2009,
#   'barrio': 'Eixample',
#   'nombre': 'Pizza Hut',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89c90',
#   'anio_inauguracion': 2018,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'Telepizza',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89c91',
#   'anio_inauguracion': 2015,
#   'barrio': 'Sant Martí',
#   'nombre': 'Pizza Hut',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89c92',
#   'anio_inauguracion': 2008,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'KFC',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89c93',
#   'anio_inauguracion': 2019,
#   'barrio': 'Nou Barris',
#   'nombre': 'McDonalds',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89c94',
#   'anio_inauguracion': 2015,
#   'barrio': 'Eixample',
#   'nombre': 'Telepizza',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c95',
#   'anio_inauguracion': 2005,
#   'barrio': 'Nou Barris',
#   'nombre': 'Papa Johns',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89c96',
#   'anio_inauguracion': 2018,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'Telepizza',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c97',
#   'anio_inauguracion': 2007,
#   'barrio': 'Eixample',
#   'nombre': 'KFC',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c98',
#   'anio_inauguracion': 2017,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Burger King',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89c99',
#   'anio_inauguracion': 2014,
#   'barrio': 'Les Corts',
#   'nombre': 'KFC',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89c9a',
#   'anio_inauguracion': 2015,
#   'barrio': 'Les Corts',
#   'nombre': 'McDonalds',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89c9b',
#   'anio_inauguracion': 2020,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'Telepizza',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89c9c',
#   'anio_inauguracion': 2008,
#   'barrio': 'Gràcia',
#   'nombre': 'Burger King',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89c9d',
#   'anio_inauguracion': 2011,
#   'barrio': 'Eixample',
#   'nombre': 'Burger King',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89c9e',
#   'anio_inauguracion': 2010,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Burger King',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c9f',
#   'anio_inauguracion': 2012,
#   'barrio': 'Eixample',
#   'nombre': 'KFC',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89ca0',
#   'anio_inauguracion': 2008,
#   'barrio': 'Nou Barris',
#   'nombre': 'Pizza Hut',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89ca1',
#   'anio_inauguracion': 2012,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'Pizza Hut',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89ca2',
#   'anio_inauguracion': 2011,
#   'barrio': 'Sant Martí',
#   'nombre': 'Burger King',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89ca3',
#   'anio_inauguracion': 2005,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'Papa Johns',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89ca4',
#   'anio_inauguracion': 2001,
#   'barrio': 'Nou Barris',
#   'nombre': 'Telepizza',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89ca5',
#   'anio_inauguracion': 2003,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Pizza Hut',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89ca6',
#   'anio_inauguracion': 2018,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'Telepizza',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89ca7',
#   'anio_inauguracion': 2016,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Papa Johns',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89ca8',
#   'anio_inauguracion': 2019,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'KFC',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89ca9',
#   'anio_inauguracion': 2013,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'Burger King',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89caa',
#   'anio_inauguracion': 2013,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'KFC',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89cab',
#   'anio_inauguracion': 2005,
#   'barrio': 'Sant Andreu',
#   'nombre': 'KFC',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89cac',
#   'anio_inauguracion': 2001,
#   'barrio': 'Les Corts',
#   'nombre': 'Telepizza',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89cad',
#   'anio_inauguracion': 2004,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'KFC',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89cae',
#   'anio_inauguracion': 2017,
#   'barrio': 'Eixample',
#   'nombre': 'Papa Johns',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89caf',
#   'anio_inauguracion': 2016,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'Papa Johns',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89cb0',
#   'anio_inauguracion': 2016,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'Telepizza',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89cb1',
#   'anio_inauguracion': 2006,
#   'barrio': 'Eixample',
#   'nombre': 'Pizza Hut',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89cb2',
#   'anio_inauguracion': 2003,
#   'barrio': 'Sant Martí',
#   'nombre': 'Burger King',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89cb3',
#   'anio_inauguracion': 2010,
#   'barrio': 'Sant Andreu',
#   'nombre': 'McDonalds',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89cb4',
#   'anio_inauguracion': 2015,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'McDonalds',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89cb5',
#   'anio_inauguracion': 2003,
#   'barrio': 'Les Corts',
#   'nombre': 'Telepizza',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89cb6',
#   'anio_inauguracion': 2003,
#   'barrio': 'Nou Barris',
#   'nombre': 'McDonalds',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89cb7',
#   'anio_inauguracion': 2015,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Pizza Hut',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89cb8',
#   'anio_inauguracion': 2009,
#   'barrio': 'Nou Barris',
#   'nombre': 'Telepizza',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89cb9',
#   'anio_inauguracion': 2012,
#   'barrio': 'Eixample',
#   'nombre': 'Burger King',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89cba',
#   'anio_inauguracion': 2008,
#   'barrio': 'Nou Barris',
#   'nombre': 'KFC',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89cbb',
#   'anio_inauguracion': 2001,
#   'barrio': 'Eixample',
#   'nombre': 'Telepizza',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89cbc',
#   'anio_inauguracion': 2015,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Burger King',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89cbd',
#   'anio_inauguracion': 2017,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'Burger King',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89cbe',
#   'anio_inauguracion': 2011,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'Papa Johns',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89cbf',
#   'anio_inauguracion': 2004,
#   'barrio': 'Les Corts',
#   'nombre': 'Telepizza',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89cc0',
#   'anio_inauguracion': 2005,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'Telepizza',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89cc1',
#   'anio_inauguracion': 2011,
#   'barrio': 'Gràcia',
#   'nombre': 'McDonalds',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89cc2',
#   'anio_inauguracion': 2015,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'Telepizza',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89cc3',
#   'anio_inauguracion': 2004,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'KFC',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89cc4',
#   'anio_inauguracion': 2006,
#   'barrio': 'Gràcia',
#   'nombre': 'Pizza Hut',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89cc5',
#   'anio_inauguracion': 2007,
#   'barrio': 'Les Corts',
#   'nombre': 'KFC',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89cc6',
#   'anio_inauguracion': 2015,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'Burger King',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89cc7',
#   'anio_inauguracion': 2010,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'Pizza Hut',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89cc8',
#   'anio_inauguracion': 2008,
#   'barrio': 'Les Corts',
#   'nombre': 'KFC',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89cc9',
#   'anio_inauguracion': 2017,
#   'barrio': 'Sant Martí',
#   'nombre': 'Burger King',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89cca',
#   'anio_inauguracion': 2020,
#   'barrio': 'Nou Barris',
#   'nombre': 'KFC',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89ccb',
#   'anio_inauguracion': 2005,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'Papa Johns',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89ccc',
#   'anio_inauguracion': 2020,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'Burger King',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89ccd',
#   'anio_inauguracion': 2015,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'Pizza Hut',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89cce',
#   'anio_inauguracion': 2019,
#   'barrio': 'Les Corts',
#   'nombre': 'Papa Johns',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89ccf',
#   'anio_inauguracion': 2002,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Papa Johns',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89cd0',
#   'anio_inauguracion': 2010,
#   'barrio': 'Sant Andreu',
#   'nombre': 'KFC',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89cd1',
#   'anio_inauguracion': 2001,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'Papa Johns',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89cd2',
#   'anio_inauguracion': 2015,
#   'barrio': 'Les Corts',
#   'nombre': 'Burger King',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89cd3',
#   'anio_inauguracion': 2003,
#   'barrio': 'Sant Andreu',
#   'nombre': 'McDonalds',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89cd4',
#   'anio_inauguracion': 2007,
#   'barrio': 'Gràcia',
#   'nombre': 'KFC',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89cd5',
#   'anio_inauguracion': 2019,
#   'barrio': 'Les Corts',
#   'nombre': 'McDonalds',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89cd6',
#   'anio_inauguracion': 2005,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'McDonalds',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89cd7',
#   'anio_inauguracion': 2001,
#   'barrio': 'Sant Martí',
#   'nombre': 'McDonalds',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89cd8',
#   'anio_inauguracion': 2007,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'KFC',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89cd9',
#   'anio_inauguracion': 2015,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'Pizza Hut',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89cda',
#   'anio_inauguracion': 2017,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'Pizza Hut',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89cdb',
#   'anio_inauguracion': 2013,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'McDonalds',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89cdc',
#   'anio_inauguracion': 2003,
#   'barrio': 'Sant Martí',
#   'nombre': 'Pizza Hut',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89cdd',
#   'anio_inauguracion': 2001,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Papa Johns',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89cde',
#   'anio_inauguracion': 2014,
#   'barrio': 'Sant Martí',
#   'nombre': 'Burger King',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89cdf',
#   'anio_inauguracion': 2005,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'Telepizza',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89ce0',
#   'anio_inauguracion': 2015,
#   'barrio': 'Nou Barris',
#   'nombre': 'Burger King',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89ce1',
#   'anio_inauguracion': 2007,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'Papa Johns',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89ce2',
#   'anio_inauguracion': 2015,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'Papa Johns',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89ce3',
#   'anio_inauguracion': 2002,
#   'barrio': 'Sant Martí',
#   'nombre': 'Telepizza',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89ce4',
#   'anio_inauguracion': 2004,
#   'barrio': 'Gràcia',
#   'nombre': 'Telepizza',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89ce5',
#   'anio_inauguracion': 2010,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'KFC',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89ce6',
#   'anio_inauguracion': 2018,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'Burger King',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89ce7',
#   'anio_inauguracion': 2005,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'McDonalds',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89ce8',
#   'anio_inauguracion': 2014,
#   'barrio': 'Les Corts',
#   'nombre': 'Pizza Hut',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89ce9',
#   'anio_inauguracion': 2020,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'Papa Johns',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89cea',
#   'anio_inauguracion': 2001,
#   'barrio': 'Gràcia',
#   'nombre': 'KFC',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89ceb',
#   'anio_inauguracion': 2006,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'Pizza Hut',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89cec',
#   'anio_inauguracion': 2004,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'McDonalds',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89ced',
#   'anio_inauguracion': 2010,
#   'barrio': 'Eixample',
#   'nombre': 'Burger King',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89cee',
#   'anio_inauguracion': 2020,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'Telepizza',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89cef',
#   'anio_inauguracion': 2006,
#   'barrio': 'Sant Martí',
#   'nombre': 'Papa Johns',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89cf0',
#   'anio_inauguracion': 2006,
#   'barrio': 'Gràcia',
#   'nombre': 'Burger King',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89cf1',
#   'anio_inauguracion': 2013,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'Pizza Hut',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89cf2',
#   'anio_inauguracion': 2006,
#   'barrio': 'Eixample',
#   'nombre': 'McDonalds',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89cf3',
#   'anio_inauguracion': 2006,
#   'barrio': 'Les Corts',
#   'nombre': 'Burger King',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89cf4',
#   'anio_inauguracion': 2011,
#   'barrio': 'Eixample',
#   'nombre': 'KFC',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89cf5',
#   'anio_inauguracion': 2015,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'Pizza Hut',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89cf6',
#   'anio_inauguracion': 2016,
#   'barrio': 'Eixample',
#   'nombre': 'Telepizza',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89cf7',
#   'anio_inauguracion': 2010,
#   'barrio': 'Sant Martí',
#   'nombre': 'McDonalds',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89cf8',
#   'anio_inauguracion': 2015,
#   'barrio': 'Nou Barris',
#   'nombre': 'Burger King',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89cf9',
#   'anio_inauguracion': 2001,
#   'barrio': 'Gràcia',
#   'nombre': 'KFC',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89cfa',
#   'anio_inauguracion': 2003,
#   'barrio': 'Gràcia',
#   'nombre': 'Telepizza',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89cfb',
#   'anio_inauguracion': 2014,
#   'barrio': 'Nou Barris',
#   'nombre': 'KFC',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89cfc',
#   'anio_inauguracion': 2012,
#   'barrio': 'Gràcia',
#   'nombre': 'Telepizza',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89cfd',
#   'anio_inauguracion': 2016,
#   'barrio': 'Eixample',
#   'nombre': 'Burger King',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89cfe',
#   'anio_inauguracion': 2000,
#   'barrio': 'Gràcia',
#   'nombre': 'Papa Johns',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89cff',
#   'anio_inauguracion': 2013,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'Telepizza',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89d00',
#   'anio_inauguracion': 2005,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'Pizza Hut',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89d01',
#   'anio_inauguracion': 2005,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'Burger King',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89d02',
#   'anio_inauguracion': 2019,
#   'barrio': 'Gràcia',
#   'nombre': 'KFC',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89d03',
#   'anio_inauguracion': 2018,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'Telepizza',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89d04',
#   'anio_inauguracion': 2020,
#   'barrio': 'Nou Barris',
#   'nombre': 'Papa Johns',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89d05',
#   'anio_inauguracion': 2004,
#   'barrio': 'Sant Martí',
#   'nombre': 'Burger King',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89d06',
#   'anio_inauguracion': 2008,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Burger King',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89d07',
#   'anio_inauguracion': 2002,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'Pizza Hut',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89d08',
#   'anio_inauguracion': 2001,
#   'barrio': 'Gràcia',
#   'nombre': 'Pizza Hut',
#   'rating': 1}]

# %% [markdown]
# Como puede verse en la línea anterior, el método to_dict nos ha generado un listado y dentro de cada elemento (fila) de la lista, aparece un diccionario con los pares clave (columna) -> valor (valor celda).
#
# Es cierto que en este caso la estructura de los diferentes documentos es la misma para todos ellos, pero esto no tiene por qué ser así.

# %% [markdown]
# Ahora ya podemos insertar estos documentos en una colección. Vamos a utilizar una **nueva colección** distinta a la  que hemos utilizado anteriormente. Así mismo, vamos a realizar el insert múltiple de una sola vez. La nueva colección la vamos a denominar "reviews".
#
# db.[nombre_coleccion].insert_many(lista_diccionarios)

# %%
# Insertamos todos los reviews de los restaurantes a través de un único comando
db.coleccion_prueba.insert_many(lRestaurantes)

# %% [markdown]
# **Pregunta:** ¿Cómo haríamos con insert_one para insertar todos los valores?

# %% [markdown]
# ### Contar y consultar sin filtros
#
# Para poder saber cuántos documentos tiene la colección de reviews, podemos utilizar el método "count_documents" dentro de la colección correspondiente. Importante incluir siempre el filtro como parámetro de "count_documents", aunque no haya ninguno. Los filtros (como veremos más adelante), también siguen el formato JSON. Cuando queremos ningún filtro, debemos indicar simplemente {} (json vacío).
#
# Y si queremos ver todos los documentos que existen en la colección, simplemente tenemos que hacer una búsqueda (find) con filtro vacío. Al igual que habíamos hecho con las bases de datos, debemos convertirlo en lista para poder visualizar el contenido de la consulta.
#
# db.nombre_coleccion.count_documents({})

# %%
# Consultamos el número de documentos incluidos en la colección de coleccionRestaurantes.
db.coleccion_prueba.count_documents({})
# Out:
# 403

# %%
# Mostramos todos los documentos contenidos en la colección Reviews db.nombre_coleccion.find({}) como lista
list(db.coleccion_prueba.find({}))
# Out:
#  1},
#  {'_id': '5e6587297a4b4ac008f89c74',
#   'anio_inauguracion': 2017,
#   'barrio': 'Eixample',
#   'nombre': 'Telepizza',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89c75',
#   'anio_inauguracion': 2000,
#   'barrio': 'Sant Andreu',
#   'nombre': 'KFC',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89c76',
#   'anio_inauguracion': 2003,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Papa Johns',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89c77',
#   'anio_inauguracion': 2008,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'KFC',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89c78',
#   'anio_inauguracion': 2009,
#   'barrio': 'Nou Barris',
#   'nombre': 'McDonalds',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c79',
#   'anio_inauguracion': 2010,
#   'barrio': 'Eixample',
#   'nombre': 'McDonalds',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89c7a',
#   'anio_inauguracion': 2006,
#   'barrio': 'Gràcia',
#   'nombre': 'Pizza Hut',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c7b',
#   'anio_inauguracion': 2020,
#   'barrio': 'Eixample',
#   'nombre': 'McDonalds',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89c7c',
#   'anio_inauguracion': 2010,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'KFC',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89c7d',
#   'anio_inauguracion': 2019,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'Burger King',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89c7e',
#   'anio_inauguracion': 2007,
#   'barrio': 'Eixample',
#   'nombre': 'Papa Johns',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89c7f',
#   'anio_inauguracion': 2009,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Burger King',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c80',
#   'anio_inauguracion': 2012,
#   'barrio': 'Eixample',
#   'nombre': 'Papa Johns',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89c81',
#   'anio_inauguracion': 2013,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'Pizza Hut',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89c82',
#   'anio_inauguracion': 2015,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'McDonalds',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c83',
#   'anio_inauguracion': 2011,
#   'barrio': 'Eixample',
#   'nombre': 'KFC',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89c84',
#   'anio_inauguracion': 2003,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Burger King',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89c85',
#   'anio_inauguracion': 2013,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'Pizza Hut',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89c86',
#   'anio_inauguracion': 2008,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'Telepizza',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89c87',
#   'anio_inauguracion': 2005,
#   'barrio': 'Eixample',
#   'nombre': 'KFC',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89c88',
#   'anio_inauguracion': 2015,
#   'barrio': 'Les Corts',
#   'nombre': 'Telepizza',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89c89',
#   'anio_inauguracion': 2020,
#   'barrio': 'Gràcia',
#   'nombre': 'KFC',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89c8a',
#   'anio_inauguracion': 2017,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'Pizza Hut',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89c8b',
#   'anio_inauguracion': 2004,
#   'barrio': 'Gràcia',
#   'nombre': 'McDonalds',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89c8c',
#   'anio_inauguracion': 2000,
#   'barrio': 'Sant Martí',
#   'nombre': 'Papa Johns',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89c8d',
#   'anio_inauguracion': 2006,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'Telepizza',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89c8e',
#   'anio_inauguracion': 2013,
#   'barrio': 'Sant Martí',
#   'nombre': 'Pizza Hut',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c8f',
#   'anio_inauguracion': 2009,
#   'barrio': 'Eixample',
#   'nombre': 'Pizza Hut',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89c90',
#   'anio_inauguracion': 2018,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'Telepizza',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89c91',
#   'anio_inauguracion': 2015,
#   'barrio': 'Sant Martí',
#   'nombre': 'Pizza Hut',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89c92',
#   'anio_inauguracion': 2008,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'KFC',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89c93',
#   'anio_inauguracion': 2019,
#   'barrio': 'Nou Barris',
#   'nombre': 'McDonalds',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89c94',
#   'anio_inauguracion': 2015,
#   'barrio': 'Eixample',
#   'nombre': 'Telepizza',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c95',
#   'anio_inauguracion': 2005,
#   'barrio': 'Nou Barris',
#   'nombre': 'Papa Johns',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89c96',
#   'anio_inauguracion': 2018,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'Telepizza',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c97',
#   'anio_inauguracion': 2007,
#   'barrio': 'Eixample',
#   'nombre': 'KFC',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c98',
#   'anio_inauguracion': 2017,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Burger King',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89c99',
#   'anio_inauguracion': 2014,
#   'barrio': 'Les Corts',
#   'nombre': 'KFC',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89c9a',
#   'anio_inauguracion': 2015,
#   'barrio': 'Les Corts',
#   'nombre': 'McDonalds',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89c9b',
#   'anio_inauguracion': 2020,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'Telepizza',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89c9c',
#   'anio_inauguracion': 2008,
#   'barrio': 'Gràcia',
#   'nombre': 'Burger King',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89c9d',
#   'anio_inauguracion': 2011,
#   'barrio': 'Eixample',
#   'nombre': 'Burger King',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89c9e',
#   'anio_inauguracion': 2010,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Burger King',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c9f',
#   'anio_inauguracion': 2012,
#   'barrio': 'Eixample',
#   'nombre': 'KFC',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89ca0',
#   'anio_inauguracion': 2008,
#   'barrio': 'Nou Barris',
#   'nombre': 'Pizza Hut',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89ca1',
#   'anio_inauguracion': 2012,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'Pizza Hut',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89ca2',
#   'anio_inauguracion': 2011,
#   'barrio': 'Sant Martí',
#   'nombre': 'Burger King',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89ca3',
#   'anio_inauguracion': 2005,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'Papa Johns',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89ca4',
#   'anio_inauguracion': 2001,
#   'barrio': 'Nou Barris',
#   'nombre': 'Telepizza',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89ca5',
#   'anio_inauguracion': 2003,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Pizza Hut',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89ca6',
#   'anio_inauguracion': 2018,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'Telepizza',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89ca7',
#   'anio_inauguracion': 2016,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Papa Johns',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89ca8',
#   'anio_inauguracion': 2019,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'KFC',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89ca9',
#   'anio_inauguracion': 2013,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'Burger King',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89caa',
#   'anio_inauguracion': 2013,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'KFC',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89cab',
#   'anio_inauguracion': 2005,
#   'barrio': 'Sant Andreu',
#   'nombre': 'KFC',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89cac',
#   'anio_inauguracion': 2001,
#   'barrio': 'Les Corts',
#   'nombre': 'Telepizza',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89cad',
#   'anio_inauguracion': 2004,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'KFC',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89cae',
#   'anio_inauguracion': 2017,
#   'barrio': 'Eixample',
#   'nombre': 'Papa Johns',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89caf',
#   'anio_inauguracion': 2016,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'Papa Johns',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89cb0',
#   'anio_inauguracion': 2016,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'Telepizza',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89cb1',
#   'anio_inauguracion': 2006,
#   'barrio': 'Eixample',
#   'nombre': 'Pizza Hut',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89cb2',
#   'anio_inauguracion': 2003,
#   'barrio': 'Sant Martí',
#   'nombre': 'Burger King',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89cb3',
#   'anio_inauguracion': 2010,
#   'barrio': 'Sant Andreu',
#   'nombre': 'McDonalds',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89cb4',
#   'anio_inauguracion': 2015,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'McDonalds',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89cb5',
#   'anio_inauguracion': 2003,
#   'barrio': 'Les Corts',
#   'nombre': 'Telepizza',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89cb6',
#   'anio_inauguracion': 2003,
#   'barrio': 'Nou Barris',
#   'nombre': 'McDonalds',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89cb7',
#   'anio_inauguracion': 2015,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Pizza Hut',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89cb8',
#   'anio_inauguracion': 2009,
#   'barrio': 'Nou Barris',
#   'nombre': 'Telepizza',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89cb9',
#   'anio_inauguracion': 2012,
#   'barrio': 'Eixample',
#   'nombre': 'Burger King',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89cba',
#   'anio_inauguracion': 2008,
#   'barrio': 'Nou Barris',
#   'nombre': 'KFC',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89cbb',
#   'anio_inauguracion': 2001,
#   'barrio': 'Eixample',
#   'nombre': 'Telepizza',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89cbc',
#   'anio_inauguracion': 2015,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Burger King',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89cbd',
#   'anio_inauguracion': 2017,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'Burger King',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89cbe',
#   'anio_inauguracion': 2011,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'Papa Johns',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89cbf',
#   'anio_inauguracion': 2004,
#   'barrio': 'Les Corts',
#   'nombre': 'Telepizza',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89cc0',
#   'anio_inauguracion': 2005,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'Telepizza',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89cc1',
#   'anio_inauguracion': 2011,
#   'barrio': 'Gràcia',
#   'nombre': 'McDonalds',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89cc2',
#   'anio_inauguracion': 2015,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'Telepizza',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89cc3',
#   'anio_inauguracion': 2004,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'KFC',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89cc4',
#   'anio_inauguracion': 2006,
#   'barrio': 'Gràcia',
#   'nombre': 'Pizza Hut',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89cc5',
#   'anio_inauguracion': 2007,
#   'barrio': 'Les Corts',
#   'nombre': 'KFC',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89cc6',
#   'anio_inauguracion': 2015,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'Burger King',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89cc7',
#   'anio_inauguracion': 2010,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'Pizza Hut',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89cc8',
#   'anio_inauguracion': 2008,
#   'barrio': 'Les Corts',
#   'nombre': 'KFC',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89cc9',
#   'anio_inauguracion': 2017,
#   'barrio': 'Sant Martí',
#   'nombre': 'Burger King',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89cca',
#   'anio_inauguracion': 2020,
#   'barrio': 'Nou Barris',
#   'nombre': 'KFC',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89ccb',
#   'anio_inauguracion': 2005,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'Papa Johns',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89ccc',
#   'anio_inauguracion': 2020,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'Burger King',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89ccd',
#   'anio_inauguracion': 2015,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'Pizza Hut',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89cce',
#   'anio_inauguracion': 2019,
#   'barrio': 'Les Corts',
#   'nombre': 'Papa Johns',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89ccf',
#   'anio_inauguracion': 2002,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Papa Johns',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89cd0',
#   'anio_inauguracion': 2010,
#   'barrio': 'Sant Andreu',
#   'nombre': 'KFC',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89cd1',
#   'anio_inauguracion': 2001,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'Papa Johns',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89cd2',
#   'anio_inauguracion': 2015,
#   'barrio': 'Les Corts',
#   'nombre': 'Burger King',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89cd3',
#   'anio_inauguracion': 2003,
#   'barrio': 'Sant Andreu',
#   'nombre': 'McDonalds',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89cd4',
#   'anio_inauguracion': 2007,
#   'barrio': 'Gràcia',
#   'nombre': 'KFC',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89cd5',
#   'anio_inauguracion': 2019,
#   'barrio': 'Les Corts',
#   'nombre': 'McDonalds',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89cd6',
#   'anio_inauguracion': 2005,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'McDonalds',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89cd7',
#   'anio_inauguracion': 2001,
#   'barrio': 'Sant Martí',
#   'nombre': 'McDonalds',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89cd8',
#   'anio_inauguracion': 2007,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'KFC',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89cd9',
#   'anio_inauguracion': 2015,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'Pizza Hut',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89cda',
#   'anio_inauguracion': 2017,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'Pizza Hut',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89cdb',
#   'anio_inauguracion': 2013,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'McDonalds',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89cdc',
#   'anio_inauguracion': 2003,
#   'barrio': 'Sant Martí',
#   'nombre': 'Pizza Hut',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89cdd',
#   'anio_inauguracion': 2001,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Papa Johns',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89cde',
#   'anio_inauguracion': 2014,
#   'barrio': 'Sant Martí',
#   'nombre': 'Burger King',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89cdf',
#   'anio_inauguracion': 2005,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'Telepizza',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89ce0',
#   'anio_inauguracion': 2015,
#   'barrio': 'Nou Barris',
#   'nombre': 'Burger King',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89ce1',
#   'anio_inauguracion': 2007,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'Papa Johns',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89ce2',
#   'anio_inauguracion': 2015,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'Papa Johns',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89ce3',
#   'anio_inauguracion': 2002,
#   'barrio': 'Sant Martí',
#   'nombre': 'Telepizza',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89ce4',
#   'anio_inauguracion': 2004,
#   'barrio': 'Gràcia',
#   'nombre': 'Telepizza',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89ce5',
#   'anio_inauguracion': 2010,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'KFC',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89ce6',
#   'anio_inauguracion': 2018,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'Burger King',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89ce7',
#   'anio_inauguracion': 2005,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'McDonalds',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89ce8',
#   'anio_inauguracion': 2014,
#   'barrio': 'Les Corts',
#   'nombre': 'Pizza Hut',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89ce9',
#   'anio_inauguracion': 2020,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'Papa Johns',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89cea',
#   'anio_inauguracion': 2001,
#   'barrio': 'Gràcia',
#   'nombre': 'KFC',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89ceb',
#   'anio_inauguracion': 2006,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'Pizza Hut',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89cec',
#   'anio_inauguracion': 2004,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'McDonalds',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89ced',
#   'anio_inauguracion': 2010,
#   'barrio': 'Eixample',
#   'nombre': 'Burger King',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89cee',
#   'anio_inauguracion': 2020,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'Telepizza',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89cef',
#   'anio_inauguracion': 2006,
#   'barrio': 'Sant Martí',
#   'nombre': 'Papa Johns',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89cf0',
#   'anio_inauguracion': 2006,
#   'barrio': 'Gràcia',
#   'nombre': 'Burger King',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89cf1',
#   'anio_inauguracion': 2013,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'Pizza Hut',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89cf2',
#   'anio_inauguracion': 2006,
#   'barrio': 'Eixample',
#   'nombre': 'McDonalds',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89cf3',
#   'anio_inauguracion': 2006,
#   'barrio': 'Les Corts',
#   'nombre': 'Burger King',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89cf4',
#   'anio_inauguracion': 2011,
#   'barrio': 'Eixample',
#   'nombre': 'KFC',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89cf5',
#   'anio_inauguracion': 2015,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'Pizza Hut',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89cf6',
#   'anio_inauguracion': 2016,
#   'barrio': 'Eixample',
#   'nombre': 'Telepizza',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89cf7',
#   'anio_inauguracion': 2010,
#   'barrio': 'Sant Martí',
#   'nombre': 'McDonalds',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89cf8',
#   'anio_inauguracion': 2015,
#   'barrio': 'Nou Barris',
#   'nombre': 'Burger King',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89cf9',
#   'anio_inauguracion': 2001,
#   'barrio': 'Gràcia',
#   'nombre': 'KFC',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89cfa',
#   'anio_inauguracion': 2003,
#   'barrio': 'Gràcia',
#   'nombre': 'Telepizza',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89cfb',
#   'anio_inauguracion': 2014,
#   'barrio': 'Nou Barris',
#   'nombre': 'KFC',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89cfc',
#   'anio_inauguracion': 2012,
#   'barrio': 'Gràcia',
#   'nombre': 'Telepizza',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89cfd',
#   'anio_inauguracion': 2016,
#   'barrio': 'Eixample',
#   'nombre': 'Burger King',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89cfe',
#   'anio_inauguracion': 2000,
#   'barrio': 'Gràcia',
#   'nombre': 'Papa Johns',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89cff',
#   'anio_inauguracion': 2013,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'Telepizza',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89d00',
#   'anio_inauguracion': 2005,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'Pizza Hut',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89d01',
#   'anio_inauguracion': 2005,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'Burger King',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89d02',
#   'anio_inauguracion': 2019,
#   'barrio': 'Gràcia',
#   'nombre': 'KFC',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89d03',
#   'anio_inauguracion': 2018,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'Telepizza',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89d04',
#   'anio_inauguracion': 2020,
#   'barrio': 'Nou Barris',
#   'nombre': 'Papa Johns',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89d05',
#   'anio_inauguracion': 2004,
#   'barrio': 'Sant Martí',
#   'nombre': 'Burger King',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89d06',
#   'anio_inauguracion': 2008,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Burger King',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89d07',
#   'anio_inauguracion': 2002,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'Pizza Hut',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89d08',
#   'anio_inauguracion': 2001,
#   'barrio': 'Gràcia',
#   'nombre': 'Pizza Hut',
#   'rating': 1}]

# %% [markdown]
# ### Contar y consultar con filtros
# Si queremos aplicar filtros, la forma de trabajar es sencilla, aunque naturalmente puede complicarse todo lo que queramos. En este caso nos vamos a quedar en un nivel básico.
#
# Supongamos que queremos limitar el conteo y consulta anteriores a aquellos reviews de restaurantes que se llaman "KFC". Para hacerlo, debemos definir el filtro como un JSON (diccionario) en el que vamos a ir indicando la clave sobre la que queremos filtrar y el valor de filtrado correspondiente.
#
# filtro = {"clave": "valor"} --> sería un equivalente a WHERE clave = "valor" en SQL.

# %%
# contamos todos los restaurantes que se tienen por nombre KFC en nuestra colección de reviews db.nombre_coleccion.count_documents(filtro)
dFiltro = {
    "nombre": "KFC"
}
db.coleccion_prueba.count_documents(dFiltro)
# Out:
# 67

# %%
# Mostramos todos los documentos de los restaurantes que se llaman KFC db.nombre_coleccion.find(filtro) como lista
dFiltro = {
    "$or": [ { "nombre": "KFC" }, {"rating": 3} ]
}
lResultados = list(db.coleccion_prueba.find(dFiltro))
lResultados
# Out:
# [{'_id': ObjectId('6075d05e341aba4b1605493d'),
#   'nombre': 'KFC',
#   'barrio': 'Eixample',
#   'rating': 4,
#   'anio_inauguracion': 2019},
#  {'_id': '5e6587297a4b4ac008f89b79',
#   'anio_inauguracion': 2016,
#   'barrio': 'Gràcia',
#   'nombre': 'KFC',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89b81',
#   'anio_inauguracion': 2008,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'KFC',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89b85',
#   'anio_inauguracion': 2017,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'KFC',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89b86',
#   'anio_inauguracion': 2020,
#   'barrio': 'Nou Barris',
#   'nombre': 'KFC',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89b88',
#   'anio_inauguracion': 2017,
#   'barrio': 'Les Corts',
#   'nombre': 'KFC',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89b8b',
#   'anio_inauguracion': 2006,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'Telepizza',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89b8f',
#   'anio_inauguracion': 2007,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Telepizza',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89b90',
#   'anio_inauguracion': 2017,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'KFC',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89b93',
#   'anio_inauguracion': 2008,
#   'barrio': 'Sant Martí',
#   'nombre': 'Telepizza',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89b97',
#   'anio_inauguracion': 2009,
#   'barrio': 'Eixample',
#   'nombre': 'Pizza Hut',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89b9d',
#   'anio_inauguracion': 2008,
#   'barrio': 'Les Corts',
#   'nombre': 'Burger King',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89b9f',
#   'anio_inauguracion': 2002,
#   'barrio': 'Sant Andreu',
#   'nombre': 'KFC',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89ba3',
#   'anio_inauguracion': 2005,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'KFC',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89baf',
#   'anio_inauguracion': 2010,
#   'barrio': 'Nou Barris',
#   'nombre': 'KFC',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89bb1',
#   'anio_inauguracion': 2010,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Pizza Hut',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89bb3',
#   'anio_inauguracion': 2011,
#   'barrio': 'Les Corts',
#   'nombre': 'McDonalds',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89bb4',
#   'anio_inauguracion': 2010,
#   'barrio': 'Les Corts',
#   'nombre': 'Papa Johns',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89bb7',
#   'anio_inauguracion': 2013,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'Pizza Hut',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89bb9',
#   'anio_inauguracion': 2011,
#   'barrio': 'Gràcia',
#   'nombre': 'KFC',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89bbb',
#   'anio_inauguracion': 2018,
#   'barrio': 'Eixample',
#   'nombre': 'Telepizza',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89bbd',
#   'anio_inauguracion': 2005,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'Papa Johns',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89bbf',
#   'anio_inauguracion': 2012,
#   'barrio': 'Sant Martí',
#   'nombre': 'KFC',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89bc0',
#   'anio_inauguracion': 2008,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'KFC',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89bc2',
#   'anio_inauguracion': 2012,
#   'barrio': 'Les Corts',
#   'nombre': 'Pizza Hut',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89bc4',
#   'anio_inauguracion': 2000,
#   'barrio': 'Nou Barris',
#   'nombre': 'Burger King',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89bc9',
#   'anio_inauguracion': 2004,
#   'barrio': 'Nou Barris',
#   'nombre': 'McDonalds',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89bd0',
#   'anio_inauguracion': 2014,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'Pizza Hut',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89bd2',
#   'anio_inauguracion': 2020,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'KFC',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89bd4',
#   'anio_inauguracion': 2016,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'Burger King',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89bd7',
#   'anio_inauguracion': 2013,
#   'barrio': 'Les Corts',
#   'nombre': 'KFC',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89bd8',
#   'anio_inauguracion': 2019,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'Pizza Hut',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89bda',
#   'anio_inauguracion': 2000,
#   'barrio': 'Sant Andreu',
#   'nombre': 'KFC',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89bdc',
#   'anio_inauguracion': 2000,
#   'barrio': 'Sant Andreu',
#   'nombre': 'KFC',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89bdd',
#   'anio_inauguracion': 2019,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Telepizza',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89bdf',
#   'anio_inauguracion': 2020,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'KFC',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89be1',
#   'anio_inauguracion': 2011,
#   'barrio': 'Gràcia',
#   'nombre': 'Telepizza',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89be3',
#   'anio_inauguracion': 2002,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'KFC',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89bec',
#   'anio_inauguracion': 2018,
#   'barrio': 'Gràcia',
#   'nombre': 'Pizza Hut',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89bed',
#   'anio_inauguracion': 2011,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'McDonalds',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89bef',
#   'anio_inauguracion': 2018,
#   'barrio': 'Gràcia',
#   'nombre': 'Pizza Hut',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89bf1',
#   'anio_inauguracion': 2015,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'McDonalds',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89bf2',
#   'anio_inauguracion': 2018,
#   'barrio': 'Sant Andreu',
#   'nombre': 'KFC',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89bf3',
#   'anio_inauguracion': 2004,
#   'barrio': 'Nou Barris',
#   'nombre': 'Papa Johns',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89bfb',
#   'anio_inauguracion': 2011,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'KFC',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89bfd',
#   'anio_inauguracion': 2004,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'Telepizza',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89bff',
#   'anio_inauguracion': 2000,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'Burger King',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c00',
#   'anio_inauguracion': 2020,
#   'barrio': 'Sant Martí',
#   'nombre': 'KFC',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89c01',
#   'anio_inauguracion': 2002,
#   'barrio': 'Gràcia',
#   'nombre': 'KFC',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89c02',
#   'anio_inauguracion': 2004,
#   'barrio': 'Sant Andreu',
#   'nombre': 'KFC',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89c04',
#   'anio_inauguracion': 2013,
#   'barrio': 'Les Corts',
#   'nombre': 'KFC',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89c0c',
#   'anio_inauguracion': 2000,
#   'barrio': 'Eixample',
#   'nombre': 'KFC',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89c0f',
#   'anio_inauguracion': 2002,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'KFC',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c10',
#   'anio_inauguracion': 2006,
#   'barrio': 'Sant Martí',
#   'nombre': 'Telepizza',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c16',
#   'anio_inauguracion': 2008,
#   'barrio': 'Sant Martí',
#   'nombre': 'Telepizza',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c1f',
#   'anio_inauguracion': 2000,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'Pizza Hut',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c20',
#   'anio_inauguracion': 2016,
#   'barrio': 'Les Corts',
#   'nombre': 'KFC',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89c21',
#   'anio_inauguracion': 2015,
#   'barrio': 'Les Corts',
#   'nombre': 'McDonalds',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c22',
#   'anio_inauguracion': 2009,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'KFC',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89c23',
#   'anio_inauguracion': 2008,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'Burger King',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c35',
#   'anio_inauguracion': 2009,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'KFC',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89c36',
#   'anio_inauguracion': 2003,
#   'barrio': 'Sant Martí',
#   'nombre': 'KFC',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89c3a',
#   'anio_inauguracion': 2003,
#   'barrio': 'Sant Martí',
#   'nombre': 'McDonalds',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c3b',
#   'anio_inauguracion': 2002,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Pizza Hut',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c3f',
#   'anio_inauguracion': 2010,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'Pizza Hut',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c41',
#   'anio_inauguracion': 2020,
#   'barrio': 'Gràcia',
#   'nombre': 'McDonalds',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c43',
#   'anio_inauguracion': 2004,
#   'barrio': 'Eixample',
#   'nombre': 'Pizza Hut',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c45',
#   'anio_inauguracion': 2014,
#   'barrio': 'Nou Barris',
#   'nombre': 'KFC',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89c47',
#   'anio_inauguracion': 2009,
#   'barrio': 'Gràcia',
#   'nombre': 'KFC',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c4a',
#   'anio_inauguracion': 2012,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'Pizza Hut',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c4b',
#   'anio_inauguracion': 2012,
#   'barrio': 'Sant Andreu',
#   'nombre': 'KFC',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89c50',
#   'anio_inauguracion': 2018,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'Papa Johns',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c52',
#   'anio_inauguracion': 2018,
#   'barrio': 'Les Corts',
#   'nombre': 'Burger King',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c54',
#   'anio_inauguracion': 2015,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'McDonalds',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c55',
#   'anio_inauguracion': 2012,
#   'barrio': 'Les Corts',
#   'nombre': 'Pizza Hut',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c56',
#   'anio_inauguracion': 2018,
#   'barrio': 'Sant Martí',
#   'nombre': 'Burger King',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c58',
#   'anio_inauguracion': 2005,
#   'barrio': 'Eixample',
#   'nombre': 'McDonalds',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c5a',
#   'anio_inauguracion': 2000,
#   'barrio': 'Sant Martí',
#   'nombre': 'KFC',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89c5b',
#   'anio_inauguracion': 2005,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'KFC',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89c5c',
#   'anio_inauguracion': 2005,
#   'barrio': 'Sant Martí',
#   'nombre': 'Pizza Hut',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c68',
#   'anio_inauguracion': 2013,
#   'barrio': 'Sant Andreu',
#   'nombre': 'McDonalds',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c69',
#   'anio_inauguracion': 2020,
#   'barrio': 'Sant Martí',
#   'nombre': 'KFC',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89c6d',
#   'anio_inauguracion': 2001,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'KFC',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89c6f',
#   'anio_inauguracion': 2015,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'KFC',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89c75',
#   'anio_inauguracion': 2000,
#   'barrio': 'Sant Andreu',
#   'nombre': 'KFC',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89c77',
#   'anio_inauguracion': 2008,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'KFC',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89c78',
#   'anio_inauguracion': 2009,
#   'barrio': 'Nou Barris',
#   'nombre': 'McDonalds',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c7a',
#   'anio_inauguracion': 2006,
#   'barrio': 'Gràcia',
#   'nombre': 'Pizza Hut',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c7c',
#   'anio_inauguracion': 2010,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'KFC',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89c7f',
#   'anio_inauguracion': 2009,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Burger King',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c82',
#   'anio_inauguracion': 2015,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'McDonalds',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c83',
#   'anio_inauguracion': 2011,
#   'barrio': 'Eixample',
#   'nombre': 'KFC',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89c87',
#   'anio_inauguracion': 2005,
#   'barrio': 'Eixample',
#   'nombre': 'KFC',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89c89',
#   'anio_inauguracion': 2020,
#   'barrio': 'Gràcia',
#   'nombre': 'KFC',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89c8e',
#   'anio_inauguracion': 2013,
#   'barrio': 'Sant Martí',
#   'nombre': 'Pizza Hut',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c92',
#   'anio_inauguracion': 2008,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'KFC',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89c94',
#   'anio_inauguracion': 2015,
#   'barrio': 'Eixample',
#   'nombre': 'Telepizza',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c96',
#   'anio_inauguracion': 2018,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'Telepizza',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c97',
#   'anio_inauguracion': 2007,
#   'barrio': 'Eixample',
#   'nombre': 'KFC',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c99',
#   'anio_inauguracion': 2014,
#   'barrio': 'Les Corts',
#   'nombre': 'KFC',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89c9e',
#   'anio_inauguracion': 2010,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Burger King',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89c9f',
#   'anio_inauguracion': 2012,
#   'barrio': 'Eixample',
#   'nombre': 'KFC',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89ca5',
#   'anio_inauguracion': 2003,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Pizza Hut',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89ca8',
#   'anio_inauguracion': 2019,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'KFC',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89caa',
#   'anio_inauguracion': 2013,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'KFC',
#   'rating': 1},
#  {'_id': '5e6587297a4b4ac008f89cab',
#   'anio_inauguracion': 2005,
#   'barrio': 'Sant Andreu',
#   'nombre': 'KFC',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89cac',
#   'anio_inauguracion': 2001,
#   'barrio': 'Les Corts',
#   'nombre': 'Telepizza',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89cad',
#   'anio_inauguracion': 2004,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'KFC',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89cb1',
#   'anio_inauguracion': 2006,
#   'barrio': 'Eixample',
#   'nombre': 'Pizza Hut',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89cb2',
#   'anio_inauguracion': 2003,
#   'barrio': 'Sant Martí',
#   'nombre': 'Burger King',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89cb3',
#   'anio_inauguracion': 2010,
#   'barrio': 'Sant Andreu',
#   'nombre': 'McDonalds',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89cba',
#   'anio_inauguracion': 2008,
#   'barrio': 'Nou Barris',
#   'nombre': 'KFC',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89cbc',
#   'anio_inauguracion': 2015,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Burger King',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89cbe',
#   'anio_inauguracion': 2011,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'Papa Johns',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89cc0',
#   'anio_inauguracion': 2005,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'Telepizza',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89cc3',
#   'anio_inauguracion': 2004,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'KFC',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89cc5',
#   'anio_inauguracion': 2007,
#   'barrio': 'Les Corts',
#   'nombre': 'KFC',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89cc8',
#   'anio_inauguracion': 2008,
#   'barrio': 'Les Corts',
#   'nombre': 'KFC',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89cca',
#   'anio_inauguracion': 2020,
#   'barrio': 'Nou Barris',
#   'nombre': 'KFC',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89cd0',
#   'anio_inauguracion': 2010,
#   'barrio': 'Sant Andreu',
#   'nombre': 'KFC',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89cd4',
#   'anio_inauguracion': 2007,
#   'barrio': 'Gràcia',
#   'nombre': 'KFC',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89cd8',
#   'anio_inauguracion': 2007,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'KFC',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89cdc',
#   'anio_inauguracion': 2003,
#   'barrio': 'Sant Martí',
#   'nombre': 'Pizza Hut',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89cdf',
#   'anio_inauguracion': 2005,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'Telepizza',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89ce1',
#   'anio_inauguracion': 2007,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'Papa Johns',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89ce5',
#   'anio_inauguracion': 2010,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'KFC',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89cea',
#   'anio_inauguracion': 2001,
#   'barrio': 'Gràcia',
#   'nombre': 'KFC',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89ceb',
#   'anio_inauguracion': 2006,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'Pizza Hut',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89cef',
#   'anio_inauguracion': 2006,
#   'barrio': 'Sant Martí',
#   'nombre': 'Papa Johns',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89cf4',
#   'anio_inauguracion': 2011,
#   'barrio': 'Eixample',
#   'nombre': 'KFC',
#   'rating': 5},
#  {'_id': '5e6587297a4b4ac008f89cf5',
#   'anio_inauguracion': 2015,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'Pizza Hut',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89cf8',
#   'anio_inauguracion': 2015,
#   'barrio': 'Nou Barris',
#   'nombre': 'Burger King',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89cf9',
#   'anio_inauguracion': 2001,
#   'barrio': 'Gràcia',
#   'nombre': 'KFC',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89cfb',
#   'anio_inauguracion': 2014,
#   'barrio': 'Nou Barris',
#   'nombre': 'KFC',
#   'rating': 4},
#  {'_id': '5e6587297a4b4ac008f89d02',
#   'anio_inauguracion': 2019,
#   'barrio': 'Gràcia',
#   'nombre': 'KFC',
#   'rating': 2},
#  {'_id': '5e6587297a4b4ac008f89d03',
#   'anio_inauguracion': 2018,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'Telepizza',
#   'rating': 3},
#  {'_id': '5e6587297a4b4ac008f89d04',
#   'anio_inauguracion': 2020,
#   'barrio': 'Nou Barris',
#   'nombre': 'Papa Johns',
#   'rating': 3}]

# %%
# Si hacemos un len de la lista, deberíamos ver que resulta el mismo número que el count_documents anterior.
len(lResultados)
# Out:
# 137

# %% [markdown]
# ### Agrupar y agregar información
#
# https://docs.mongodb.com/manual/aggregation/
# https://docs.mongodb.com/manual/reference/method/db.collection.aggregate/
#
# Para poder agregar información de documentos de MongoDB, podemos utilizar el método Aggregate. Este método es el equivalente de GROUP BY con un COUNT o SUM, o función de agregación equivalente. Al igual que hemos hecho con el find o el count_documents, este método aplica sobre la colección en cuestión:
#
# db.[nombre_coleccion].aggregate(json_condiciones)
#
# Este método es el más complicado a nivel de sintaxis, ya que no es muy "user friendly" :-) A este método, se le pasan tres tipos de "parámetros" (lista de diccionarios):
#
# 1. (dolar)match: es el equivalmente al where de SQL.
# 2. (dolar)group: los campos sobre los que vamos a agrupar (_id será la clave del campo que vamos a agrupar).
# 3. (dolar)sort: los campos por los que vamos a ordenar
#
# Lo que vamos a hacer es mostrar cuántos restaurantes hay para cada nivel de rating, desde el 1 hasta el 5, utilizando el método **aggregate**.

# %%
# Primero, definimos los parámetros:
lParams = [
    {
        # Agrupación
        "$group": {
            "_id": "$rating", # _id código interno de MongoDB para indicar en el valor, el nombre del campo sobre el que vamos a agrupar.
            # Como puede verse, se incluye un $ delante del nombre del campo que actúa como Id
            "num_restaurantes": {"$sum": 1} # num_restaurantes es el nombre del campo agregado resultante (como un alias), que en este caso es un COUNT, o lo que es lo mismo un SUM de 1 para cada registro
        }
    }, 
    {
        # Ordenación
        "$sort": {
            "_id": 1 # estamos ordenando de forma ascendente (1) el campo $_id que es el "rating"
        }
    }
]

# %%
# Ahora listamos los resultados 
lResultado = list(db.coleccion_prueba.aggregate(lParams))
display(lResultado)
total = 0 
for elemento in lResultado:
    total += elemento["num_restaurantes"]
display(total)
# Out:
# [{'_id': None, 'num_restaurantes': 2},
#  {'_id': 1, 'num_restaurantes': 77},
#  {'_id': 2, 'num_restaurantes': 84},
#  {'_id': 3, 'num_restaurantes': 84},
#  {'_id': 4, 'num_restaurantes': 73},
#  {'_id': 5, 'num_restaurantes': 83}]
# 403

# %% [markdown]
# Probemos ahora qué pasaría si quisiéramos filtrar por restaurantes Burger King y KFC:

# %%
# Primero, definimos los parámetros filtrando por Burger King:
lParams = [
    {
        # Where
        "$match": {
            "$or": [ { "nombre": "KFC" }, {"nombre": "Burger King"} ]
        }
    }, 
    {
        # Agrupación
        "$group": {
            "_id": "$rating", # $_id código interno de MongoDB para indicar en el valor, el nombre del campo sobre el que vamos a agrupar.
            # Como puede verse, se incluye un $ delante del nombre del campo que actúa como Id
            "num_restaurantes": {"$sum": 1} # num_restaurantes es el nombre del campo agregado resultante (como un alias), que en este caso es un COUNT, o lo que es lo mismo un SUM de 1 para cada registro
        }
    }, 
    {
        # Ordenación
        "$sort": {
            "_id": 1 # estamos ordenando de forma ascendente (1) el campo $_id que es el "rating"
        }
    }
]

# %%
# Ahora listamos los resultados 
resultado = list(db.coleccion_prueba.aggregate(lParams))
display(resultado)
total = 0 
for elemento in resultado:
    total += elemento["num_restaurantes"]
display(total)
# Out:
# [{'_id': 1, 'num_restaurantes': 26},
#  {'_id': 2, 'num_restaurantes': 30},
#  {'_id': 3, 'num_restaurantes': 26},
#  {'_id': 4, 'num_restaurantes': 23},
#  {'_id': 5, 'num_restaurantes': 28}]
# 133

# %% [markdown]
# ### Actualizar y borrar documentos
#
# Al igual que podemos hacer UPDATE en SQL, aquí podemos hacer update_one y update_many (el primero, actualiza sólo el primer valor que encuentra, mientras que el segundo actualiza todos).
#
# db.[nombre_coleccion].update_many(dict_campo_condicion, dict_set)

# %%
# Actualicemos todos los restaurantes que se llaman "Burger King" y llamémosles "Burger Queen" y cambiamos el rating a 8000
# Primero definimos los parámetros dCampo y dSet
dCondition = {"nombre": "Burger Queen"}
dSet = {"$set": {"nombre": "Burger King", "rating":8000}}
# Y después ejecutamos
db.coleccion_prueba.update_many(dCondition, dSet)

# %%
# Vamos a buscar el antiguo Burger King.
db.coleccion_prueba.count_documents({"nombre": "Burger King"})
# Out:
# 66

# %%
# Vamos a buscar el antiguo Burger Queen.
db.coleccion_prueba.count_documents({"nombre": "Burger Queen"})
# Out:
# 0

# %%
list(db.coleccion_prueba.find({"rating": {"$gt": 7000}}))
# Out:
# [{'_id': '5e6587297a4b4ac008f89b7f',
#   'anio_inauguracion': 2000,
#   'barrio': 'Les Corts',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89b8c',
#   'anio_inauguracion': 2001,
#   'barrio': 'Les Corts',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89b8d',
#   'anio_inauguracion': 2011,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89b98',
#   'anio_inauguracion': 2002,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89b9d',
#   'anio_inauguracion': 2008,
#   'barrio': 'Les Corts',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89ba1',
#   'anio_inauguracion': 2020,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89bac',
#   'anio_inauguracion': 2017,
#   'barrio': 'Gràcia',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89bba',
#   'anio_inauguracion': 2006,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89bbe',
#   'anio_inauguracion': 2001,
#   'barrio': 'Sant Martí',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89bc1',
#   'anio_inauguracion': 2010,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89bc4',
#   'anio_inauguracion': 2000,
#   'barrio': 'Nou Barris',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89bc5',
#   'anio_inauguracion': 2000,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89bc6',
#   'anio_inauguracion': 2017,
#   'barrio': 'Nou Barris',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89bcc',
#   'anio_inauguracion': 2015,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89bd1',
#   'anio_inauguracion': 2014,
#   'barrio': 'Les Corts',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89bd4',
#   'anio_inauguracion': 2016,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89bd9',
#   'anio_inauguracion': 2015,
#   'barrio': 'Eixample',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89be7',
#   'anio_inauguracion': 2017,
#   'barrio': 'Sant Martí',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89bfa',
#   'anio_inauguracion': 2010,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89bff',
#   'anio_inauguracion': 2000,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89c06',
#   'anio_inauguracion': 2016,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89c08',
#   'anio_inauguracion': 2001,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89c09',
#   'anio_inauguracion': 2020,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89c0d',
#   'anio_inauguracion': 2013,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89c0e',
#   'anio_inauguracion': 2009,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89c13',
#   'anio_inauguracion': 2018,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89c15',
#   'anio_inauguracion': 2020,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89c18',
#   'anio_inauguracion': 2019,
#   'barrio': 'Ciutat Vella',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89c23',
#   'anio_inauguracion': 2008,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89c25',
#   'anio_inauguracion': 2019,
#   'barrio': 'Gràcia',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89c29',
#   'anio_inauguracion': 2010,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89c2c',
#   'anio_inauguracion': 2002,
#   'barrio': 'Nou Barris',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89c38',
#   'anio_inauguracion': 2004,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89c3d',
#   'anio_inauguracion': 2012,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89c52',
#   'anio_inauguracion': 2018,
#   'barrio': 'Les Corts',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89c56',
#   'anio_inauguracion': 2018,
#   'barrio': 'Sant Martí',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89c5f',
#   'anio_inauguracion': 2018,
#   'barrio': 'Eixample',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89c6a',
#   'anio_inauguracion': 2004,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89c7d',
#   'anio_inauguracion': 2019,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89c7f',
#   'anio_inauguracion': 2009,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89c84',
#   'anio_inauguracion': 2003,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89c98',
#   'anio_inauguracion': 2017,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89c9c',
#   'anio_inauguracion': 2008,
#   'barrio': 'Gràcia',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89c9d',
#   'anio_inauguracion': 2011,
#   'barrio': 'Eixample',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89c9e',
#   'anio_inauguracion': 2010,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89ca2',
#   'anio_inauguracion': 2011,
#   'barrio': 'Sant Martí',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89ca9',
#   'anio_inauguracion': 2013,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89cb2',
#   'anio_inauguracion': 2003,
#   'barrio': 'Sant Martí',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89cb9',
#   'anio_inauguracion': 2012,
#   'barrio': 'Eixample',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89cbc',
#   'anio_inauguracion': 2015,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89cbd',
#   'anio_inauguracion': 2017,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89cc6',
#   'anio_inauguracion': 2015,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89cc9',
#   'anio_inauguracion': 2017,
#   'barrio': 'Sant Martí',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89ccc',
#   'anio_inauguracion': 2020,
#   'barrio': 'Sants - Montjuïc',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89cd2',
#   'anio_inauguracion': 2015,
#   'barrio': 'Les Corts',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89cde',
#   'anio_inauguracion': 2014,
#   'barrio': 'Sant Martí',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89ce0',
#   'anio_inauguracion': 2015,
#   'barrio': 'Nou Barris',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89ce6',
#   'anio_inauguracion': 2018,
#   'barrio': 'Sarrià - Sant Gervasi',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89ced',
#   'anio_inauguracion': 2010,
#   'barrio': 'Eixample',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89cf0',
#   'anio_inauguracion': 2006,
#   'barrio': 'Gràcia',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89cf3',
#   'anio_inauguracion': 2006,
#   'barrio': 'Les Corts',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89cf8',
#   'anio_inauguracion': 2015,
#   'barrio': 'Nou Barris',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89cfd',
#   'anio_inauguracion': 2016,
#   'barrio': 'Eixample',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89d01',
#   'anio_inauguracion': 2005,
#   'barrio': 'Horta - Guinardó',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89d05',
#   'anio_inauguracion': 2004,
#   'barrio': 'Sant Martí',
#   'nombre': 'Burger King',
#   'rating': 8000},
#  {'_id': '5e6587297a4b4ac008f89d06',
#   'anio_inauguracion': 2008,
#   'barrio': 'Sant Andreu',
#   'nombre': 'Burger King',
#   'rating': 8000}]

# %% [markdown]
# Y si ahora queremos **borrar**:
#
# db.[nombre_coleccion].delete_many(dict_campo_condicion)

# %%
# Borremos todos los registros que sean "Burger Queen"
db.coleccion_prueba.delete_many({"rating": 8000})

# %%
# Comprobemos que, efectivamente, se han borrado
list(db.coleccionRestaurantes.find({"rating": 8000}))
# Out:
# []
