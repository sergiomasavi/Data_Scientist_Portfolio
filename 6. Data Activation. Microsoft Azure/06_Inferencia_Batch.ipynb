# %% [markdown]
# <img src="Tarjeta.png">

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Conectar-área-de-trabajo" data-toc-modified-id="Conectar-área-de-trabajo-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Conectar área de trabajo</a></span></li><li><span><a href="#Entrenar-y-registrar-modelo" data-toc-modified-id="Entrenar-y-registrar-modelo-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Entrenar y registrar modelo</a></span></li><li><span><a href="#Generar-y-subir-datos-batch" data-toc-modified-id="Generar-y-subir-datos-batch-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Generar y subir datos batch</a></span></li><li><span><a href="#Crear-instancia" data-toc-modified-id="Crear-instancia-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Crear instancia</a></span></li><li><span><a href="#Crear-canalización-para-inferencia-batch" data-toc-modified-id="Crear-canalización-para-inferencia-batch-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Crear canalización para inferencia batch</a></span></li><li><span><a href="#Publicar-la-canalización-y-usar-como-una-interfaz-REST" data-toc-modified-id="Publicar-la-canalización-y-usar-como-una-interfaz-REST-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Publicar la canalización y usar como una interfaz REST</a></span></li></ul></div>

# %% [markdown]
# # Inferencia Batch

# %% [markdown]
# ## Conectar área de trabajo

# %%
import azureml.core
from azureml.core import Workspace

# Cargar el área de trabajo del fichero de configuración
ws = Workspace.from_config()
print('Versión de Azure ML {} y área de trabajo {}'.format(azureml.core.VERSION, ws.name))
# Out:
# Versión de Azure ML 1.32.0 y área de trabajo aml-nuclio

# %% [markdown]
# ## Entrenar y registrar modelo

# %%
from azureml.core import Experiment
from azureml.core import Model
import pandas as pd
import numpy as np
import joblib
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

# Crear el experimento
experiment = Experiment(workspace=ws, name='nuclio-train-vino')
run = experiment.start_logging()
print("Empezando experimento:", experiment.name)

# Cargar los datos de un fichero local
data = pd.read_csv('data/winequality.csv', sep=';', decimal='.')

# Separar features and target
features = ['fixed_acidity', 'volatile_acidity', 'citric_acid', 'residual_sugar', 'chlorides', 'free_sulfur_dioxide', 'total_sulfur_dioxide', 'density', 'ph', 'sulphates']
X, y = data[features].values, data['top_quality'].values

# Split data into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0)

# Entrenamiento de un arbol de decision
print('Entrenando un decision tree model')
model = DecisionTreeClassifier().fit(X_train, y_train)

# calculate accuracy
y_hat = model.predict(X_test)
acc = np.average(y_hat == y_test)
print('Accuracy:', acc)
run.log('Accuracy', np.float(acc))

# Calcular AUC
y_scores = model.predict_proba(X_test)
auc = roc_auc_score(y_test,y_scores[:,1])
print('AUC: ' + str(auc))
run.log('AUC', np.float(auc))

# Guardar el modelo entrenado en la carpeta outputs
print("Guardando el modelo...")
os.makedirs('outputs', exist_ok=True)
model_file = os.path.join('outputs', 'vino_model.pkl')
joblib.dump(value=model, filename=model_file)

# Completar ejecución
run.complete()

# Registrar el modelo
print('Registrando el modelo...')
Model.register(workspace=run.experiment.workspace,
               model_path = model_file,
               model_name = 'vino_model',
               tags={'Training context':'Inline Training'},
               properties={'AUC': np.float(auc), 'Accuracy': np.float(acc)})

print('Modelo entrenado y registrado')
# Out:
# Empezando experimento: nuclio-train-vino
# Entrenando un decision tree model
# Accuracy: 0.8115646258503402
# AUC: 0.7299711990633483
# Guardando el modelo...
# Registrando el modelo...
# Registering model vino_model
# Modelo entrenado y registrado

# %% [markdown]
# ## Generar y subir datos batch

# %%
from azureml.core import Datastore, Dataset
import pandas as pd
import os

# Conseguir los datastores que hay por defecto
ws.set_default_datastore('workspaceblobstore')
default_ds = ws.get_default_datastore()

# Enumera los datastores e indica cual es el de por defecto
for ds_name in ws.datastores:
    print(ds_name, "- Por defecto =", ds_name == default_ds.name)

# Load the diabetes data
data = pd.read_csv('data/winequality.csv', sep=';', decimal='.')
# Quedarnos con las features y unos 100 registros
features = ['fixed_acidity', 'volatile_acidity', 'citric_acid', 'residual_sugar', 'chlorides', 'free_sulfur_dioxide', 'total_sulfur_dioxide', 'density', 'ph', 'sulphates']
sample = data[features].sample(n=100).values

# Crear carpeta
batch_folder = './batch-data'
os.makedirs(batch_folder, exist_ok=True)
print("Carpeta creada!")

# Guardar los ejemplos en un fichero separado cada registro
print("Guardando ficheros...")
for i in range(100):
    fname = str(i+1) + '.csv'
    sample[i].tofile(os.path.join(batch_folder, fname), sep=",")
print("ficheros guardados!")

# Cargar los ficheros en el datastore
print("Subiendo ficheros al datastore...")
default_ds = ws.get_default_datastore()
default_ds.upload(src_dir="batch-data", target_path="batch-data", overwrite=True, show_progress=True)

# Registrar dataset para el input
batch_data_set = Dataset.File.from_files(path=(default_ds, 'batch-data/'), validate=False)
try:
    batch_data_set = batch_data_set.register(workspace=ws, 
                                             name='batch-data',
                                             description='batch data',
                                             create_new_version=True)
except Exception as ex:
    print(ex)

print("Hecho!")
# Out:
# azureml_globaldatasets - Por defecto = False
# workspacefilestore - Por defecto = False
# workspaceblobstore - Por defecto = True
# Carpeta creada!
# Guardando ficheros...
# ficheros guardados!
# Subiendo ficheros al datastore...
# Uploading an estimated of 100 files
# Uploading batch-data/1.csv
# Uploaded batch-data/1.csv, 1 files out of an estimated total of 100
# Uploading batch-data/10.csv
# Uploaded batch-data/10.csv, 2 files out of an estimated total of 100
# Uploading batch-data/100.csv
# Uploaded batch-data/100.csv, 3 files out of an estimated total of 100
# Uploading batch-data/11.csv
# Uploaded batch-data/11.csv, 4 files out of an estimated total of 100
# Uploading batch-data/12.csv
# Uploaded batch-data/12.csv, 5 files out of an estimated total of 100
# Uploading batch-data/13.csv
# Uploaded batch-data/13.csv, 6 files out of an estimated total of 100
# Uploading batch-data/14.csv
# Uploaded batch-data/14.csv, 7 files out of an estimated total of 100
# Uploading batch-data/15.csv
# Uploaded batch-data/15.csv, 8 files out of an estimated total of 100
# Uploading batch-data/16.csv
# Uploaded batch-data/16.csv, 9 files out of an estimated total of 100
# Uploading batch-data/17.csv
# Uploaded batch-data/17.csv, 10 files out of an estimated total of 100
# Uploading batch-data/18.csv
# Uploaded batch-data/18.csv, 11 files out of an estimated total of 100
# Uploading batch-data/19.csv
# Uploaded batch-data/19.csv, 12 files out of an estimated total of 100
# Uploading batch-data/2.csv
# Uploaded batch-data/2.csv, 13 files out of an estimated total of 100
# Uploading batch-data/20.csv
# Uploaded batch-data/20.csv, 14 files out of an estimated total of 100
# Uploading batch-data/21.csv
# Uploaded batch-data/21.csv, 15 files out of an estimated total of 100
# Uploading batch-data/22.csv
# Uploaded batch-data/22.csv, 16 files out of an estimated total of 100
# Uploading batch-data/23.csv
# Uploaded batch-data/23.csv, 17 files out of an estimated total of 100
# Uploading batch-data/24.csv
# Uploaded batch-data/24.csv, 18 files out of an estimated total of 100
# Uploading batch-data/25.csv
# Uploaded batch-data/25.csv, 19 files out of an estimated total of 100
# Uploading batch-data/26.csv
# Uploaded batch-data/26.csv, 20 files out of an estimated total of 100
# Uploading batch-data/27.csv
# Uploaded batch-data/27.csv, 21 files out of an estimated total of 100
# Uploading batch-data/28.csv
# Uploaded batch-data/28.csv, 22 files out of an estimated total of 100
# Uploading batch-data/29.csv
# Uploaded batch-data/29.csv, 23 files out of an estimated total of 100
# Uploading batch-data/3.csv
# Uploaded batch-data/3.csv, 24 files out of an estimated total of 100
# Uploading batch-data/30.csv
# Uploaded batch-data/30.csv, 25 files out of an estimated total of 100
# Uploading batch-data/31.csv
# Uploaded batch-data/31.csv, 26 files out of an estimated total of 100
# Uploading batch-data/32.csv
# Uploaded batch-data/32.csv, 27 files out of an estimated total of 100
# Uploading batch-data/33.csv
# Uploaded batch-data/33.csv, 28 files out of an estimated total of 100
# Uploading batch-data/34.csv
# Uploaded batch-data/34.csv, 29 files out of an estimated total of 100
# Uploading batch-data/35.csv
# Uploaded batch-data/35.csv, 30 files out of an estimated total of 100
# Uploading batch-data/36.csv
# Uploaded batch-data/36.csv, 31 files out of an estimated total of 100
# Uploading batch-data/37.csv
# Uploaded batch-data/37.csv, 32 files out of an estimated total of 100
# Uploading batch-data/38.csv
# Uploaded batch-data/38.csv, 33 files out of an estimated total of 100
# Uploading batch-data/39.csv
# Uploaded batch-data/39.csv, 34 files out of an estimated total of 100
# Uploading batch-data/4.csv
# Uploaded batch-data/4.csv, 35 files out of an estimated total of 100
# Uploading batch-data/40.csv
# Uploaded batch-data/40.csv, 36 files out of an estimated total of 100
# Uploading batch-data/41.csv
# Uploaded batch-data/41.csv, 37 files out of an estimated total of 100
# Uploading batch-data/42.csv
# Uploaded batch-data/42.csv, 38 files out of an estimated total of 100
# Uploading batch-data/43.csv
# Uploaded batch-data/43.csv, 39 files out of an estimated total of 100
# Uploading batch-data/44.csv
# Uploaded batch-data/44.csv, 40 files out of an estimated total of 100
# Uploading batch-data/45.csv
# Uploaded batch-data/45.csv, 41 files out of an estimated total of 100
# Uploading batch-data/46.csv
# Uploaded batch-data/46.csv, 42 files out of an estimated total of 100
# Uploading batch-data/47.csv
# Uploaded batch-data/47.csv, 43 files out of an estimated total of 100
# Uploading batch-data/48.csv
# Uploaded batch-data/48.csv, 44 files out of an estimated total of 100
# Uploading batch-data/49.csv
# Uploaded batch-data/49.csv, 45 files out of an estimated total of 100
# Uploading batch-data/5.csv
# Uploaded batch-data/5.csv, 46 files out of an estimated total of 100
# Uploading batch-data/50.csv
# Uploaded batch-data/50.csv, 47 files out of an estimated total of 100
# Uploading batch-data/51.csv
# Uploaded batch-data/51.csv, 48 files out of an estimated total of 100
# Uploading batch-data/52.csv
# Uploaded batch-data/52.csv, 49 files out of an estimated total of 100
# Uploading batch-data/53.csv
# Uploaded batch-data/53.csv, 50 files out of an estimated total of 100
# Uploading batch-data/54.csv
# Uploaded batch-data/54.csv, 51 files out of an estimated total of 100
# Uploading batch-data/55.csv
# Uploaded batch-data/55.csv, 52 files out of an estimated total of 100
# Uploading batch-data/56.csv
# Uploaded batch-data/56.csv, 53 files out of an estimated total of 100
# Uploading batch-data/57.csv
# Uploaded batch-data/57.csv, 54 files out of an estimated total of 100
# Uploading batch-data/58.csv
# Uploaded batch-data/58.csv, 55 files out of an estimated total of 100
# Uploading batch-data/59.csv
# Uploaded batch-data/59.csv, 56 files out of an estimated total of 100
# Uploading batch-data/6.csv
# Uploaded batch-data/6.csv, 57 files out of an estimated total of 100
# Uploading batch-data/60.csv
# Uploaded batch-data/60.csv, 58 files out of an estimated total of 100
# Uploading batch-data/61.csv
# Uploaded batch-data/61.csv, 59 files out of an estimated total of 100
# Uploading batch-data/62.csv
# Uploaded batch-data/62.csv, 60 files out of an estimated total of 100
# Uploading batch-data/63.csv
# Uploaded batch-data/63.csv, 61 files out of an estimated total of 100
# Uploading batch-data/64.csv
# Uploaded batch-data/64.csv, 62 files out of an estimated total of 100
# Uploading batch-data/65.csv
# Uploaded batch-data/65.csv, 63 files out of an estimated total of 100
# Uploading batch-data/66.csv
# Uploaded batch-data/66.csv, 64 files out of an estimated total of 100
# Uploading batch-data/67.csv
# Uploaded batch-data/67.csv, 65 files out of an estimated total of 100
# Uploading batch-data/68.csv
# Uploaded batch-data/68.csv, 66 files out of an estimated total of 100
# Uploading batch-data/69.csv
# Uploaded batch-data/69.csv, 67 files out of an estimated total of 100
# Uploading batch-data/7.csv
# Uploaded batch-data/7.csv, 68 files out of an estimated total of 100
# Uploading batch-data/70.csv
# Uploaded batch-data/70.csv, 69 files out of an estimated total of 100
# Uploading batch-data/71.csv
# Uploaded batch-data/71.csv, 70 files out of an estimated total of 100
# Uploading batch-data/72.csv
# Uploaded batch-data/72.csv, 71 files out of an estimated total of 100
# Uploading batch-data/73.csv
# Uploaded batch-data/73.csv, 72 files out of an estimated total of 100
# Uploading batch-data/74.csv
# Uploaded batch-data/74.csv, 73 files out of an estimated total of 100
# Uploading batch-data/75.csv
# Uploaded batch-data/75.csv, 74 files out of an estimated total of 100
# Uploading batch-data/76.csv
# Uploaded batch-data/76.csv, 75 files out of an estimated total of 100
# Uploading batch-data/77.csv
# Uploaded batch-data/77.csv, 76 files out of an estimated total of 100
# Uploading batch-data/78.csv
# Uploaded batch-data/78.csv, 77 files out of an estimated total of 100
# Uploading batch-data/79.csv
# Uploaded batch-data/79.csv, 78 files out of an estimated total of 100
# Uploading batch-data/8.csv
# Uploaded batch-data/8.csv, 79 files out of an estimated total of 100
# Uploading batch-data/80.csv
# Uploaded batch-data/80.csv, 80 files out of an estimated total of 100
# Uploading batch-data/81.csv
# Uploaded batch-data/81.csv, 81 files out of an estimated total of 100
# Uploading batch-data/82.csv
# Uploaded batch-data/82.csv, 82 files out of an estimated total of 100
# Uploading batch-data/83.csv
# Uploaded batch-data/83.csv, 83 files out of an estimated total of 100
# Uploading batch-data/84.csv
# Uploaded batch-data/84.csv, 84 files out of an estimated total of 100
# Uploading batch-data/85.csv
# Uploaded batch-data/85.csv, 85 files out of an estimated total of 100
# Uploading batch-data/86.csv
# Uploaded batch-data/86.csv, 86 files out of an estimated total of 100
# Uploading batch-data/87.csv
# Uploaded batch-data/87.csv, 87 files out of an estimated total of 100
# Uploading batch-data/88.csv
# Uploaded batch-data/88.csv, 88 files out of an estimated total of 100
# Uploading batch-data/89.csv
# Uploaded batch-data/89.csv, 89 files out of an estimated total of 100
# Uploading batch-data/9.csv
# Uploaded batch-data/9.csv, 90 files out of an estimated total of 100
# Uploading batch-data/90.csv
# Uploaded batch-data/90.csv, 91 files out of an estimated total of 100
# Uploading batch-data/91.csv
# Uploaded batch-data/91.csv, 92 files out of an estimated total of 100
# Uploading batch-data/92.csv
# Uploaded batch-data/92.csv, 93 files out of an estimated total of 100
# Uploading batch-data/93.csv
# Uploaded batch-data/93.csv, 94 files out of an estimated total of 100
# Uploading batch-data/94.csv
# Uploaded batch-data/94.csv, 95 files out of an estimated total of 100
# Uploading batch-data/95.csv
# Uploaded batch-data/95.csv, 96 files out of an estimated total of 100
# Uploading batch-data/96.csv
# Uploaded batch-data/96.csv, 97 files out of an estimated total of 100
# Uploading batch-data/97.csv
# Uploaded batch-data/97.csv, 98 files out of an estimated total of 100
# Uploading batch-data/98.csv
# Uploaded batch-data/98.csv, 99 files out of an estimated total of 100
# Uploading batch-data/99.csv
# Uploaded batch-data/99.csv, 100 files out of an estimated total of 100
# Uploaded 100 files
# Hecho!

# %% [markdown]
# ## Crear instancia

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

cluster_name = "NuclioCluster"

try:
    # Validar si existe
    inference_cluster = ComputeTarget(workspace=ws, name=cluster_name)
    print('Cluster de proceso encontrado.')
except ComputeTargetException:
    # Si no existe, se crea
    try:
        compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_DS11_V2', max_nodes=2)
        inference_cluster = ComputeTarget.create(ws, cluster_name, compute_config)
        inference_cluster.wait_for_completion(show_output=True)
    except Exception as ex:
        print(ex)
# Out:
# Cluster de proceso encontrado.

# %% [markdown]
# ## Crear canalización para inferencia batch

# %%
import os
# Crear una carpeta para el experimento
experiment_folder = 'batch_pipeline'
os.makedirs(experiment_folder, exist_ok=True)

print(experiment_folder)
# Out:
# batch_pipeline

# %%
# %%writefile $experiment_folder/batch_vino.py
import os
import numpy as np
from azureml.core import Model
import joblib


def init():
    # Ejecutar cuando el paso de la canalización se inicia
    global model

    # cargar modelo
    model_path = Model.get_model_path('vino_model')
    model = joblib.load(model_path)


def run(mini_batch):
    # Ejecutar para cada batch
    resultList = []

    # procesa cada fichero en batch
    for f in mini_batch:
        # leer datos
        data = np.genfromtxt(f, delimiter=',')
        # Transformar 
        prediction = model.predict(data.reshape(1, -1))
        # Append de las predicciones
        resultList.append("{}: {}".format(os.path.basename(f), prediction[0]))
    return resultList
# Out:
# Writing batch_pipeline/batch_vino.py

# %%
# %%writefile $experiment_folder/batch_environment.yml
# name: batch_environment
# dependencies:
# - python=3.6.2
# - scikit-learn
# - pip
# - pip:
#   - azureml-defaults
# Out:
# Writing batch_pipeline/batch_environment.yml

# %% [markdown]
# Next we'll define a run context that includes the Conda environment.

# %%
from azureml.core import Environment
from azureml.core.runconfig import DEFAULT_CPU_IMAGE

# Crear un entorno para el experimento
batch_env = Environment.from_conda_specification("experiment_env", experiment_folder + "/batch_environment.yml")
batch_env.docker.base_image = DEFAULT_CPU_IMAGE
print('Configuración preparada.')
# Out:
# Configuración preparada.

# %% [markdown]
# Se va a usar una canalización que ejecuta una predicción batch y guarda los resultados en un fichero de texto. Para ello, se puede usar **ParallelRunStep** que permite procesar los datos batch en paralelo.

# %%
from azureml.pipeline.steps import ParallelRunConfig, ParallelRunStep
from azureml.data import OutputFileDatasetConfig
from azureml.core.runconfig import DockerConfiguration

output_dir = OutputFileDatasetConfig(name='inferences')

parallel_run_config = ParallelRunConfig(
    source_directory=experiment_folder,
    entry_script="batch_vino.py",
    mini_batch_size="5",
    error_threshold=10,
    output_action="append_row",
    environment=batch_env,
    compute_target=inference_cluster,
    node_count=2)

parallelrun_step = ParallelRunStep(
    name='batch-score-vino',
    parallel_run_config=parallel_run_config,
    inputs=[batch_data_set.as_named_input('vino_batch')],
    output=output_dir,
    arguments=[],
    allow_reuse=True
)

print('Paso definido')
# Out:
# Paso definido

# %% [markdown]
# > **Nota**: Esto tardará tiempo

# %%
from azureml.core import Experiment
from azureml.pipeline.core import Pipeline

pipeline = Pipeline(workspace=ws, steps=[parallelrun_step])
pipeline_run = Experiment(ws, 'nuclio-vino-batch').submit(pipeline)
pipeline_run.wait_for_completion(show_output=True)
# Out:
# Created step batch-score-vino [012ab228][5ba56d6a-4cd2-4521-91c2-1919a8bbe84c], (This step will run and generate new outputs)
# Submitted PipelineRun 3f81b6ca-05a8-4203-94ff-0a858883ea44
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/3f81b6ca-05a8-4203-94ff-0a858883ea44?wsid=/subscriptions/87f9793d-5515-43eb-b182-0f27b97da8b3/resourcegroups/nuclio/workspaces/aml-nuclio&tid=e93a2455-92c2-4ff2-add1-a6a39d490ed6
# PipelineRunId: 3f81b6ca-05a8-4203-94ff-0a858883ea44
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/3f81b6ca-05a8-4203-94ff-0a858883ea44?wsid=/subscriptions/87f9793d-5515-43eb-b182-0f27b97da8b3/resourcegroups/nuclio/workspaces/aml-nuclio&tid=e93a2455-92c2-4ff2-add1-a6a39d490ed6
# PipelineRun Status: NotStarted
# PipelineRun Status: Running
#
#
# StepRunId: 0fd5b744-5f93-4374-9f8a-669b8aa890f2
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/0fd5b744-5f93-4374-9f8a-669b8aa890f2?wsid=/subscriptions/87f9793d-5515-43eb-b182-0f27b97da8b3/resourcegroups/nuclio/workspaces/aml-nuclio&tid=e93a2455-92c2-4ff2-add1-a6a39d490ed6
# StepRun( batch-score-vino ) Status: NotStarted
# StepRun( batch-score-vino ) Status: Queued
# StepRun( batch-score-vino ) Status: Running
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
# 2021/09/02 13:58:17 Downloading source code...
# 2021/09/02 13:58:18 Finished downloading source code
# 2021/09/02 13:58:18 Creating Docker network: acb_default_network, driver: 'bridge'
# 2021/09/02 13:58:18 Successfully set up Docker network: acb_default_network
# 2021/09/02 13:58:18 Setting up Docker configuration...
# 2021/09/02 13:58:19 Successfully set up Docker configuration
# 2021/09/02 13:58:19 Logging in to registry: 8b4996d3aba44b8ebec2f0a5e9f488c7.azurecr.io
# 2021/09/02 13:58:20 Successfully logged into 8b4996d3aba44b8ebec2f0a5e9f488c7.azurecr.io
# 2021/09/02 13:58:20 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/09/02 13:58:20 Scanning for dependencies...
# 2021/09/02 13:58:20 Successfully scanned dependencies
# 2021/09/02 13:58:20 Launching container with name: acb_step_0
# Sending build context to Docker daemon  66.56kB
#
# Step 1/18 : FROM mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210615.v1@sha256:8360f8650a20d3a4932c9ba4e476b2481445c224e16905a68fc6edb718d85e28
# mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210615.v1@sha256:8360f8650a20d3a4932c9ba4e476b2481445c224e16905a68fc6edb718d85e28: Pulling from azureml/openmpi3.1.2-ubuntu18.04
# 4bbfd2c87b75: Pulling fs layer
# d2e110be24e1: Pulling fs layer
# 889a7173dcfe: Pulling fs layer
# 7a7a145ebf57: Pulling fs layer
# 1ae81884420d: Pulling fs layer
# fcdf07e25452: Pulling fs layer
# 95262654cd7f: Pulling fs layer
# 520cb0fab4f5: Pulling fs layer
# 00c1c086d027: Pulling fs layer
# 282c4a3b6fb6: Pulling fs layer
# f4201c7ca826: Pulling fs layer
# 1ae81884420d: Waiting
# fcdf07e25452: Waiting
# 95262654cd7f: Waiting
# 520cb0fab4f5: Waiting
# 00c1c086d027: Waiting
# 282c4a3b6fb6: Waiting
# f4201c7ca826: Waiting
# 7a7a145ebf57: Waiting
# 889a7173dcfe: Download complete
# d2e110be24e1: Verifying Checksum
# d2e110be24e1: Download complete
# 4bbfd2c87b75: Verifying Checksum
# 4bbfd2c87b75: Download complete
# 1ae81884420d: Verifying Checksum
# 1ae81884420d: Download complete
# fcdf07e25452: Verifying Checksum
# fcdf07e25452: Download complete
# 520cb0fab4f5: Verifying Checksum
# 520cb0fab4f5: Download complete
# 7a7a145ebf57: Verifying Checksum
# 7a7a145ebf57: Download complete
# 4bbfd2c87b75: Pull complete
# 282c4a3b6fb6: Verifying Checksum
# 282c4a3b6fb6: Download complete
# 00c1c086d027: Verifying Checksum
# 00c1c086d027: Download complete
# f4201c7ca826: Download complete
# 95262654cd7f: Verifying Checksum
# 95262654cd7f: Download complete
# d2e110be24e1: Pull complete
# 889a7173dcfe: Pull complete
# 7a7a145ebf57: Pull complete
# 1ae81884420d: Pull complete
# fcdf07e25452: Pull complete
# 95262654cd7f: Pull complete
# 520cb0fab4f5: Pull complete
# 00c1c086d027: Pull complete
# 282c4a3b6fb6: Pull complete
# f4201c7ca826: Pull complete
# Digest: sha256:8360f8650a20d3a4932c9ba4e476b2481445c224e16905a68fc6edb718d85e28
# Status: Downloaded newer image for mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210615.v1@sha256:8360f8650a20d3a4932c9ba4e476b2481445c224e16905a68fc6edb718d85e28
#  ---> 6ba46986c29e
# Step 2/18 : USER root
#  ---> Running in 743029569f9e
# Removing intermediate container 743029569f9e
#  ---> ec521e396c9c
# Step 3/18 : RUN mkdir -p $HOME/.cache
#  ---> Running in 63238b18de14
# Removing intermediate container 63238b18de14
#  ---> 36a9b0141578
# Step 4/18 : WORKDIR /
#  ---> Running in 3e6360131a7b
# Removing intermediate container 3e6360131a7b
#  ---> fb2879ce5a70
# Step 5/18 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> d891c0e8e91b
# Step 6/18 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in 7c5fb91bef10
# Removing intermediate container 7c5fb91bef10
#  ---> 1bd03cd44855
# Step 7/18 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> d26c9027b952
# Step 8/18 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in 463a28f5e35a
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# Downloading and Extracting Packages
#
# pip-21.2.2           | 1.8 MB    |            |   0%
# pip-21.2.2           | 1.8 MB    | ########## | 100%
# pip-21.2.2           | 1.8 MB    | ########## | 100%
#
# libstdcxx-ng-9.3.0   | 3.1 MB    |            |   0%
# libstdcxx-ng-9.3.0   | 3.1 MB    | ########## | 100%
# libstdcxx-ng-9.3.0   | 3.1 MB    | ########## | 100%
#
# numpy-1.19.2         | 22 KB     |            |   0%
# numpy-1.19.2         | 22 KB     | ########## | 100%
#
# _libgcc_mutex-0.1    | 3 KB      |            |   0%
# _libgcc_mutex-0.1    | 3 KB      | ########## | 100%
#
# numpy-base-1.19.2    | 4.1 MB    |            |   0%
# numpy-base-1.19.2    | 4.1 MB    | ########## | 100%
# numpy-base-1.19.2    | 4.1 MB    | ########## | 100%
#
# certifi-2021.5.30    | 139 KB    |            |   0%
# certifi-2021.5.30    | 139 KB    | ########## | 100%
#
# libgfortran4-7.5.0   | 995 KB    |            |   0%
# libgfortran4-7.5.0   | 995 KB    | ########## | 100%
#
# sqlite-3.23.1        | 808 KB    |            |   0%
# sqlite-3.23.1        | 808 KB    | ########## | 100%
#
# scipy-1.5.2          | 14.4 MB   |            |   0%
# scipy-1.5.2          | 14.4 MB   | #######5   |  76%
# scipy-1.5.2          | 14.4 MB   | ########## | 100%
# scipy-1.5.2          | 14.4 MB   | ########## | 100%
#
# ca-certificates-2021 | 113 KB    |            |   0%
# ca-certificates-2021 | 113 KB    | ########## | 100%
#
# mkl-service-2.3.0    | 52 KB     |            |   0%
# mkl-service-2.3.0    | 52 KB     | ########## | 100%
#
# libffi-3.2.1         | 48 KB     |            |   0%
# libffi-3.2.1         | 48 KB     | ########## | 100%
#
# libedit-3.1          | 151 KB    |            |   0%
# libedit-3.1          | 151 KB    | ########## | 100%
#
# openssl-1.0.2u       | 2.2 MB    |            |   0%
# openssl-1.0.2u       | 2.2 MB    | ########## | 100%
#
# mkl_fft-1.3.0        | 170 KB    |            |   0%
# mkl_fft-1.3.0        | 170 KB    | ########## | 100%
#
# blas-1.0             | 6 KB      |            |   0%
# blas-1.0             | 6 KB      | ########## | 100%
#
# intel-openmp-2021.3. | 1.4 MB    |            |   0%
# intel-openmp-2021.3. | 1.4 MB    | ########## | 100%
#
# tk-8.6.10            | 3.0 MB    |            |   0%
# tk-8.6.10            | 3.0 MB    | ########## | 100%
# tk-8.6.10            | 3.0 MB    | ########## | 100%
#
# threadpoolctl-2.2.0  | 16 KB     |            |   0%
# threadpoolctl-2.2.0  | 16 KB     | ########## | 100%
#
# setuptools-52.0.0    | 724 KB    |            |   0%
# setuptools-52.0.0    | 724 KB    | ########## | 100%
#
# libgcc-ng-9.3.0      | 4.8 MB    |            |   0%
# libgcc-ng-9.3.0      | 4.8 MB    | ########## | 100%
# libgcc-ng-9.3.0      | 4.8 MB    | ########## | 100%
#
# libgomp-9.3.0        | 311 KB    |            |   0%
# libgomp-9.3.0        | 311 KB    | ########## | 100%
#
# python-3.6.2         | 23.6 MB   |            |   0%
# python-3.6.2         | 23.6 MB   | ####6      |  46%
# python-3.6.2         | 23.6 MB   | ########## | 100%
# python-3.6.2         | 23.6 MB   | ########## | 100%
#
# readline-7.0         | 848 KB    |            |   0%
# readline-7.0         | 848 KB    | ########## | 100%
#
# libgfortran-ng-7.5.0 | 22 KB     |            |   0%
# libgfortran-ng-7.5.0 | 22 KB     | ########## | 100%
#
# scikit-learn-0.24.2  | 5.2 MB    |            |   0%
# scikit-learn-0.24.2  | 5.2 MB    | ########## | 100%
# scikit-learn-0.24.2  | 5.2 MB    | ########## | 100%
#
# ncurses-6.0          | 781 KB    |            |   0%
# ncurses-6.0          | 781 KB    | ########## | 100%
# ncurses-6.0          | 781 KB    | ########## | 100%
#
# xz-5.2.5             | 341 KB    |            |   0%
# xz-5.2.5             | 341 KB    | ########## | 100%
#
# _openmp_mutex-4.5    | 22 KB     |            |   0%
# _openmp_mutex-4.5    | 22 KB     | ########## | 100%
#
# mkl_random-1.1.1     | 327 KB    |            |   0%
# mkl_random-1.1.1     | 327 KB    | ########## | 100%
#
# six-1.16.0           | 18 KB     |            |   0%
# six-1.16.0           | 18 KB     | ########## | 100%
#
# wheel-0.37.0         | 32 KB     |            |   0%
# wheel-0.37.0         | 32 KB     | ########## | 100%
#
# zlib-1.2.11          | 103 KB    |            |   0%
# zlib-1.2.11          | 103 KB    | ########## | 100%
#
# joblib-1.0.1         | 208 KB    |            |   0%
# joblib-1.0.1         | 208 KB    | ########## | 100%
#
# mkl-2020.2           | 138.3 MB  |            |   0%
# mkl-2020.2           | 138.3 MB  | 8          |   8%
# mkl-2020.2           | 138.3 MB  | #8         |  18%
# mkl-2020.2           | 138.3 MB  | ##8        |  28%
# mkl-2020.2           | 138.3 MB  | ###8       |  39%
# mkl-2020.2           | 138.3 MB  | ####8      |  49%
# mkl-2020.2           | 138.3 MB  | #####8     |  59%
# mkl-2020.2           | 138.3 MB  | ######8    |  68%
# mkl-2020.2           | 138.3 MB  | #######8   |  79%
# mkl-2020.2           | 138.3 MB  | ########8  |  89%
# mkl-2020.2           | 138.3 MB  | #########8 |  99%
# mkl-2020.2           | 138.3 MB  | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working...
#
#     Installed package of scikit-learn can be accelerated using scikit-learn-intelex.
#     More details are available here: https://intel.github.io/scikit-learn-intelex
#
#     For example:
#
#         $ conda install scikit-learn-intelex
#         $ python -m sklearnex my_application.py
#
#
#
# done
# Installing pip dependencies: ...working...
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.hyhlad6y.requirements.txt']
# Pip subprocess output:
# Collecting azureml-defaults
#   Downloading azureml_defaults-1.33.0-py3-none-any.whl (3.1 kB)
# Collecting azureml-dataset-runtime[fuse]~=1.33.0
#   Downloading azureml_dataset_runtime-1.33.0-py3-none-any.whl (3.5 kB)
# Collecting azureml-core~=1.33.0
#   Downloading azureml_core-1.33.0.post1-py3-none-any.whl (2.2 MB)
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Collecting opencensus-ext-azure==1.0.8
#   Downloading opencensus_ext_azure-1.0.8-py2.py3-none-any.whl (35 kB)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
# Collecting applicationinsights>=0.11.7
#   Downloading applicationinsights-0.11.10-py2.py3-none-any.whl (55 kB)
# Collecting flask==1.0.3
#   Downloading Flask-1.0.3-py2.py3-none-any.whl (92 kB)
# Collecting gunicorn==20.1.0
#   Downloading gunicorn-20.1.0-py3-none-any.whl (79 kB)
# Collecting werkzeug<=1.0.1,>=0.16.1
#   Downloading Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
# Collecting Jinja2>=2.10
#   Downloading Jinja2-3.0.1-py3-none-any.whl (133 kB)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-2.0.1-py3-none-any.whl (18 kB)
# Collecting click>=5.1
#   Downloading click-8.0.1-py3-none-any.whl (97 kB)
# Requirement already satisfied: setuptools>=3.0 in /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d/lib/python3.6/site-packages (from gunicorn==20.1.0->azureml-defaults->-r /azureml-environment-setup/condaenv.hyhlad6y.requirements.txt (line 1)) (52.0.0.post20210125)
# Collecting opencensus<1.0.0,>=0.7.13
#   Downloading opencensus-0.7.13-py2.py3-none-any.whl (127 kB)
# Collecting psutil>=5.6.3
#   Downloading psutil-5.8.0-cp36-cp36m-manylinux2010_x86_64.whl (291 kB)
# Collecting requests>=2.19.0
#   Downloading requests-2.26.0-py2.py3-none-any.whl (62 kB)
# Collecting contextlib2<1.0.0
#   Downloading contextlib2-0.6.0.post1-py2.py3-none-any.whl (9.8 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<4.0.0
#   Downloading cryptography-3.4.8-cp36-abi3-manylinux_2_24_x86_64.whl (3.0 MB)
# Collecting azure-mgmt-authorization<1.0.0,>=0.40.0
#   Downloading azure_mgmt_authorization-0.61.0-py2.py3-none-any.whl (94 kB)
# Collecting jmespath<1.0.0
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting azure-mgmt-resource<15.0.0,>=1.2.1
#   Downloading azure_mgmt_resource-13.0.0-py2.py3-none-any.whl (1.3 MB)
# Collecting SecretStorage<4.0.0
#   Downloading SecretStorage-3.3.1-py3-none-any.whl (15 kB)
# Collecting urllib3<=1.26.5,>=1.23
#   Downloading urllib3-1.26.5-py2.py3-none-any.whl (138 kB)
# Collecting adal<=1.2.7,>=1.2.0
#   Downloading adal-1.2.7-py2.py3-none-any.whl (55 kB)
# Collecting msrest<1.0.0,>=0.5.1
#   Downloading msrest-0.6.21-py2.py3-none-any.whl (85 kB)
# Collecting pytz
#   Downloading pytz-2021.1-py2.py3-none-any.whl (510 kB)
# Collecting pathspec<1.0.0
#   Downloading pathspec-0.9.0-py2.py3-none-any.whl (31 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting PyJWT<3.0.0
#   Downloading PyJWT-2.1.0-py3-none-any.whl (16 kB)
# Collecting ruamel.yaml<0.17.5,>=0.15.35
#   Downloading ruamel.yaml-0.17.4-py3-none-any.whl (101 kB)
# Collecting docker<5.0.0
#   Downloading docker-4.4.4-py2.py3-none-any.whl (147 kB)
# Collecting jsonpickle<3.0.0
#   Downloading jsonpickle-2.0.0-py2.py3-none-any.whl (37 kB)
# Collecting python-dateutil<3.0.0,>=2.7.3
#   Downloading python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
# Collecting azure-mgmt-keyvault<10.0.0,>=0.40.0
#   Downloading azure_mgmt_keyvault-9.1.0-py2.py3-none-any.whl (314 kB)
# Collecting pyopenssl<21.0.0
#   Downloading pyOpenSSL-20.0.1-py2.py3-none-any.whl (54 kB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-8.1.0-py2.py3-none-any.whl (796 kB)
# Collecting msrestazure<=0.6.4,>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting azure-common<2.0.0,>=1.1.12
#   Downloading azure_common-1.1.27-py2.py3-none-any.whl (12 kB)
# Collecting azure-mgmt-storage<16.0.0,>=1.5.0
#   Downloading azure_mgmt_storage-11.2.0-py2.py3-none-any.whl (547 kB)
# Collecting ndg-httpsclient<=0.5.1
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting azure-mgmt-core<2.0.0,>=1.2.0
#   Downloading azure_mgmt_core-1.3.0-py2.py3-none-any.whl (25 kB)
# Collecting azure-core<2.0.0,>=1.15.0
#   Downloading azure_core-1.17.0-py2.py3-none-any.whl (165 kB)
# Requirement already satisfied: six>=1.11.0 in /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d/lib/python3.6/site-packages (from azure-core<2.0.0,>=1.15.0->azure-mgmt-core<2.0.0,>=1.2.0->azure-mgmt-containerregistry>=2.0.0->azureml-core~=1.33.0->azureml-defaults->-r /azureml-environment-setup/condaenv.hyhlad6y.requirements.txt (line 1)) (1.16.0)
# Collecting azureml-dataprep<2.21.0a,>=2.20.0a
#   Downloading azureml_dataprep-2.20.1-py3-none-any.whl (39.4 MB)
# Collecting pyarrow<4.0.0,>=0.17.0
#   Downloading pyarrow-3.0.0-cp36-cp36m-manylinux2014_x86_64.whl (20.7 MB)
# Requirement already satisfied: numpy!=1.19.3 in /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d/lib/python3.6/site-packages (from azureml-dataset-runtime[fuse]~=1.33.0->azureml-defaults->-r /azureml-environment-setup/condaenv.hyhlad6y.requirements.txt (line 1)) (1.19.2)
# Collecting fusepy<4.0.0,>=3.0.1
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Collecting azureml-dataprep-native<39.0.0,>=38.0.0
#   Downloading azureml_dataprep_native-38.0.0-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting azure-identity<1.5.0,>=1.2.0
#   Downloading azure_identity-1.4.1-py2.py3-none-any.whl (86 kB)
# Collecting cloudpickle<2.0.0,>=1.1.0
#   Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Collecting dotnetcore2<3.0.0,>=2.1.14
#   Downloading dotnetcore2-2.1.21-py3-none-manylinux1_x86_64.whl (28.7 MB)
# Collecting azureml-dataprep-rslex<1.19.0a,>=1.18.0dev0
#   Downloading azureml_dataprep_rslex-1.18.2-cp36-cp36m-manylinux1_x86_64.whl (10.4 MB)
# Collecting msal-extensions~=0.2.2
#   Downloading msal_extensions-0.2.2-py2.py3-none-any.whl (15 kB)
# Collecting msal<2.0.0,>=1.3.0
#   Downloading msal-1.14.0-py2.py3-none-any.whl (75 kB)
# Collecting importlib-metadata
#   Downloading importlib_metadata-4.8.1-py3-none-any.whl (17 kB)
# Collecting cffi>=1.12
#   Downloading cffi-1.14.6-cp36-cp36m-manylinux1_x86_64.whl (401 kB)
# Collecting pycparser
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-1.2.1-py2.py3-none-any.whl (52 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.6.0-py2.py3-none-any.whl (19 kB)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.0.1-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (30 kB)
# Collecting portalocker~=1.0
#   Downloading portalocker-1.7.1-py2.py3-none-any.whl (10 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d/lib/python3.6/site-packages (from msrest<1.0.0,>=0.5.1->azureml-core~=1.33.0->azureml-defaults->-r /azureml-environment-setup/condaenv.hyhlad6y.requirements.txt (line 1)) (2021.5.30)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting opencensus-context==0.1.2
#   Downloading opencensus_context-0.1.2-py2.py3-none-any.whl (4.4 kB)
# Collecting google-api-core<2.0.0,>=1.0.0
#   Downloading google_api_core-1.31.2-py2.py3-none-any.whl (93 kB)
# Collecting contextvars
#   Downloading contextvars-2.4.tar.gz (9.6 kB)
# Collecting packaging>=14.3
#   Downloading packaging-21.0-py3-none-any.whl (40 kB)
# Collecting googleapis-common-protos<2.0dev,>=1.6.0
#   Downloading googleapis_common_protos-1.53.0-py2.py3-none-any.whl (198 kB)
# Collecting google-auth<2.0dev,>=1.25.0
#   Downloading google_auth-1.35.0-py2.py3-none-any.whl (152 kB)
# Collecting protobuf>=3.12.0
#   Downloading protobuf-3.17.3-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.7.2-py3-none-any.whl (34 kB)
# Collecting cachetools<5.0,>=2.0.0
#   Downloading cachetools-4.2.2-py3-none-any.whl (11 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting pyparsing>=2.0.2
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
# Collecting idna<4,>=2.5
#   Downloading idna-3.2-py3-none-any.whl (59 kB)
# Collecting charset-normalizer~=2.0.0
#   Downloading charset_normalizer-2.0.4-py3-none-any.whl (36 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.1-py2.py3-none-any.whl (146 kB)
# Collecting ruamel.yaml.clib>=0.1.2
#   Downloading ruamel.yaml.clib-0.2.6-cp36-cp36m-manylinux1_x86_64.whl (552 kB)
# Collecting jeepney>=0.6
#   Downloading jeepney-0.7.1-py3-none-any.whl (54 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting immutables>=0.9
#   Downloading immutables-0.16-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (103 kB)
# Collecting typing-extensions>=3.7.4.3
#   Downloading typing_extensions-3.10.0.2-py3-none-any.whl (26 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.5.0-py3-none-any.whl (5.7 kB)
# Building wheels for collected packages: json-logging-py, fusepy, contextvars
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3925 sha256=dca7c0bcd7f6304ce26cbf628f473ac4f0ec8d9e9a4b5ed531037ae53250fc8a
#   Stored in directory: /root/.cache/pip/wheels/e2/1d/52/535a274b9c2ce7d4064838f2bdb62013801281ef7d7f21e2ee
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10502 sha256=7b4a07da828f7451c04b36cbd21d08ed1c97ce2f019329f291763d20740c8a2f
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
#   Building wheel for contextvars (setup.py): started
#   Building wheel for contextvars (setup.py): finished with status 'done'
#   Created wheel for contextvars: filename=contextvars-2.4-py3-none-any.whl size=7665 sha256=966f44682c4378e0cb7ef007d0944c75275f54e1d11f22311f1fab0351b0ee97
#   Stored in directory: /root/.cache/pip/wheels/41/11/53/911724983aa48deb94792432e14e518447212dd6c5477d49d3
# Successfully built json-logging-py fusepy contextvars
# Installing collected packages: pycparser, cffi, urllib3, PyJWT, idna, cryptography, charset-normalizer, requests, typing-extensions, pyasn1, portalocker, oauthlib, msal, rsa, requests-oauthlib, python-dateutil, pyparsing, pyasn1-modules, protobuf, msal-extensions, isodate, immutables, distro, cachetools, azure-core, zipp, pytz, packaging, msrest, googleapis-common-protos, google-auth, dotnetcore2, contextvars, cloudpickle, azureml-dataprep-rslex, azureml-dataprep-native, azure-identity, adal, websocket-client, ruamel.yaml.clib, pyopenssl, pyarrow, opencensus-context, msrestazure, MarkupSafe, jeepney, importlib-metadata, google-api-core, backports.weakref, azureml-dataprep, azure-mgmt-core, azure-common, werkzeug, SecretStorage, ruamel.yaml, psutil, pathspec, opencensus, ndg-httpsclient, jsonpickle, jmespath, Jinja2, itsdangerous, fusepy, docker, contextlib2, click, backports.tempfile, azureml-dataset-runtime, azure-mgmt-storage, azure-mgmt-resource, azure-mgmt-keyvault, azure-mgmt-containerregistry, azure-mgmt-authorization, azure-graphrbac, opencensus-ext-azure, json-logging-py, gunicorn, flask, configparser, azureml-core, applicationinsights, azureml-defaults
# Successfully installed Jinja2-3.0.1 MarkupSafe-2.0.1 PyJWT-2.1.0 SecretStorage-3.3.1 adal-1.2.7 applicationinsights-0.11.10 azure-common-1.1.27 azure-core-1.17.0 azure-graphrbac-0.61.1 azure-identity-1.4.1 azure-mgmt-authorization-0.61.0 azure-mgmt-containerregistry-8.1.0 azure-mgmt-core-1.3.0 azure-mgmt-keyvault-9.1.0 azure-mgmt-resource-13.0.0 azure-mgmt-storage-11.2.0 azureml-core-1.33.0.post1 azureml-dataprep-2.20.1 azureml-dataprep-native-38.0.0 azureml-dataprep-rslex-1.18.2 azureml-dataset-runtime-1.33.0 azureml-defaults-1.33.0 backports.tempfile-1.0 backports.weakref-1.0.post1 cachetools-4.2.2 cffi-1.14.6 charset-normalizer-2.0.4 click-8.0.1 cloudpickle-1.6.0 configparser-3.7.4 contextlib2-0.6.0.post1 contextvars-2.4 cryptography-3.4.8 distro-1.6.0 docker-4.4.4 dotnetcore2-2.1.21 flask-1.0.3 fusepy-3.0.1 google-api-core-1.31.2 google-auth-1.35.0 googleapis-common-protos-1.53.0 gunicorn-20.1.0 idna-3.2 immutables-0.16 importlib-metadata-4.8.1 isodate-0.6.0 itsdangerous-2.0.1 jeepney-0.7.1 jmespath-0.10.0 json-logging-py-0.2 jsonpickle-2.0.0 msal-1.14.0 msal-extensions-0.2.2 msrest-0.6.21 msrestazure-0.6.4 ndg-httpsclient-0.5.1 oauthlib-3.1.1 opencensus-0.7.13 opencensus-context-0.1.2 opencensus-ext-azure-1.0.8 packaging-21.0 pathspec-0.9.0 portalocker-1.7.1 protobuf-3.17.3 psutil-5.8.0 pyarrow-3.0.0 pyasn1-0.4.8 pyasn1-modules-0.2.8 pycparser-2.20 pyopenssl-20.0.1 pyparsing-2.4.7 python-dateutil-2.8.2 pytz-2021.1 requests-2.26.0 requests-oauthlib-1.3.0 rsa-4.7.2 ruamel.yaml-0.17.4 ruamel.yaml.clib-0.2.6 typing-extensions-3.10.0.2 urllib3-1.26.5 websocket-client-1.2.1 werkzeug-1.0.1 zipp-3.5.0
#
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 4.10.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# WARNING: /root/.conda/pkgs does not exist
#
# Removing intermediate container 463a28f5e35a
#  ---> c64eff1b6f70
# Step 9/18 : ENV PATH /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d/bin:$PATH
#  ---> Running in 3e20b12c3c63
# Removing intermediate container 3e20b12c3c63
#  ---> e33711928512
# Step 10/18 : COPY azureml-environment-setup/send_conda_dependencies.py azureml-environment-setup/send_conda_dependencies.py
#  ---> 83d5a9377259
# Step 11/18 : COPY azureml-environment-setup/environment_context.json azureml-environment-setup/environment_context.json
#  ---> 3c5fe0e79fea
# Step 12/18 : RUN python /azureml-environment-setup/send_conda_dependencies.py -p /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d
#  ---> Running in 7ab73ddb4fe0
# Report materialized dependencies for the environment
# Reading environment context
# Exporting conda environment
# Sending request with materialized conda environment details
# Successfully sent materialized environment details
# Removing intermediate container 7ab73ddb4fe0
#  ---> 7733f7452f01
# Step 13/18 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d
#  ---> Running in 8bc66beeda2c
# Removing intermediate container 8bc66beeda2c
#  ---> 29332524262d
# Step 14/18 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_e220b045f6c3c3008b1a386af067185d/lib:$LD_LIBRARY_PATH
#  ---> Running in 7f1aaeebb6c8
# Removing intermediate container 7f1aaeebb6c8
#  ---> f6bd6bc2d8c7
# Step 15/18 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> 28e8d3b2ab97
# Step 16/18 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in b410d554f9a0
# Removing intermediate container b410d554f9a0
#  ---> a8c519d09cce
# Step 17/18 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in dce2dfd12396
# Removing intermediate container dce2dfd12396
#  ---> 3d18696e557f
# Step 18/18 : CMD ["bash"]
#  ---> Running in 3a102c781659
# Removing intermediate container 3a102c781659
#  ---> 4ceed061f9df
# Successfully built 4ceed061f9df
# Successfully tagged 8b4996d3aba44b8ebec2f0a5e9f488c7.azurecr.io/azureml/azureml_8f26716135fe6100d42713cc1f1fffdc:latest
# Successfully tagged 8b4996d3aba44b8ebec2f0a5e9f488c7.azurecr.io/azureml/azureml_8f26716135fe6100d42713cc1f1fffdc:1
# 2021/09/02 14:00:06 Successfully executed container: acb_step_0
# 2021/09/02 14:00:06 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/09/02 14:00:06 Pushing image: 8b4996d3aba44b8ebec2f0a5e9f488c7.azurecr.io/azureml/azureml_8f26716135fe6100d42713cc1f1fffdc:1, attempt 1
# The push refers to repository [8b4996d3aba44b8ebec2f0a5e9f488c7.azurecr.io/azureml/azureml_8f26716135fe6100d42713cc1f1fffdc]
# c0d6a5e833b8: Preparing
# 760fd331f1c7: Preparing
# 76276da68993: Preparing
# 3ef57fc4de74: Preparing
# 95f5d6429dd3: Preparing
# 1390e1aca72d: Preparing
# 9ab34a087997: Preparing
# c7989bd83b86: Preparing
# ea0ae71a2f70: Preparing
# fe09032048fd: Preparing
# cbe733e9771d: Preparing
# 74218ef6464a: Preparing
# 5ba1f0778181: Preparing
# 658e73e9fcdf: Preparing
# b48835f37b9c: Preparing
# a7c59d42f9e5: Preparing
# bb7a0d4412a3: Preparing
# 5f08512fd434: Preparing
# c7bb31fc0e08: Preparing
# 50858308da3d: Preparing
# 1390e1aca72d: Waiting
# 9ab34a087997: Waiting
# c7989bd83b86: Waiting
# ea0ae71a2f70: Waiting
# fe09032048fd: Waiting
# cbe733e9771d: Waiting
# 74218ef6464a: Waiting
# 5ba1f0778181: Waiting
# 658e73e9fcdf: Waiting
# b48835f37b9c: Waiting
# a7c59d42f9e5: Waiting
# bb7a0d4412a3: Waiting
# 5f08512fd434: Waiting
# c7bb31fc0e08: Waiting
# 50858308da3d: Waiting
# 76276da68993: Pushed
# 3ef57fc4de74: Pushed
# c0d6a5e833b8: Pushed
# 760fd331f1c7: Pushed
# 1390e1aca72d: Pushed
# c7989bd83b86: Pushed
# 9ab34a087997: Pushed
# ea0ae71a2f70: Pushed
# fe09032048fd: Pushed
# cbe733e9771d: Pushed
# 5ba1f0778181: Pushed
# 74218ef6464a: Pushed
# b48835f37b9c: Pushed
# a7c59d42f9e5: Pushed
# 5f08512fd434: Pushed
# c7bb31fc0e08: Pushed
# 658e73e9fcdf: Pushed
# 50858308da3d: Pushed
# bb7a0d4412a3: Pushed
# 95f5d6429dd3: Pushed
# 1: digest: sha256:d91a5c32989c2938bf0f62ee5959b673f00e6c826f2d7dd8d4d34653d87058e2 size: 4514
# 2021/09/02 14:01:55 Successfully pushed image: 8b4996d3aba44b8ebec2f0a5e9f488c7.azurecr.io/azureml/azureml_8f26716135fe6100d42713cc1f1fffdc:1
# 2021/09/02 14:01:55 Executing step ID: acb_step_2. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/09/02 14:01:55 Pushing image: 8b4996d3aba44b8ebec2f0a5e9f488c7.azurecr.io/azureml/azureml_8f26716135fe6100d42713cc1f1fffdc:latest, attempt 1
# The push refers to repository [8b4996d3aba44b8ebec2f0a5e9f488c7.azurecr.io/azureml/azureml_8f26716135fe6100d42713cc1f1fffdc]
# c0d6a5e833b8: Preparing
# 760fd331f1c7: Preparing
# 76276da68993: Preparing
# 3ef57fc4de74: Preparing
# 95f5d6429dd3: Preparing
# 1390e1aca72d: Preparing
# 9ab34a087997: Preparing
# c7989bd83b86: Preparing
# ea0ae71a2f70: Preparing
# fe09032048fd: Preparing
# cbe733e9771d: Preparing
# 74218ef6464a: Preparing
# 5ba1f0778181: Preparing
# 658e73e9fcdf: Preparing
# b48835f37b9c: Preparing
# a7c59d42f9e5: Preparing
# bb7a0d4412a3: Preparing
# 5f08512fd434: Preparing
# c7bb31fc0e08: Preparing
# 50858308da3d: Preparing
# 1390e1aca72d: Waiting
# 9ab34a087997: Waiting
# c7989bd83b86: Waiting
# ea0ae71a2f70: Waiting
# fe09032048fd: Waiting
# cbe733e9771d: Waiting
# 74218ef6464a: Waiting
# 5ba1f0778181: Waiting
# 658e73e9fcdf: Waiting
# b48835f37b9c: Waiting
# a7c59d42f9e5: Waiting
# bb7a0d4412a3: Waiting
# 5f08512fd434: Waiting
# c7bb31fc0e08: Waiting
# 50858308da3d: Waiting
# 760fd331f1c7: Layer already exists
# 95f5d6429dd3: Layer already exists
# c0d6a5e833b8: Layer already exists
# 3ef57fc4de74: Layer already exists
# 76276da68993: Layer already exists
# 1390e1aca72d: Layer already exists
# c7989bd83b86: Layer already exists
# 9ab34a087997: Layer already exists
# ea0ae71a2f70: Layer already exists
# fe09032048fd: Layer already exists
# 74218ef6464a: Layer already exists
# 5ba1f0778181: Layer already exists
# cbe733e9771d: Layer already exists
# b48835f37b9c: Layer already exists
# 658e73e9fcdf: Layer already exists
# a7c59d42f9e5: Layer already exists
# bb7a0d4412a3: Layer already exists
# 5f08512fd434: Layer already exists
# c7bb31fc0e08: Layer already exists
# 50858308da3d: Layer already exists
# latest: digest: sha256:d91a5c32989c2938bf0f62ee5959b673f00e6c826f2d7dd8d4d34653d87058e2 size: 4514
# 2021/09/02 14:01:56 Successfully pushed image: 8b4996d3aba44b8ebec2f0a5e9f488c7.azurecr.io/azureml/azureml_8f26716135fe6100d42713cc1f1fffdc:latest
# 2021/09/02 14:01:56 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 106.612057)
# 2021/09/02 14:01:56 Populating digests for step ID: acb_step_0...
# 2021/09/02 14:01:58 Successfully populated digests for step ID: acb_step_0
# 2021/09/02 14:01:58 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 108.529086)
# 2021/09/02 14:01:58 Step ID: acb_step_2 marked as successful (elapsed time in seconds: 1.377544)
# 2021/09/02 14:01:58 The following dependencies were found:
# 2021/09/02 14:01:58
# - image:
#     registry: 8b4996d3aba44b8ebec2f0a5e9f488c7.azurecr.io
#     repository: azureml/azureml_8f26716135fe6100d42713cc1f1fffdc
#     tag: latest
#     digest: sha256:d91a5c32989c2938bf0f62ee5959b673f00e6c826f2d7dd8d4d34653d87058e2
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/openmpi3.1.2-ubuntu18.04
#     tag: 20210615.v1
#     digest: sha256:8360f8650a20d3a4932c9ba4e476b2481445c224e16905a68fc6edb718d85e28
#   git: {}
# - image:
#     registry: 8b4996d3aba44b8ebec2f0a5e9f488c7.azurecr.io
#     repository: azureml/azureml_8f26716135fe6100d42713cc1f1fffdc
#     tag: "1"
#     digest: sha256:d91a5c32989c2938bf0f62ee5959b673f00e6c826f2d7dd8d4d34653d87058e2
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/openmpi3.1.2-ubuntu18.04
#     tag: 20210615.v1
#     digest: sha256:8360f8650a20d3a4932c9ba4e476b2481445c224e16905a68fc6edb718d85e28
#   git: {}
#
#
# Run ID: dd2 was successful after 3m42s
#
# Streaming azureml-logs/55_azureml-execution-tvmps_0c6f1a20cf6ddb4b5bf56da4019923989b700fa7cdb4fc151162e219c66540f9_d.txt
# ========================================================================================================================
# 2021-09-02T14:09:23Z Running following command: /bin/bash -c sudo blobfuse /mnt/batch/tasks/shared/LS_root/jobs/aml-nuclio/azureml/0fd5b744-5f93-4374-9f8a-669b8aa890f2/mounts/workspaceblobstore --tmp-path=/mnt/batch/tasks/shared/LS_root/jobs/aml-nuclio/azureml/0fd5b744-5f93-4374-9f8a-669b8aa890f2/caches/workspaceblobstore -o ro --file-cache-timeout-in-seconds=1000000 --cache-size-mb=24796 -o nonempty -o allow_other --config-file=/mnt/batch/tasks/shared/LS_root/jobs/aml-nuclio/azureml/0fd5b744-5f93-4374-9f8a-669b8aa890f2/configs/workspaceblobstore.cfg --log-level=LOG_WARNING
# 2021-09-02T14:09:23Z Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/aml-nuclio/azureml/0fd5b744-5f93-4374-9f8a-669b8aa890f2/mounts/workspaceblobstore
# 2021-09-02T14:09:23Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-09-02T14:09:23Z Starting output-watcher...
# 2021-09-02T14:09:23Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2021-09-02T14:09:24Z Executing 'Copy ACR Details file' on 10.0.0.7
# 2021-09-02T14:09:24Z Executing 'Copy ACR Details file' on 10.0.0.5
# 2021-09-02T14:09:24Z Copy ACR Details file succeeded on 10.0.0.5. Output:
# >>>
# >>>
# 2021-09-02T14:09:24Z Copy ACR Details file succeeded on 10.0.0.7. Output:
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_1e5b59c0734bdc528077f509e1d397fe
# 92473f7ef455: Pulling fs layer
# fb52bde70123: Pulling fs layer
# 64788f86be3f: Pulling fs layer
# 33f6d5f2e001: Pulling fs layer
# eeb715f1b6ae: Pulling fs layer
# fe519cf36537: Pulling fs layer
# 58ff99196c15: Pulling fs layer
# 9b13f06a8eff: Pulling fs layer
# 2d4e93adbf58: Pulling fs layer
# 6ee7c3767844: Pulling fs layer
# 62cfc3ccb8ab: Pulling fs layer
# 4a7af9d757ee: Pulling fs layer
# 886c27cf0865: Pulling fs layer
# 7c9062f12448: Pulling fs layer
# 7268e886f68a: Pulling fs layer
# e1fdaab561c7: Pulling fs layer
# ccb2816215bd: Pulling fs layer
# 55d70b17f345: Pulling fs layer
# 33f6d5f2e001: Waiting
# eeb715f1b6ae: Waiting
# fe519cf36537: Waiting
# 58ff99196c15: Waiting
# 9b13f06a8eff: Waiting
# 2d4e93adbf58: Waiting
# 6ee7c3767844: Waiting
# 62cfc3ccb8ab: Waiting
# 4a7af9d757ee: Waiting
# 886c27cf0865: Waiting
# 7c9062f12448: Waiting
# 7268e886f68a: Waiting
# e1fdaab561c7: Waiting
# ccb2816215bd: Waiting
# 55d70b17f345: Waiting
# 64788f86be3f: Verifying Checksum
# 64788f86be3f: Download complete
# fb52bde70123: Verifying Checksum
# fb52bde70123: Download complete
# 33f6d5f2e001: Verifying Checksum
# 33f6d5f2e001: Download complete
# 92473f7ef455: Verifying Checksum
# 92473f7ef455: Download complete
# 58ff99196c15: Verifying Checksum
# 58ff99196c15: Download complete
# fe519cf36537: Verifying Checksum
# fe519cf36537: Download complete
# eeb715f1b6ae: Verifying Checksum
# eeb715f1b6ae: Download complete
# 6ee7c3767844: Verifying Checksum
# 6ee7c3767844: Download complete
# 9b13f06a8eff: Verifying Checksum
# 9b13f06a8eff: Download complete
# 4a7af9d757ee: Verifying Checksum
# 4a7af9d757ee: Download complete
# 62cfc3ccb8ab: Verifying Checksum
# 62cfc3ccb8ab: Download complete
# 886c27cf0865: Verifying Checksum
# 886c27cf0865: Download complete
# 2d4e93adbf58: Verifying Checksum
# 2d4e93adbf58: Download complete
# e1fdaab561c7: Verifying Checksum
# e1fdaab561c7: Download complete
# 7268e886f68a: Verifying Checksum
# 7268e886f68a: Download complete
# ccb2816215bd: Verifying Checksum
# ccb2816215bd: Download complete
# 55d70b17f345: Verifying Checksum
# 55d70b17f345: Download complete
# 92473f7ef455: Pull complete
# fb52bde70123: Pull complete
# 64788f86be3f: Pull complete
# 33f6d5f2e001: Pull complete
# 7c9062f12448: Verifying Checksum
# 7c9062f12448: Download complete
# eeb715f1b6ae: Pull complete
# fe519cf36537: Pull complete
# 58ff99196c15: Pull complete
# 9b13f06a8eff: Pull complete
# 2d4e93adbf58: Pull complete
# 6ee7c3767844: Pull complete
# 62cfc3ccb8ab: Pull complete
# 4a7af9d757ee: Pull complete
# 886c27cf0865: Pull complete
#
# Streaming azureml-logs/65_job_prep-tvmps_0c6f1a20cf6ddb4b5bf56da4019923989b700fa7cdb4fc151162e219c66540f9_d.txt
# ===============================================================================================================
# [2021-09-02T14:09:51.470337] Entering job preparation.
# [2021-09-02T14:09:51.960985] Starting job preparation.
# [2021-09-02T14:09:51.961013] Extracting the control code.
# [2021-09-02T14:09:51.961429] Starting extract_project.
# [2021-09-02T14:09:51.961467] Starting to extract zip file.
# [2021-09-02T14:09:51.975338] Finished extracting zip file.
# [2021-09-02T14:09:51.978396] Using urllib.request Python 3.0 or later
# [2021-09-02T14:09:51.978464] Start fetching snapshots.
# [2021-09-02T14:09:51.978522] Start fetching snapshot.
# [2021-09-02T14:09:51.978551] Retrieving project from snapshot: f57c5dca-a166-4ceb-b341-9a398593aa01
# Starting the daemon thread to refresh tokens in background for process with pid = 51
# [2021-09-02T14:09:52.177614] Finished fetching snapshot.
# [2021-09-02T14:09:52.177646] Start fetching snapshot.
# [2021-09-02T14:09:52.177705] Retrieving project from snapshot: 0fcc8538-9ace-4b52-ad65-b6964c0edf20
# [2021-09-02T14:09:57.399663] Finished fetching snapshot.
# [2021-09-02T14:09:57.399695] Finished fetching snapshots.
# [2021-09-02T14:09:57.399782] Finished extract_project.
# [2021-09-02T14:09:57.399867] Finished fetching and extracting the control code.
# [2021-09-02T14:09:57.406597] Start run_history_prep.
# [2021-09-02T14:09:57.412359] Job preparation is complete.
# [2021-09-02T14:09:57.412605] Entering Data Context Managers in Sidecar
# [2021-09-02T14:09:57.413305] Running Sidecar prep cmd...
# [2021-09-02T14:09:57.740918] INFO azureml.sidecar.sidecar: Received task: enter_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/aml-nuclio/azureml/0fd5b744-5f93-4374-9f8a-669b8aa890f2/wd/azureml/0fd5b744-5f93-4374-9f8a-669b8aa890f2
# [2021-09-02T14:09:57.741657] INFO azureml.sidecar.sidecar: Invoking "enter_contexts" task with Context Managers: {"context_managers": ["Dataset:context_managers.Datasets"]}
# Enter __enter__ of DatasetContextManager
# SDK version: azureml-core==1.32.0 azureml-dataprep==2.20.1. Session id: 155f4207-2e27-4f59-8eba-1acffbc71be7. Run id: 0fd5b744-5f93-4374-9f8a-669b8aa890f2.
# Processing 'vino_batch'.
# Mode: 'mount'.
# Path on compute is specified: 'False'.
# Processing dataset FileDataset
# {
#   "source": [
#     "('workspaceblobstore', 'batch-data/')"
#   ],
#   "definition": [
#     "GetDatastoreFiles"
#   ],
#   "registration": {
#     "id": "0ed87060-2ae1-433b-b413-7ae68aff6bc4",
#     "name": "batch-data",
#     "version": 1,
#     "description": "batch data",
#     "workspace": "Workspace.create(name='aml-nuclio', subscription_id='87f9793d-5515-43eb-b182-0f27b97da8b3', resource_group='nuclio')"
#   }
# }
# Mounting vino_batch to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/aml-nuclio/azureml/0fd5b744-5f93-4374-9f8a-669b8aa890f2/wd/vino_batch_0ed87060-2ae1-433b-b413-7ae68aff6bc4.
# Mounted vino_batch to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/aml-nuclio/azureml/0fd5b744-5f93-4374-9f8a-669b8aa890f2/wd/vino_batch_0ed87060-2ae1-433b-b413-7ae68aff6bc4 as folder.
# Processing 'inferences'.
# Mode: 'mount'.
# Path on compute is specified: '/mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/aml-nuclio/azureml/0fd5b744-5f93-4374-9f8a-669b8aa890f2/wd/inferences_workspaceblobstore'.
# Already registered authentication for run id: 0fd5b744-5f93-4374-9f8a-669b8aa890f2
# Mounted inferences to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/aml-nuclio/azureml/0fd5b744-5f93-4374-9f8a-669b8aa890f2/wd/inferences_workspaceblobstore.
# Exit __enter__ of DatasetContextManager
# Set Dataset vino_batch's target path to /mnt/batch/tasks/shared/LS_root/jobs/aml-nuclio/azureml/0fd5b744-5f93-4374-9f8a-669b8aa890f2/wd/vino_batch_0ed87060-2ae1-433b-b413-7ae68aff6bc4
# Set OutputDataset inferences's target path to /tmp/cf0b3ff3-26ab-4ffe-803c-76f49337eca6
# [2021-09-02T14:10:10.462798] INFO azureml.sidecar.task.enter_contexts: Entered Context Managers
# [2021-09-02T14:10:11.093517] Ran Sidecar prep cmd.
# [2021-09-02T14:10:11.093602] Running Context Managers in Sidecar complete.
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
# 2021/09/02 14:10:48 Starting App Insight Logger for task:  runTaskLet
# 2021/09/02 14:10:48 Version: 3.0.01695.0004 Branch: .SourceBranch Commit: d8186cb
# 2021/09/02 14:10:48 Attempt 1 of http call to http://10.0.0.5:16384/sendlogstoartifacts/info
# 2021/09/02 14:10:48 Send process info logs to master server succeeded
# 2021/09/02 14:10:48 Attempt 1 of http call to http://10.0.0.5:16384/sendlogstoartifacts/status
# 2021/09/02 14:10:48 Send process info logs to master server succeeded
# [2021-09-02T14:10:48.973453] Entering context manager injector.
# [2021-09-02T14:10:49.388748] context_manager_injector.py Command line Options: Namespace(inject=['ProjectPythonPath:context_managers.ProjectPythonPath', 'Dataset:context_managers.Datasets', 'RunHistory:context_managers.RunHistory', 'TrackUserError:context_managers.TrackUserError'], invocation=['driver/amlbi_main.py', '--client_sdk_version', '1.32.0', '--scoring_module_name', 'batch_vino.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', 'DatasetOutputConfig:inferences', '--input_fds_0', 'vino_batch'])
# Script type = None
# [2021-09-02T14:10:49.392273] Entering Run History Context Manager.
# [2021-09-02T14:10:49.986467] Current directory: /mnt/batch/tasks/shared/LS_root/jobs/aml-nuclio/azureml/0fd5b744-5f93-4374-9f8a-669b8aa890f2/wd/azureml/0fd5b744-5f93-4374-9f8a-669b8aa890f2
# [2021-09-02T14:10:49.986712] Preparing to call script [driver/amlbi_main.py] with arguments:['--client_sdk_version', '1.32.0', '--scoring_module_name', 'batch_vino.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', '$inferences', '--input_fds_0', 'vino_batch']
# [2021-09-02T14:10:49.986740] After variable expansion, calling script [driver/amlbi_main.py] with arguments:['--client_sdk_version', '1.32.0', '--scoring_module_name', 'batch_vino.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', '/tmp/cf0b3ff3-26ab-4ffe-803c-76f49337eca6', '--input_fds_0', 'vino_batch']
#
# 2021/09/02 14:10:53 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 1
# FilteredData: 0.
#
#
# [2021-09-02T14:11:41.126343] The experiment completed successfully. Finalizing run...
# Cleaning up all outstanding Run operations, waiting 900.0 seconds
# 3 items cleaning up...
# Cleanup took 0.31615734100341797 seconds
# [2021-09-02T14:11:41.580087] Finished context manager injector.
# 2021/09/02 14:11:42 Attempt 1 of http call to http://10.0.0.5:16384/sendlogstoartifacts/status
# 2021/09/02 14:11:42 Send process info logs to master server succeeded
# 2021/09/02 14:11:42 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 2
# FilteredData: 0.
# 2021/09/02 14:11:42 Process Exiting with Code:  0
# 2021/09/02 14:11:43 All App Insights Logs was sent successfully or the close timeout of 10 was reached
#
# Streaming azureml-logs/75_job_post-tvmps_0c6f1a20cf6ddb4b5bf56da4019923989b700fa7cdb4fc151162e219c66540f9_d.txt
# ===============================================================================================================
# [2021-09-02T14:11:43.712507] Entering job release
# [2021-09-02T14:11:44.390008] Starting job release
# [2021-09-02T14:11:44.390505] Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 351
# [2021-09-02T14:11:44.390875] job release stage : upload_datastore starting...
# [2021-09-02T14:11:44.403943] job release stage : start importing azureml.history._tracking in run_history_release.[2021-09-02T14:11:44.404153] Entering context manager injector.
# [2021-09-02T14:11:44.404769] job release stage : copy_batchai_cached_logs starting...
# [2021-09-02T14:11:44.404810] job release stage : copy_batchai_cached_logs completed...
#
# [2021-09-02T14:11:44.406698] job release stage : execute_job_release starting...[2021-09-02T14:11:44.407085] job release stage : upload_datastore completed...
#
# [2021-09-02T14:11:44.496257] job release stage : send_run_telemetry starting...
# [2021-09-02T14:11:44.514305] get vm size and vm region successfully.
# [2021-09-02T14:11:44.524053] get compute meta data successfully.
# [2021-09-02T14:11:44.590271] job release stage : execute_job_release completed...
# [2021-09-02T14:11:44.672647] post artifact meta request successfully.
# [2021-09-02T14:11:44.698504] upload compute record artifact successfully.
# [2021-09-02T14:11:44.698646] job release stage : send_run_telemetry completed...
# [2021-09-02T14:11:44.698876] Running in AzureML-Sidecar, starting to exit user context managers...
# [2021-09-02T14:11:44.698966] Running Sidecar release cmd...
# [2021-09-02T14:11:44.708727] INFO azureml.sidecar.sidecar: Received task: exit_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/aml-nuclio/azureml/0fd5b744-5f93-4374-9f8a-669b8aa890f2/wd/azureml/0fd5b744-5f93-4374-9f8a-669b8aa890f2
# Enter __exit__ of DatasetContextManager
# Unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/aml-nuclio/azureml/0fd5b744-5f93-4374-9f8a-669b8aa890f2/wd/vino_batch_0ed87060-2ae1-433b-b413-7ae68aff6bc4.
# Finishing unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/aml-nuclio/azureml/0fd5b744-5f93-4374-9f8a-669b8aa890f2/wd/vino_batch_0ed87060-2ae1-433b-b413-7ae68aff6bc4.
# Unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/aml-nuclio/azureml/0fd5b744-5f93-4374-9f8a-669b8aa890f2/wd/inferences_workspaceblobstore.
# fuse: failed to unmount /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/aml-nuclio/azureml/0fd5b744-5f93-4374-9f8a-669b8aa890f2/wd/inferences_workspaceblobstore: No such file or directory
# Finishing unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/aml-nuclio/azureml/0fd5b744-5f93-4374-9f8a-669b8aa890f2/wd/inferences_workspaceblobstore.
# Exit __exit__ of DatasetContextManager
# [2021-09-02T14:11:44.749633] Removing absolute paths from host...
# [2021-09-02T14:11:44.749870] INFO azureml.sidecar.task.exit_contexts: Exited Context Managers
# [2021-09-02T14:11:45.362725] Ran Sidecar release cmd.
# [2021-09-02T14:11:45.362996] Job release is complete
#
# StepRun(batch-score-vino) Execution Summary
# ============================================
# StepRun( batch-score-vino ) Status: Finished
# {'runId': '0fd5b744-5f93-4374-9f8a-669b8aa890f2', 'target': 'NuclioCluster', 'status': 'Completed', 'startTimeUtc': '2021-09-02T14:09:19.184465Z', 'endTimeUtc': '2021-09-02T14:12:53.531599Z', 'properties': {'ContentSnapshotId': 'f57c5dca-a166-4ceb-b341-9a398593aa01', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '5ba56d6a-4cd2-4521-91c2-1919a8bbe84c', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': '012ab228', 'azureml.pipelinerunid': '3f81b6ca-05a8-4203-94ff-0a858883ea44', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json', 'azureml.parallelrunstep': 'true'}, 'inputDatasets': [{'dataset': {'id': '0ed87060-2ae1-433b-b413-7ae68aff6bc4'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'vino_batch', 'mechanism': 'Mount'}}, {'dataset': {'id': 'e10b3f39-852f-4f3c-a632-10ff7c9a5b2c'}, 'consumptionDetails': {'type': 'Reference'}}], 'outputDatasets': [{'identifier': {'savedId': 'e10b3f39-852f-4f3c-a632-10ff7c9a5b2c'}, 'outputType': 'RunOutput', 'outputDetails': {'outputName': 'inferences'}, 'dataset': {
#   "source": [
#     "('workspaceblobstore', 'dataset/0fd5b744-5f93-4374-9f8a-669b8aa890f2/inferences/')"
#   ],
#   "definition": [
#     "GetDatastoreFiles"
#   ],
#   "registration": {
#     "id": "e10b3f39-852f-4f3c-a632-10ff7c9a5b2c",
#     "name": null,
#     "version": null,
#     "workspace": "Workspace.create(name='aml-nuclio', subscription_id='87f9793d-5515-43eb-b182-0f27b97da8b3', resource_group='nuclio')"
#   }
# }}], 'runDefinition': {'script': 'driver/amlbi_main.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--client_sdk_version', '1.32.0', '--scoring_module_name', 'batch_vino.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', 'DatasetOutputConfig:inferences', '--input_fds_0', 'vino_batch'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'NuclioCluster', 'dataReferences': {}, 'data': {'vino_batch': {'dataLocation': {'dataset': {'id': '0ed87060-2ae1-433b-b413-7ae68aff6bc4', 'name': None, 'version': '1'}, 'dataPath': None, 'uri': None}, 'mechanism': 'Mount', 'environmentVariableName': 'vino_batch', 'pathOnCompute': None, 'overwrite': False, 'options': None}}, 'outputData': {'inferences': {'outputLocation': {'dataset': None, 'dataPath': {'datastoreName': 'workspaceblobstore', 'relativePath': None}, 'uri': None}, 'mechanism': 'Mount', 'additionalOptions': {'pathOnCompute': '/tmp/cf0b3ff3-26ab-4ffe-803c-76f49337eca6/', 'registrationOptions': {'name': None, 'description': None, 'tags': None, 'datasetRegistrationOptions': {'additionalTransformation': None}}, 'uploadOptions': {'overwrite': False, 'sourceGlobs': {'globPatterns': None}}, 'mountOptions': None}, 'environmentVariableName': None}}, 'datacaches': [], 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 2, 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'experiment_env', 'version': 'Autosave_2021-09-02T13:58:12Z_08688bef', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'dependencies': ['python=3.6.2', 'scikit-learn', 'pip', {'pip': ['azureml-defaults']}], 'name': 'azureml_e220b045f6c3c3008b1a386af067185d'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210615.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': False, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': 'D2', 'imageVersion': 'pytorch-1.7.0', 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None, 'virtualClusterArmId': None, 'tensorboardLogDirectory': None, 'sshPublicKey': None, 'enableAzmlInt': True, 'priority': 'Medium', 'slaTier': 'Standard', 'userAlias': None}, 'kubernetesCompute': {'instanceType': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': 'nccl', 'processCount': None}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'commandReturnCodeConfig': {'returnCode': 'Zero', 'successfulReturnCodes': []}, 'environmentVariables': {}, 'applicationEndpoints': {}, 'parameters': [], 'dataBricks': {'workers': 0, 'minimumWorkerCount': 0, 'maxMumWorkerCount': 0, 'sparkVersion': '4.0.x-scala2.11', 'nodeTypeId': 'Standard_D3_v2', 'sparkConf': {}, 'sparkEnvVars': {}, 'instancePoolId' ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '3f81b6ca-05a8-4203-94ff-0a858883ea44', 'status': 'Completed', 'startTimeUtc': '2021-09-02T13:57:24.137298Z', 'endTimeUtc': '2021-09-02T14:12:55.436002Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://amlnuclio7384818405.blob.core.windows.net/azureml/ExperimentRun/dcid.3f81b6ca-05a8-4203-94ff-0a858883ea44/logs/azureml/executionlogs.txt?sv=2019-07-07&sr=b&sig=%2BuGmeM3GURGoA2vwgwJWgdmU5crB0yYJfJ64Y6OerFI%3D&st=2021-09-02T14%3A01%3A47Z&se=2021-09-02T22%3A11%3A47Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://amlnuclio7384818405.blob.core.windows.net/azureml/ExperimentRun/dcid.3f81b6ca-05a8-4203-94ff-0a858883ea44/logs/azureml/stderrlogs.txt?sv=2019-07-07&sr=b&sig=Z2CzWfSYlCJgoJjJGlzAF%2BkScjqLQqd74Z5sj4coXYs%3D&st=2021-09-02T14%3A01%3A47Z&se=2021-09-02T22%3A11%3A47Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://amlnuclio7384818405.blob.core.windows.net/azureml/ExperimentRun/dcid.3f81b6ca-05a8-4203-94ff-0a858883ea44/logs/azureml/stdoutlogs.txt?sv=2019-07-07&sr=b&sig=Cd5pk9eE8OVIWRKS5XFW5CGNLyxK1%2BrJDrlnMaFjhG0%3D&st=2021-09-02T14%3A01%3A47Z&se=2021-09-02T22%3A11%3A47Z&sp=r'}, 'submittedBy': 'Heri Nuclio'}
# 'Finished'

# %%
import pandas as pd
import shutil

# Elimina la carpeta con los resultados locales
shutil.rmtree('vino-results', ignore_errors=True)

# Consigue la ejecución del primer paso y descarga el output
prediction_run = next(pipeline_run.get_children())
prediction_output = prediction_run.get_output_data('inferences')
prediction_output.download(local_path='vino-results')

# Recorre la jerarquía de carpetas y encuentra el archivo de resultados
for root, dirs, files in os.walk('vino-results'):
    for file in files:
        if file.endswith('parallel_run_step.txt'):
            result_file = os.path.join(root,file)

# Output
df = pd.read_csv(result_file, delimiter=":", header=None)
df.columns = ["File", "Prediction"]

# Visualiza las 20 primeras filas
df.head(20)
# Out:
#        File  Prediction
# 0     1.csv           0
# 1    10.csv           0
# 2   100.csv           1
# 3    11.csv           0
# 4    12.csv           0
# 5    13.csv           0
# 6    14.csv           0
# 7    15.csv           1
# 8    16.csv           0
# 9    17.csv           1
# 10   18.csv           1
# 11   19.csv           1
# 12    2.csv           0
# 13   20.csv           0
# 14   21.csv           0
# 15   22.csv           0
# 16   23.csv           0
# 17   24.csv           0
# 18   25.csv           0
# 19   26.csv           0

# %% [markdown]
# ## Publicar la canalización y usar como una interfaz REST

# %%
published_pipeline = pipeline_run.publish_pipeline(
    name='vino-batch-pipeline', description='Scoring batch de los datos del vino', version='1.0')

published_pipeline
# Out:
# Pipeline(Name: vino-batch-pipeline,
# Id: cf71cfaa-590f-4ccb-8f60-319968c02485,
# Status: Active,
# Endpoint: https://francecentral.api.azureml.ms/pipelines/v1.0/subscriptions/87f9793d-5515-43eb-b182-0f27b97da8b3/resourceGroups/nuclio/providers/Microsoft.MachineLearningServices/workspaces/aml-nuclio/PipelineRuns/PipelineSubmit/cf71cfaa-590f-4ccb-8f60-319968c02485)

# %%
rest_endpoint = published_pipeline.endpoint
print(rest_endpoint)
# Out:
# https://francecentral.api.azureml.ms/pipelines/v1.0/subscriptions/87f9793d-5515-43eb-b182-0f27b97da8b3/resourceGroups/nuclio/providers/Microsoft.MachineLearningServices/workspaces/aml-nuclio/PipelineRuns/PipelineSubmit/cf71cfaa-590f-4ccb-8f60-319968c02485

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()
print('Autentificación preparada.')
# Out:
# Autentificación preparada.

# %% [markdown]
# Se puede llamar a la interfaz REST. La canalización ejecuta de manera asincrona.

# %%
import requests

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": "nuclio-vino-batch"})
run_id = response.json()["Id"]
run_id
# Out:
# '2b8cd4cc-257b-474e-b7a6-4af7018b0c86'

# %%
from azureml.pipeline.core.run import PipelineRun
from azureml.widgets import RunDetails

published_pipeline_run = PipelineRun(ws.experiments['nuclio-vino-batch'], run_id)

published_pipeline_run.wait_for_completion(show_output=True)
# Out:
# PipelineRunId: 2b8cd4cc-257b-474e-b7a6-4af7018b0c86
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/2b8cd4cc-257b-474e-b7a6-4af7018b0c86?wsid=/subscriptions/87f9793d-5515-43eb-b182-0f27b97da8b3/resourcegroups/nuclio/workspaces/aml-nuclio&tid=e93a2455-92c2-4ff2-add1-a6a39d490ed6
# PipelineRun Status: Running
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '2b8cd4cc-257b-474e-b7a6-4af7018b0c86', 'status': 'Completed', 'startTimeUtc': '2021-09-02T14:13:01.644062Z', 'endTimeUtc': '2021-09-02T14:13:02.894834Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'Unavailable', 'runType': 'HTTP', 'azureml.parameters': '{}', 'azureml.pipelineid': 'cf71cfaa-590f-4ccb-8f60-319968c02485'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://amlnuclio7384818405.blob.core.windows.net/azureml/ExperimentRun/dcid.2b8cd4cc-257b-474e-b7a6-4af7018b0c86/logs/azureml/executionlogs.txt?sv=2019-07-07&sr=b&sig=2bMttj9rOea1ymVQLk3nEzP6vSgjMx6wf2U0KjpSMhI%3D&st=2021-09-02T14%3A03%3A03Z&se=2021-09-02T22%3A13%3A03Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://amlnuclio7384818405.blob.core.windows.net/azureml/ExperimentRun/dcid.2b8cd4cc-257b-474e-b7a6-4af7018b0c86/logs/azureml/stderrlogs.txt?sv=2019-07-07&sr=b&sig=oRuV0pLUBMBLXhSKB2NJ7XM5vxUjbpB0w0u7Skttdjw%3D&st=2021-09-02T14%3A03%3A03Z&se=2021-09-02T22%3A13%3A03Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://amlnuclio7384818405.blob.core.windows.net/azureml/ExperimentRun/dcid.2b8cd4cc-257b-474e-b7a6-4af7018b0c86/logs/azureml/stdoutlogs.txt?sv=2019-07-07&sr=b&sig=xCa%2FprEgiaNit8Gva0qbdOAbHsk6eaUesDNAaiOfARA%3D&st=2021-09-02T14%3A03%3A03Z&se=2021-09-02T22%3A13%3A03Z&sp=r'}, 'submittedBy': 'Heri Nuclio'}
# 'Finished'

# %%
import pandas as pd
import shutil

# Elimina la carpeta con los resultados locales
shutil.rmtree('vino-results', ignore_errors=True)

# Consigue la ejecución del primer paso y descarga el output
prediction_run = next(pipeline_run.get_children())
prediction_output = prediction_run.get_output_data('inferences')
prediction_output.download(local_path='vino-results')

# Recorre la jerarquía de carpetas y encuentra el archivo de resultados
for root, dirs, files in os.walk('vino-results'):
    for file in files:
        if file.endswith('parallel_run_step.txt'):
            result_file = os.path.join(root,file)

# Output
df = pd.read_csv(result_file, delimiter=":", header=None)
df.columns = ["File", "Prediction"]

# Visualiza las 20 primeras filas
df.head(20)
# Out:
#        File  Prediction
# 0     1.csv           0
# 1    10.csv           0
# 2   100.csv           1
# 3    11.csv           0
# 4    12.csv           0
# 5    13.csv           0
# 6    14.csv           0
# 7    15.csv           1
# 8    16.csv           0
# 9    17.csv           1
# 10   18.csv           1
# 11   19.csv           1
# 12    2.csv           0
# 13   20.csv           0
# 14   21.csv           0
# 15   22.csv           0
# 16   23.csv           0
# 17   24.csv           0
# 18   25.csv           0
# 19   26.csv           0

# %% [markdown]
# **Más información**: [Compilación de una canalización de Azure Machine Learning para la puntuación por lote](https://docs.microsoft.com/azure/machine-learning/how-to-run-batch-predictions)
